# %% [markdown]
# # Check raw vs evaluated data
#
# Check that after all changes, the evaluated files contain the same names (first, mid, last, full) than the raw test data file

# %%
import pandas as pd
from evaluators import *
from IPython.display import display

# %%
def check_match_test_evaluated_data(evaluator):
    """Checks that the content of an evaluated file agrees with the raw test data.
    Prints the rows that do not agree
    Merges the raw test data file and the evaluated one and checks for distinct columns"""
    # Run load_data with optional return_frame=True to not overwrite evaluator.test_data
    rawdf = evaluator.load_data(return_frame=True)
    evaldf = evaluator.test_data
    # We assume that the data has been evaluated, i.e. rawdf and evaldf are different
    # Make left join to get all matches that are in raw but not in eval
    merged = evaldf.merge(rawdf, indicator=True, how='outer')
    # Results in column _merge are either 'both' or 'left_only' - the latter are to be updated
    changed_tests = merged[merged['_merge'].isin(['left_only', 'right_only'])]
    if len(changed_tests) == 0:
        print('Evaluated data set matches contents of test data set. Good!')
    else:
        print('There is a mismatch between raw and evaluated datasets. Please fix.')
        print('right_only are entries in the raw data set. left_only in the evaluated one.')
    display(changed_tests)

# %% [markdown]
# ### Gender_guesser

# %%
data_source = 'all'
service_name = GenderGuesserEvaluator

# %%
evaluatorGG = service_name(data_source)
evaluatorGG.load_data()
evaluatorGG.fetch_gender()
# Out:
# Reading data from dump file test_data/gender_guesser/test_data_all_gender_guesser.csv

# %%
check_match_test_evaluated_data(evaluatorGG)
# Out:
# Evaluated data set matches contents of test data set. Good!
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_gender, gender_infered, _merge]
# Index: []

# %% [markdown]
# Gender_guesser was evaluated after the refactoring. No need to re-do the names with connectors.

# %%
evaluatorGG.compute_all_errors()
evaluatorGG.confusion_matrix
# Out:
#    f_pred  m_pred  u_pred
# f    1509      69     383
# m      94    2953     782
# u     250     638     398

# %% [markdown]
# ### Genderize_io

# %%
data_source = 'all'
service_name = GenderizeIoEvaluator

# %%
evaluatorGIO = service_name(data_source)
evaluatorGIO.load_data()
evaluatorGIO.fetch_gender()
# Out:
# Reading data from dump file test_data/genderize_io/test_data_all_genderize_io.csv

# %%
check_match_test_evaluated_data(evaluatorGIO)
# Out:
# Evaluated data set matches contents of test data set. Good!
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_count, api_gender, api_name, api_probability, gender_infered, _merge]
# Index: []

# %% [markdown]
# Genderize_io was evaluated after the refactoring. No need to re-do the names with connectors.

# %%
evaluatorGIO.compute_all_errors()
evaluatorGIO.confusion_matrix
# Out:
#    f_pred  m_pred  u_pred
# f    1722      88     151
# m     220    3197     412
# u     361     762     163

# %% [markdown]
# ### NamSor

# %%
data_source = 'all'
service_name = NamSorEvaluator

# %%
evaluatorNS = service_name(data_source)
evaluatorNS.load_data()
evaluatorNS.fetch_gender()
# Out:
# Reading data from dump file test_data/namsor/test_data_all_namsor.csv

# %%
check_match_test_evaluated_data(evaluatorNS)
# Out:
# Evaluated data set matches contents of test data set. Good!
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_firstName, api_gender, api_lastName, api_scale, gender_infered, _merge]
# Index: []

# %% [markdown]
# NamSor was evaluated after the refactoring. No need to re-do the names with connectors.

# %%
evaluatorNS.compute_all_errors()
evaluatorNS.confusion_matrix
# Out:
#    f_pred  m_pred  u_pred
# f    1662     109     190
# m     162    3341     326
# u     282     706     298

# %% [markdown]
# ### NamesAPI-Full

# %%
data_source = 'all'
service_name = NamesAPIFullEvaluator

# %%
evaluatorNAF = service_name(data_source)
evaluatorNAF.load_data()
evaluatorNAF.fetch_gender()
# Out:
# Reading data from dump file test_data/names_api_full/test_data_all_names_api_full.csv

# %% [markdown]
# #### Fix problem with 'nan' name

# %%
check_match_test_evaluated_data(evaluatorNAF)
# Out:
# There is a mismatch between raw and evaluated datasets. Please fix.
# right_only are entries in the raw data set. left_only in the evaluated one.
#      first_name middle_name last_name      full_name gender  origin  \
# 5038                   xian      chen  nan xian chen      m  nature
# 7076        nan        xian      chen  nan xian chen      m  nature
#
#       api_confidence api_gender api_maleProportion gender_infered      _merge
# 5038        0.814064       MALE                                 m   left_only
# 7076             NaN        NaN                NaN            NaN  right_only

# %%
# In the old test data file the first name had been incorrectly read as NaN. Put 'nan' back in
evaluatorNAF.test_data.loc[5038, 'first_name'] = 'nan'

# %%
evaluatorNAF.update_selected_records([5038])
# Out:
# Updating entry 5038
# Calling API for name:
# first_name: nan	middle_name: xian	                   last_name: chen	full_name: nan xian chen
# Data updated in dump file test_data/names_api_full/test_data_all_names_api_full.csv

# %%
evaluatorNAF.fetch_gender()
# Out:
# Reading data from dump file test_data/names_api_full/test_data_all_names_api_full.csv

# %%
check_match_test_evaluated_data(evaluatorNAF)
# Out:
# Evaluated data set matches contents of test data set. Good!
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_confidence, api_gender, api_maleProportion, gender_infered, _merge]
# Index: []

# %% [markdown]
# #### Re-do names with middle name - since handling of connectors in the code changed after loop refactoring

# %%
evaluatorNAF.test_data[evaluatorNAF.test_data.middle_name!=''].head()
# Out:
#    first_name middle_name   last_name                  full_name gender  \
# 0      pierre        paul      grivel         pierre paul grivel      m
# 6   catherine     bouloux     marquet  catherine bouloux marquet      f
# 14     claude     joachim      hamann      claude joachim hamann      m
# 22      jorge     drumond       silva        jorge drumond silva      m
# 25       jost     hinrich  eschenburg    jost hinrich eschenburg      m
#
#     origin  api_confidence api_gender api_maleProportion gender_infered
# 0   zbmath        1.000000       MALE                                 m
# 6   zbmath        0.901827     FEMALE                                 f
# 14  zbmath        1.000000       MALE                                 m
# 22  zbmath        0.896182       MALE                                 m
# 25  zbmath        0.735872       MALE                                 m

# %%
len(evaluatorNAF.test_data[evaluatorNAF.test_data.middle_name!=''])
# Out:
# 913

# %% [markdown]
# We need to re-do all those 913 cases above, since we do not know which ones came from joining first and middle name with empty connector.

# %%
evaluatorNAF.test_data[(evaluatorNAF.test_data.middle_name!='')].head(10)
# Out:
#     first_name  middle_name   last_name                  full_name gender  \
# 0       pierre         paul      grivel         pierre paul grivel      m
# 6    catherine      bouloux     marquet  catherine bouloux marquet      f
# 14      claude      joachim      hamann      claude joachim hamann      m
# 22       jorge      drumond       silva        jorge drumond silva      m
# 25        jost      hinrich  eschenburg    jost hinrich eschenburg      m
# 44         jae           il         lee                 jae il lee      u
# 50       boris  yakovlevich       levin    boris yakovlevich levin      m
# 71       marek       cezary        zdun          marek cezary zdun      m
# 88      pierre         loic      meliot         pierre loic meliot      m
# 110    douglas         john       white         douglas john white      m
#
#      origin  api_confidence api_gender api_maleProportion gender_infered
# 0    zbmath        1.000000       MALE                                 m
# 6    zbmath        0.901827     FEMALE                                 f
# 14   zbmath        1.000000       MALE                                 m
# 22   zbmath        0.896182       MALE                                 m
# 25   zbmath        0.735872       MALE                                 m
# 44   zbmath        0.911111    UNKNOWN                                 u
# 50   zbmath        1.000000       MALE                                 m
# 71   zbmath        1.000000       MALE                                 m
# 88   zbmath        1.000000       MALE                                 m
# 110  zbmath        1.000000       MALE                                 m

# %%
len(evaluatorNAF.test_data[(evaluatorNAF.test_data.middle_name!='')])
# Out:
# 913

# %%
to_update_indices = evaluatorNAF.test_data[(evaluatorNAF.test_data.middle_name!='')].index
to_update_indices
# Out:
# Int64Index([   0,    6,   14,   22,   25,   44,   50,   71,   88,  110,
#             ...
#             7050, 7051, 7056, 7057, 7062, 7063, 7064, 7068, 7073, 7074],
#            dtype='int64', length=913)

# %%
evaluatorNAF.update_selected_records(to_update_indices)
# Out:
# Updating entry 0
# Calling API for name:
# first_name: pierre	middle_name: paul	                   last_name: grivel	full_name: pierre paul grivel
# Updating entry 6
# Calling API for name:
# first_name: catherine	middle_name: bouloux	                   last_name: marquet	full_name: catherine bouloux marquet
# Updating entry 14
# Calling API for name:
# first_name: claude	middle_name: joachim	                   last_name: hamann	full_name: claude joachim hamann
# Updating entry 22
# Calling API for name:
# first_name: jorge	middle_name: drumond	                   last_name: silva	full_name: jorge drumond silva
# Updating entry 25
# Calling API for name:
# first_name: jost	middle_name: hinrich	                   last_name: eschenburg	full_name: jost hinrich eschenburg
# Updating entry 44
# Calling API for name:
# first_name: jae	middle_name: il	                   last_name: lee	full_name: jae il lee
# Updating entry 50
# Calling API for name:
# first_name: boris	middle_name: yakovlevich	                   last_name: levin	full_name: boris yakovlevich levin
# Updating entry 71
# Calling API for name:
# first_name: marek	middle_name: cezary	                   last_name: zdun	full_name: marek cezary zdun
# Updating entry 88
# Calling API for name:
# first_name: pierre	middle_name: loic	                   last_name: meliot	full_name: pierre loic meliot
# Updating entry 110
# Calling API for name:
# first_name: douglas	middle_name: john	                   last_name: white	full_name: douglas john white
# Updating entry 111
# Calling API for name:
# first_name: davy	middle_name: ho	                   last_name: chan	full_name: davy ho chan
# Updating entry 114
# Calling API for name:
# first_name: isabel	middle_name: fraga	                   last_name: alves	full_name: isabel fraga alves
# Updating entry 115
# Calling API for name:
# first_name: jin	middle_name: ho	                   last_name: choi	full_name: jin ho choi
# Updating entry 121
# Calling API for name:
# first_name: john	middle_name: ren	                   last_name: chen	full_name: john ren chen
# Updating entry 134
# Calling API for name:
# first_name: outi	middle_name: elina	                   last_name: maasalo	full_name: outi elina maasalo
# Updating entry 139
# Calling API for name:
# first_name: marie	middle_name: francoise	                   last_name: delcroix	full_name: marie francoise delcroix
# Updating entry 145
# Calling API for name:
# first_name: suhasini	middle_name: subba	                   last_name: rao	full_name: suhasini subba rao
# Updating entry 147
# Calling API for name:
# first_name: david	middle_name: matthew	                   last_name: kelly	full_name: david matthew kelly
# Updating entry 163
# Calling API for name:
# first_name: james	middle_name: murray	                   last_name: hill	full_name: james murray hill
# Updating entry 180
# Calling API for name:
# first_name: maria	middle_name: zofia	                   last_name: banaszczyk	full_name: maria zofia banaszczyk
# Updating entry 181
# Calling API for name:
# first_name: mehmet	middle_name: namik	                   last_name: oguztoereli	full_name: mehmet namik oguztoereli
# Updating entry 187
# Calling API for name:
# first_name: alexei	middle_name: yu	                   last_name: karlovich	full_name: alexei yu karlovich
# Updating entry 195
# Calling API for name:
# first_name: soo	middle_name: jin	                   last_name: kim	full_name: soo jin kim
# Updating entry 218
# Calling API for name:
# first_name: sung	middle_name: hoon	                   last_name: hong	full_name: sung hoon hong
# Updating entry 224
# Calling API for name:
# first_name: figen	middle_name: acil	                   last_name: kiraz	full_name: figen acil kiraz
# Updating entry 238
# Calling API for name:
# first_name: asim	middle_name: kumar	                   last_name: mandal	full_name: asim kumar mandal
# Updating entry 256
# Calling API for name:
# first_name: alf	middle_name: birger	                   last_name: rustad	full_name: alf birger rustad
# Updating entry 266
# Calling API for name:
# first_name: abdel	middle_name: hadi	                   last_name: ahmed	full_name: abdel hadi ahmed
# Updating entry 292
# Calling API for name:
# first_name: razvan	middle_name: alin	                   last_name: satnoianu	full_name: razvan alin satnoianu
# Updating entry 295
# Calling API for name:
# first_name: huy	middle_name: thang	                   last_name: cao	full_name: huy thang cao
# Updating entry 300
# Calling API for name:
# first_name: ben	middle_name: da	                   last_name: zhou	full_name: ben da zhou
# Updating entry 310
# Calling API for name:
# first_name: hon	middle_name: kit	                   last_name: wai	full_name: hon kit wai
# Updating entry 311
# Calling API for name:
# first_name: bao	middle_name: wen	                   last_name: sun	full_name: bao wen sun
# Updating entry 312
# Calling API for name:
# first_name: byoung	middle_name: chan	                   last_name: lee	full_name: byoung chan lee
# Updating entry 325
# Calling API for name:
# first_name: carlos	middle_name: renato	                   last_name: vazquez	full_name: carlos renato vazquez
# Updating entry 327
# Calling API for name:
# first_name: b	middle_name: jo	                   last_name: ptashnyk	full_name: b jo ptashnyk
# Updating entry 333
# Calling API for name:
# first_name: chao	middle_name: zhu	                   last_name: zhang	full_name: chao zhu zhang
# Updating entry 342
# Calling API for name:
# first_name: jwu	middle_name: sheng	                   last_name: hu	full_name: jwu sheng hu
# Updating entry 347
# Calling API for name:
# first_name: wai	middle_name: king	                   last_name: ching	full_name: wai king ching
# Updating entry 348
# Calling API for name:
# first_name: maria	middle_name: conception	                   last_name: carvalho	full_name: maria conception carvalho
# Updating entry 357
# Calling API for name:
# first_name: cai	middle_name: gui	                   last_name: liu	full_name: cai gui liu
# Updating entry 359
# Calling API for name:
# first_name: jan	middle_name: tijmen	                   last_name: udding	full_name: jan tijmen udding
# Updating entry 361
# Calling API for name:
# first_name: hsueh	middle_name: chuan	                   last_name: liu	full_name: hsueh chuan liu
# Updating entry 366
# Calling API for name:
# first_name: frieder	middle_name: jens	                   last_name: lange	full_name: frieder jens lange
# Updating entry 373
# Calling API for name:
# first_name: cheng	middle_name: wei	                   last_name: chen	full_name: cheng wei chen
# Updating entry 378
# Calling API for name:
# first_name: john	middle_name: wilson	                   last_name: calkin	full_name: john wilson calkin
# Updating entry 389
# Calling API for name:
# first_name: tack	middle_name: wang	                   last_name: lee	full_name: tack wang lee
# Updating entry 422
# Calling API for name:
# first_name: judith	middle_name: louisa	                   last_name: schmid	full_name: judith louisa schmid
# Updating entry 482
# Calling API for name:
# first_name: yves	middle_name: marie	                   last_name: allioux	full_name: yves marie allioux
# Updating entry 495
# Calling API for name:
# first_name: linda	middle_name: esther	                   last_name: oray	full_name: linda esther oray
# Updating entry 514
# Calling API for name:
# first_name: shing	middle_name: tung	                   last_name: yau	full_name: shing tung yau
# Updating entry 570
# Calling API for name:
# first_name: diane	middle_name: romayne	                   last_name: baker	full_name: diane romayne baker
# Updating entry 572
# Calling API for name:
# first_name: dusanka	middle_name: savic	                   last_name: pavicevic	full_name: dusanka savic pavicevic
# Updating entry 589
# Calling API for name:
# first_name: geraldo	middle_name: vicente	                   last_name: de almeida	full_name: geraldo vicente de almeida
# Updating entry 602
# Calling API for name:
# first_name: hyoung	middle_name: gon	                   last_name: lee	full_name: hyoung gon lee
# Updating entry 606
# Calling API for name:
# first_name: ronald	middle_name: grigor	                   last_name: suny	full_name: ronald grigor suny
# Updating entry 666
# Calling API for name:
# first_name: pedro	middle_name: ramon	                   last_name: gutierrez hernandez	full_name: pedro ramon gutierrez hernandez
# Updating entry 705
# Calling API for name:
# first_name: nirmal	middle_name: kumar	                   last_name: chandra	full_name: nirmal kumar chandra
# Updating entry 717
# Calling API for name:
# first_name: charlotte	middle_name: pomerantz	                   last_name: marzani	full_name: charlotte pomerantz marzani
# Updating entry 739
# Calling API for name:
# first_name: pierre	middle_name: sylvain	                   last_name: filliozat	full_name: pierre sylvain filliozat
# Updating entry 751
# Calling API for name:
# first_name: anne	middle_name: hudson	                   last_name: jones	full_name: anne hudson jones
# Updating entry 782
# Calling API for name:
# first_name: hans	middle_name: peter	                   last_name: bruch	full_name: hans peter bruch
# Updating entry 789
# Calling API for name:
# first_name: carol	middle_name: anne	                   last_name: costabile-heming	full_name: carol anne costabile-heming
# Updating entry 795
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: pujol	full_name: jean louis pujol
# Updating entry 802
# Calling API for name:
# first_name: karl	middle_name: heinz	                   last_name: schwalbe	full_name: karl heinz schwalbe
# Updating entry 833
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: bardon	full_name: jean pierre bardon
# Updating entry 885
# Calling API for name:
# first_name: jose	middle_name: carlos	                   last_name: mainer	full_name: jose carlos mainer
# Updating entry 888
# Calling API for name:
# first_name: rolf	middle_name: tore	                   last_name: ottesen	full_name: rolf tore ottesen
# Updating entry 898
# Calling API for name:
# first_name: mary	middle_name: rose	                   last_name: couper	full_name: mary rose couper
# Updating entry 952
# Calling API for name:
# first_name: cindy	middle_name: fabian	                   last_name: mascone	full_name: cindy fabian mascone
# Updating entry 967
# Calling API for name:
# first_name: nancy	middle_name: mary	                   last_name: adams	full_name: nancy mary adams
# Updating entry 984
# Calling API for name:
# first_name: rob	middle_name: roy	                   last_name: kelly	full_name: rob roy kelly
# Updating entry 988
# Calling API for name:
# first_name: allen	middle_name: purdue	                   last_name: britton	full_name: allen purdue britton
# Updating entry 992
# Calling API for name:
# first_name: aage	middle_name: niels	                   last_name: bohr	full_name: aage niels bohr
# Updating entry 995
# Calling API for name:
# first_name: alastair	middle_name: michael	                   last_name: porter	full_name: alastair michael douglas porter
# Updating entry 996
# Calling API for name:
# first_name: alastair	middle_name: vincent	                   last_name: campbell	full_name: alastair vincent campbell
# Updating entry 997
# Calling API for name:
# first_name: aldo	middle_name: ricardo	                   last_name: castaneda	full_name: aldo ricardo castaneda
# Updating entry 998
# Calling API for name:
# first_name: aleksandr	middle_name: aleksandrovich	                   last_name: kaplyanskii	full_name: aleksandr aleksandrovich kaplyanskii
# Updating entry 999
# Calling API for name:
# first_name: aleksandr	middle_name: petrovich	                   last_name: krylov	full_name: aleksandr petrovich krylov
# Updating entry 1000
# Calling API for name:
# first_name: aleksandr	middle_name: yakovlevich	                   last_name: lerner	full_name: aleksandr yakovlevich lerner
# Updating entry 1002
# Calling API for name:
# first_name: alexander	middle_name: yakovlevich	                   last_name: lerner	full_name: alexander yakovlevich lerner
# Updating entry 1004
# Calling API for name:
# first_name: anatolii	middle_name: aleksandrovich	                   last_name: ishchenko	full_name: anatolii aleksandrovich ishchenko
# Updating entry 1006
# Calling API for name:
# first_name: andre	middle_name: stephane	                   last_name: hamer	full_name: andre stephane hamer
# Updating entry 1008
# Calling API for name:
# first_name: anna	middle_name: isabella	                   last_name: davison	full_name: anna isabella davison
# Updating entry 1009
# Calling API for name:
# first_name: anne	middle_name: mary	                   last_name: buck	full_name: anne mary buck
# Updating entry 1011
# Calling API for name:
# first_name: anthony	middle_name: francis	                   last_name: rickards	full_name: anthony francis rickards
# Updating entry 1012
# Calling API for name:
# first_name: antony	middle_name: frank	                   last_name: francis	full_name: antony frank francis
# Updating entry 1013
# Calling API for name:
# first_name: arsen	middle_name: ralph	                   last_name: papakhian	full_name: arsen ralph papakhian
# Updating entry 1016
# Calling API for name:
# first_name: arthur	middle_name: philip	                   last_name: waind	full_name: arthur philip booth waind
# Updating entry 1024
# Calling API for name:
# first_name: benedict	middle_name: john	                   last_name: barry	full_name: benedict john barry
# Updating entry 1026
# Calling API for name:
# first_name: bertram	middle_name: neville	                   last_name: brockhouse	full_name: bertram neville brockhouse
# Updating entry 1036
# Calling API for name:
# first_name: campbell	middle_name: grieve	                   last_name: stalker	full_name: campbell grieve stalker
# Updating entry 1037
# Calling API for name:
# first_name: carl	middle_name: gottfried	                   last_name: semper	full_name: carl gottfried semper
# Updating entry 1038
# Calling API for name:
# first_name: carl	middle_name: gustav	                   last_name: jung	full_name: carl gustav jung
# Updating entry 1052
# Calling API for name:
# first_name: david	middle_name: abraham	                   last_name: katcher	full_name: david abraham katcher
# Updating entry 1053
# Calling API for name:
# first_name: david	middle_name: hamilton	                   last_name: smith	full_name: david hamilton smith
# Updating entry 1054
# Calling API for name:
# first_name: david	middle_name: herbert	                   last_name: donald	full_name: david herbert donald
# Updating entry 1056
# Calling API for name:
# first_name: david	middle_name: morris	                   last_name: welborn	full_name: david morris welborn
# Updating entry 1058
# Calling API for name:
# first_name: david	middle_name: schofield	                   last_name: jeffery	full_name: david schofield jeffery
# Updating entry 1062
# Calling API for name:
# first_name: derek	middle_name: charles	                   last_name: robinson	full_name: derek charles robinson
# Updating entry 1067
# Calling API for name:
# first_name: donald	middle_name: morgan	                   last_name: anderson	full_name: donald morgan anderson
# Updating entry 1068
# Calling API for name:
# first_name: donald	middle_name: redfield	                   last_name: griffin	full_name: donald redfield griffin
# Updating entry 1069
# Calling API for name:
# first_name: donald	middle_name: stevenson	                   last_name: pitkin	full_name: donald stevenson pitkin
# Updating entry 1070
# Calling API for name:
# first_name: donald	middle_name: william	                   last_name: gau	full_name: donald william gau
# Updating entry 1073
# Calling API for name:
# first_name: richard	middle_name: moreton	                   last_name: ellison	full_name: richard moreton ellison
# Updating entry 1076
# Calling API for name:
# first_name: clifton	middle_name: fletcher	                   last_name: mountain	full_name: clifton fletcher mountain
# Updating entry 1080
# Calling API for name:
# first_name: peer	middle_name: michael	                   last_name: portner	full_name: peer michael portner
# Updating entry 1088
# Calling API for name:
# first_name: edmund	middle_name: neville	                   last_name: hey	full_name: edmund neville hey
# Updating entry 1091
# Calling API for name:
# first_name: edwin	middle_name: sinclair	                   last_name: young	full_name: edwin sinclair young
# Updating entry 1094
# Calling API for name:
# first_name: eloge	middle_name: john	                   last_name: greene	full_name: eloge john colton greene
# Updating entry 1095
# Calling API for name:
# first_name: eric	middle_name: matheson	                   last_name: dunlop	full_name: eric matheson dunlop
# Updating entry 1098
# Calling API for name:
# first_name: evgenii	middle_name: akimovich	                   last_name: turov	full_name: evgenii akimovich turov
# Updating entry 1099
# Calling API for name:
# first_name: evgenii	middle_name: nikolaevich	                   last_name: avrorin	full_name: evgenii nikolaevich avrorin
# Updating entry 1106
# Calling API for name:
# first_name: garry	middle_name: davis	                   last_name: jones	full_name: garry davis jones
# Updating entry 1108
# Calling API for name:
# first_name: geoffrey	middle_name: john	                   last_name: pugh	full_name: geoffrey john frederick pugh
# Updating entry 1109
# Calling API for name:
# first_name: george	middle_name: adam	                   last_name: newsholme	full_name: george adam newsholme
# Updating entry 1111
# Calling API for name:
# first_name: george	middle_name: alfred	                   last_name: quinnell	full_name: george alfred fiske quinnell
# Updating entry 1113
# Calling API for name:
# first_name: george	middle_name: william	                   last_name: blair	full_name: george william scott blair
# Updating entry 1117
# Calling API for name:
# first_name: graham	middle_name: martin	                   last_name: pizzey	full_name: graham martin pizzey
# Updating entry 1118
# Calling API for name:
# first_name: graham	middle_name: warner	                   last_name: ward	full_name: graham warner ward
# Updating entry 1119
# Calling API for name:
# first_name: griff	middle_name: terry	                   last_name: ross	full_name: griff terry ross
# Updating entry 1120
# Calling API for name:
# first_name: guillermo	middle_name: lohmann	                   last_name: villena	full_name: guillermo lohmann villena
# Updating entry 1121
# Calling API for name:
# first_name: gwilym	middle_name: kenneth	                   last_name: davies	full_name: gwilym kenneth davies
# Updating entry 1124
# Calling API for name:
# first_name: harry	middle_name: francis	                   last_name: taylor	full_name: harry francis west taylor
# Updating entry 1128
# Calling API for name:
# first_name: herta	middle_name: julie	                   last_name: altschulova	full_name: herta julie altschulova
# Updating entry 1134
# Calling API for name:
# first_name: john	middle_name: szentagothai	                   last_name: centennial	full_name: john szentagothai centennial
# Updating entry 1144
# Calling API for name:
# first_name: joseph	middle_name: michael	                   last_name: foley	full_name: joseph michael foley
# Updating entry 1151
# Calling API for name:
# first_name: igor	middle_name: ivanovich	                   last_name: volkov	full_name: igor ivanovich volkov
# Updating entry 1158
# Calling API for name:
# first_name: leonid	middle_name: nikitovich	                   last_name: barabanov	full_name: leonid nikitovich barabanov
# Updating entry 1164
# Calling API for name:
# first_name: frederic	middle_name: louis	                   last_name: lizzi	full_name: frederic louis lizzi
# Updating entry 1165
# Calling API for name:
# first_name: george	middle_name: alex	                   last_name: mills	full_name: george alex mills
# Updating entry 1168
# Calling API for name:
# first_name: lawrence	middle_name: gideon	                   last_name: raisz	full_name: lawrence gideon raisz
# Updating entry 1171
# Calling API for name:
# first_name: margaret	middle_name: byrd	                   last_name: rawson	full_name: margaret byrd rawson
# Updating entry 1176
# Calling API for name:
# first_name: alexei	middle_name: borisovich	                   last_name: kaidalov	full_name: alexei borisovich kaidalov
# Updating entry 1186
# Calling API for name:
# first_name: john	middle_name: maxwell	                   last_name: cowley	full_name: john maxwell cowley
# Updating entry 1187
# Calling API for name:
# first_name: janet	middle_name: marion	                   last_name: martin	full_name: janet marion martin
# Updating entry 1192
# Calling API for name:
# first_name: jeanne	middle_name: allen	                   last_name: smith	full_name: jeanne allen smith
# Updating entry 1193
# Calling API for name:
# first_name: jeffery	middle_name: raymond	                   last_name: ede	full_name: jeffery raymond ede
# Updating entry 1194
# Calling API for name:
# first_name: johann	middle_name: christian	                   last_name: heinroth	full_name: johann christian august heinroth
# Updating entry 1195
# Calling API for name:
# first_name: john	middle_name: atherton	                   last_name: young	full_name: john atherton young
# Updating entry 1197
# Calling API for name:
# first_name: john	middle_name: frederick	                   last_name: reading	full_name: john frederick reading
# Updating entry 1198
# Calling API for name:
# first_name: john	middle_name: paton	                   last_name: erskine	full_name: john paton erskine
# Updating entry 1200
# Calling API for name:
# first_name: john	middle_name: robinson	                   last_name: pierce	full_name: john robinson pierce
# Updating entry 1204
# Calling API for name:
# first_name: jose	middle_name: juan	                   last_name: arrom	full_name: jose juan arrom
# Updating entry 1205
# Calling API for name:
# first_name: jose	middle_name: manuel	                   last_name: esteve	full_name: jose manuel esteve
# Updating entry 1206
# Calling API for name:
# first_name: jose	middle_name: maria	                   last_name: neves	full_name: jose maria neves
# Updating entry 1207
# Calling API for name:
# first_name: joseph	middle_name: periam	                   last_name: danton	full_name: joseph periam danton
# Updating entry 1209
# Calling API for name:
# first_name: julius	middle_name: erich	                   last_name: wess	full_name: julius erich wess
# Updating entry 1215
# Calling API for name:
# first_name: kenneth	middle_name: alan	                   last_name: johnson	full_name: kenneth alan johnson
# Updating entry 1216
# Calling API for name:
# first_name: kenneth	middle_name: crossley	                   last_name: mcwalter	full_name: kenneth crossley mcwalter
# Updating entry 1219
# Calling API for name:
# first_name: klaus	middle_name: dieter	                   last_name: seemann	full_name: klaus dieter seemann
# Updating entry 1226
# Calling API for name:
# first_name: leonid	middle_name: ivanovich	                   last_name: korochkin	full_name: leonid ivanovich korochkin
# Updating entry 1227
# Calling API for name:
# first_name: leslie	middle_name: alan	                   last_name: shepard	full_name: leslie alan shepard
# Updating entry 1228
# Calling API for name:
# first_name: abraham	middle_name: louis	                   last_name: levin	full_name: abraham louis levin
# Updating entry 1232
# Calling API for name:
# first_name: ludwig	middle_name: karl	                   last_name: ratschiller	full_name: ludwig karl ratschiller
# Updating entry 1234
# Calling API for name:
# first_name: luigi	middle_name: guglielmo	                   last_name: moncada	full_name: luigi guglielmo moncada
# Updating entry 1238
# Calling API for name:
# first_name: malcolm	middle_name: alexander	                   last_name: ramsay	full_name: malcolm alexander ramsay
# Updating entry 1241
# Calling API for name:
# first_name: mary	middle_name: kathleen	                   last_name: marchant	full_name: mary kathleen marchant
# Updating entry 1243
# Calling API for name:
# first_name: richard	middle_name: wesley	                   last_name: telinde	full_name: richard wesley telinde
# Updating entry 1248
# Calling API for name:
# first_name: merrick	middle_name: edward	                   last_name: abrahams	full_name: merrick edward peltier abrahams
# Updating entry 1250
# Calling API for name:
# first_name: michael	middle_name: dudley	                   last_name: sturge	full_name: michael dudley sturge
# Updating entry 1256
# Calling API for name:
# first_name: nadezhda	middle_name: borisovna	                   last_name: bolotina	full_name: nadezhda borisovna bolotina
# Updating entry 1257
# Calling API for name:
# first_name: nicholas	middle_name: john	                   last_name: mills	full_name: nicholas john mills
# Updating entry 1258
# Calling API for name:
# first_name: nikolai	middle_name: alekseevich	                   last_name: chernoplekov	full_name: nikolai alekseevich chernoplekov
# Updating entry 1263
# Calling API for name:
# first_name: james	middle_name: wardrop	                   last_name: telford	full_name: james wardrop telford
# Updating entry 1272
# Calling API for name:
# first_name: paul	middle_name: walter	                   last_name: hartl	full_name: paul walter hartl
# Updating entry 1274
# Calling API for name:
# first_name: christopher	middle_name: kevin	                   last_name: boyle	full_name: christopher kevin boyle
# Updating entry 1275
# Calling API for name:
# first_name: william	middle_name: alfred	                   last_name: read	full_name: william alfred read
# Updating entry 1278
# Calling API for name:
# first_name: leon	middle_name: anthony	                   last_name: fennessy	full_name: leon anthony fennessy
# Updating entry 1281
# Calling API for name:
# first_name: rosalind	middle_name: hauk	                   last_name: kornfeld	full_name: rosalind hauk kornfeld
# Updating entry 1287
# Calling API for name:
# first_name: friedrich	middle_name: wilhelm	                   last_name: ahnefeld	full_name: friedrich wilhelm ahnefeld
# Updating entry 1292
# Calling API for name:
# first_name: oleg	middle_name: aleksandrovich	                   last_name: petrii	full_name: oleg aleksandrovich petrii
# Updating entry 1293
# Calling API for name:
# first_name: oscar	middle_name: davis	                   last_name: ratnoff	full_name: oscar davis ratnoff
# Updating entry 1297
# Calling API for name:
# first_name: otto	middle_name: wilhelm	                   last_name: madelung	full_name: otto wilhelm madelung
# Updating entry 1301
# Calling API for name:
# first_name: paul	middle_name: dudley	                   last_name: white	full_name: paul dudley white
# Updating entry 1302
# Calling API for name:
# first_name: pauline	middle_name: atherton	                   last_name: cochrane	full_name: pauline atherton cochrane
# Updating entry 1303
# Calling API for name:
# first_name: pax	middle_name: allan	                   last_name: chingawale	full_name: pax allan chingawale
# Updating entry 1305
# Calling API for name:
# first_name: claude	middle_name: michel	                   last_name: cluny	full_name: claude michel cluny
# Updating entry 1306
# Calling API for name:
# first_name: peter	middle_name: clay	                   last_name: eklund	full_name: peter clay eklund
# Updating entry 1307
# Calling API for name:
# first_name: peter	middle_name: edgerly	                   last_name: firchow	full_name: peter edgerly firchow
# Updating entry 1308
# Calling API for name:
# first_name: petrovsky	middle_name: arthur	                   last_name: vladimirovich	full_name: petrovsky arthur vladimirovich
# Updating entry 1309
# Calling API for name:
# first_name: philip	middle_name: john	                   last_name: kingston	full_name: philip john kingston
# Updating entry 1311
# Calling API for name:
# first_name: phyllis	middle_name: louisa	                   last_name: botha	full_name: phyllis louisa botha
# Updating entry 1312
# Calling API for name:
# first_name: pieter	middle_name: joost	                   last_name: goedhart	full_name: pieter joost goedhart
# Updating entry 1314
# Calling API for name:
# first_name: ignaz	middle_name: joseph	                   last_name: pleyel	full_name: ignaz joseph pleyel
# Updating entry 1325
# Calling API for name:
# first_name: phillip	middle_name: vallentine	                   last_name: tobias	full_name: phillip vallentine tobias
# Updating entry 1331
# Calling API for name:
# first_name: michael	middle_name: alan	                   last_name: cooper	full_name: michael alan ralph cooper
# Updating entry 1363
# Calling API for name:
# first_name: richard	middle_name: charles	                   last_name: pfister	full_name: richard charles pfister
# Updating entry 1364
# Calling API for name:
# first_name: richard	middle_name: lee	                   last_name: hester	full_name: richard lee hester
# Updating entry 1366
# Calling API for name:
# first_name: richard	middle_name: penrose	                   last_name: schmidt	full_name: richard penrose schmidt
# Updating entry 1367
# Calling API for name:
# first_name: richard	middle_name: starr	                   last_name: ross	full_name: richard starr ross
# Updating entry 1368
# Calling API for name:
# first_name: richard	middle_name: thomas	                   last_name: robiscoe	full_name: richard thomas robiscoe
# Updating entry 1369
# Calling API for name:
# first_name: thomas	middle_name: jefferson	                   last_name: jarrell	full_name: thomas jefferson jarrell
# Updating entry 1371
# Calling API for name:
# first_name: roselyn	middle_name: adele	                   last_name: walker	full_name: roselyn adele walker
# Updating entry 1372
# Calling API for name:
# first_name: ross	middle_name: galbraith	                   last_name: mitchell	full_name: ross galbraith mitchell
# Updating entry 1378
# Calling API for name:
# first_name: samuel	middle_name: roger	                   last_name: rimmer	full_name: samuel roger rimmer
# Updating entry 1379
# Calling API for name:
# first_name: mary	middle_name: jo	                   last_name: nye	full_name: mary jo nye
# Updating entry 1382
# Calling API for name:
# first_name: sergei	middle_name: anatolyevich	                   last_name: starostin	full_name: sergei anatolyevich starostin
# Updating entry 1383
# Calling API for name:
# first_name: sergei	middle_name: petrovich	                   last_name: denisov	full_name: sergei petrovich denisov
# Updating entry 1398
# Calling API for name:
# first_name: paul	middle_name: peter	                   last_name: rosen	full_name: paul peter rosen
# Updating entry 1404
# Calling API for name:
# first_name: guida	middle_name: mary	                   last_name: crowley	full_name: guida mary crowley
# Updating entry 1406
# Calling API for name:
# first_name: thomas	middle_name: joseph	                   last_name: delaney	full_name: thomas joseph delaney
# Updating entry 1407
# Calling API for name:
# first_name: thomas	middle_name: vincent	                   last_name: santulli	full_name: thomas vincent santulli
# Updating entry 1416
# Calling API for name:
# first_name: umesh	middle_name: chandra	                   last_name: pati	full_name: umesh chandra pati
# Updating entry 1418
# Calling API for name:
# first_name: vasilii	middle_name: zakharovich	                   last_name: vlasov	full_name: vasilii zakharovich vlasov
# Updating entry 1419
# Calling API for name:
# first_name: viktor	middle_name: matveevich	                   last_name: bukhshtaber	full_name: viktor matveevich bukhshtaber
# Updating entry 1420
# Calling API for name:
# first_name: vladimir	middle_name: leonidovitch	                   last_name: doshchitsyn	full_name: vladimir leonidovitch doshchitsyn
# Updating entry 1421
# Calling API for name:
# first_name: vladimir	middle_name: mikhailovich	                   last_name: fridkin	full_name: vladimir mikhailovich fridkin
# Updating entry 1422
# Calling API for name:
# first_name: william	middle_name: daniel	                   last_name: sudia	full_name: william daniel sudia
# Updating entry 1423
# Calling API for name:
# first_name: walter	middle_name: thomas	                   last_name: morgan	full_name: walter thomas james morgan
# Updating entry 1424
# Calling API for name:
# first_name: william	middle_name: craig	                   last_name: reynolds	full_name: william craig reynolds
# Updating entry 1425
# Calling API for name:
# first_name: william	middle_name: glenn	                   last_name: sly	full_name: william glenn sly
# Updating entry 1426
# Calling API for name:
# first_name: william	middle_name: joseph	                   last_name: reals	full_name: william joseph reals
# Updating entry 1428
# Calling API for name:
# first_name: william	middle_name: sprott	                   last_name: pollitzer	full_name: william sprott pollitzer
# Updating entry 1431
# Calling API for name:
# first_name: yakov	middle_name: zalmanovich	                   last_name: tsypkin	full_name: yakov zalmanovich tsypkin
# Updating entry 1435
# Calling API for name:
# first_name: yury	middle_name: akhmetovich	                   last_name: aminov	full_name: yury akhmetovich aminov
# Updating entry 1436
# Calling API for name:
# first_name: zhores	middle_name: ivanovich	                   last_name: alferov	full_name: zhores ivanovich alferov
# Updating entry 1447
# Calling API for name:
# first_name: jane	middle_name: ruth	                   last_name: aceng	full_name: jane ruth aceng
# Updating entry 1466
# Calling API for name:
# first_name: lorraine	middle_name: niño	                   last_name: alexander	full_name: lorraine niño alexander
# Updating entry 1469
# Calling API for name:
# first_name: graziella	middle_name: badin	                   last_name: aliti	full_name: graziella badin aliti
# Updating entry 1485
# Calling API for name:
# first_name: johan	middle_name: hviid	                   last_name: andersen	full_name: johan hviid andersen
# Updating entry 1536
# Calling API for name:
# first_name: josé	middle_name: augusto	                   last_name: barreto-filho	full_name: josé augusto barreto-filho
# Updating entry 1614
# Calling API for name:
# first_name: kaare	middle_name: harald	                   last_name: bønaa	full_name: kaare harald bønaa
# Updating entry 1698
# Calling API for name:
# first_name: henry	middle_name: lik-yuen	                   last_name: chan	full_name: henry lik-yuen chan
# Updating entry 1702
# Calling API for name:
# first_name: kit	middle_name: yee	                   last_name: chan	full_name: kit yee chan
# Updating entry 1726
# Calling API for name:
# first_name: elaine	middle_name: w-t	                   last_name: chong	full_name: elaine w-t chong
# Updating entry 1728
# Calling API for name:
# first_name: mahbub	middle_name: elahi	                   last_name: chowdhury	full_name: mahbub elahi chowdhury
# Updating entry 1838
# Calling API for name:
# first_name: gian	middle_name: luca	                   last_name: di tanna	full_name: gian luca di tanna
# Updating entry 1842
# Calling API for name:
# first_name: binh	middle_name: an	                   last_name: diep	full_name: binh an diep
# Updating entry 2010
# Calling API for name:
# first_name: tara	middle_name: bridget	                   last_name: giblin	full_name: tara bridget giblin
# Updating entry 2090
# Calling API for name:
# first_name: chanita	middle_name: hughes	                   last_name: halbert	full_name: chanita hughes halbert
# Updating entry 2218
# Calling API for name:
# first_name: poul	middle_name: harboe	                   last_name: jacobsen	full_name: poul harboe jacobsen
# Updating entry 2235
# Calling API for name:
# first_name: sun	middle_name: ha	                   last_name: jee	full_name: sun ha jee
# Updating entry 2281
# Calling API for name:
# first_name: young	middle_name: ae	                   last_name: kang	full_name: young ae kang
# Updating entry 2282
# Calling API for name:
# first_name: jae	middle_name: hee	                   last_name: kang	full_name: jae hee kang
# Updating entry 2283
# Calling API for name:
# first_name: liew	middle_name: woei	                   last_name: kang	full_name: liew woei kang
# Updating entry 2317
# Calling API for name:
# first_name: mishal	middle_name: sameer	                   last_name: khan	full_name: mishal sameer khan
# Updating entry 2322
# Calling API for name:
# first_name: hae	middle_name: jin	                   last_name: kim	full_name: hae jin kim
# Updating entry 2379
# Calling API for name:
# first_name: geeta	middle_name: trilok	                   last_name: kumar	full_name: geeta trilok kumar
# Updating entry 2439
# Calling API for name:
# first_name: ka	middle_name: lau	                   last_name: leung	full_name: ka lau leung
# Updating entry 2489
# Calling API for name:
# first_name: yoon	middle_name: kong	                   last_name: loke	full_name: yoon kong loke
# Updating entry 2547
# Calling API for name:
# first_name: maría	middle_name: elena	                   last_name: martínez	full_name: maría elena martínez
# Updating entry 2571
# Calling API for name:
# first_name: mary	middle_name: mcgrae	                   last_name: mcdermott	full_name: mary mcgrae mcdermott
# Updating entry 2670
# Calling API for name:
# first_name: ann	middle_name: marie	                   last_name: navar-boggan	full_name: ann marie navar-boggan
# Updating entry 2691
# Calling API for name:
# first_name: linda	middle_name: olivia	                   last_name: nichols	full_name: linda olivia nichols
# Updating entry 2729
# Calling API for name:
# first_name: marcus	middle_name: eng	                   last_name: ong	full_name: marcus eng ong
# Updating entry 2731
# Calling API for name:
# first_name: jan	middle_name: jelrik	                   last_name: oosterheert	full_name: jan jelrik oosterheert
# Updating entry 2757
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: parienti	full_name: jean jacques parienti
# Updating entry 2786
# Calling API for name:
# first_name: john	middle_name: victor	                   last_name: peter	full_name: john victor peter
# Updating entry 2805
# Calling API for name:
# first_name: rafael	middle_name: zambelli	                   last_name: pinto	full_name: rafael zambelli pinto
# Updating entry 2830
# Calling API for name:
# first_name: adria	middle_name: tassy	                   last_name: prosser	full_name: adria tassy prosser
# Updating entry 2921
# Calling API for name:
# first_name: hanna	middle_name: bloomfield	                   last_name: rubins	full_name: hanna bloomfield rubins
# Updating entry 2925
# Calling API for name:
# first_name: luis	middle_name: miguel	                   last_name: ruilope	full_name: luis miguel ruilope
# Updating entry 2949
# Calling API for name:
# first_name: charles	middle_name: marc	                   last_name: samama	full_name: charles marc samama
# Updating entry 2965
# Calling API for name:
# first_name: elizabeth	middle_name: sumamo	                   last_name: schellenberg	full_name: elizabeth sumamo schellenberg
# Updating entry 3031
# Calling API for name:
# first_name: jacqueline	middle_name: baras	                   last_name: shreibati	full_name: jacqueline baras shreibati
# Updating entry 3055
# Calling API for name:
# first_name: håvard	middle_name: ove	                   last_name: skjerven	full_name: håvard ove skjerven
# Updating entry 3071
# Calling API for name:
# first_name: henrik	middle_name: toft	                   last_name: sørensen	full_name: henrik toft sørensen
# Updating entry 3085
# Calling API for name:
# first_name: philippe	middle_name: gabriel	                   last_name: steg	full_name: philippe gabriel steg
# Updating entry 3089
# Calling API for name:
# first_name: henry	middle_name: thomas	                   last_name: stelfox	full_name: henry thomas stelfox
# Updating entry 3147
# Calling API for name:
# first_name: milena	middle_name: gurgel	                   last_name: teles	full_name: milena gurgel teles
# Updating entry 3292
# Calling API for name:
# first_name: chi	middle_name: pang	                   last_name: wen	full_name: chi pang wen
# Updating entry 3313
# Calling API for name:
# first_name: renda	middle_name: soylemez	                   last_name: wiener	full_name: renda soylemez wiener
# Updating entry 3336
# Calling API for name:
# first_name: tien	middle_name: yin	                   last_name: wong	full_name: tien yin wong
# Updating entry 3362
# Calling API for name:
# first_name: kol	middle_name: jia	                   last_name: yong	full_name: kol jia yong
# Updating entry 3363
# Calling API for name:
# first_name: marianne	middle_name: ulcickas	                   last_name: yood	full_name: marianne ulcickas yood
# Updating entry 3389
# Calling API for name:
# first_name: ha	middle_name: lim	                   last_name: oh	full_name: ha lim oh
# Updating entry 3393
# Calling API for name:
# first_name: shiao	middle_name: tong	                   last_name: kong	full_name: shiao tong kong
# Updating entry 3397
# Calling API for name:
# first_name: moon	middle_name: jeong	                   last_name: chang	full_name: moon jeong chang
# Updating entry 3401
# Calling API for name:
# first_name: hae	middle_name: yun	                   last_name: nam	full_name: hae yun nam
# Updating entry 3417
# Calling API for name:
# first_name: ji	middle_name: in	                   last_name: kang	full_name: ji in kang
# Updating entry 3420
# Calling API for name:
# first_name: marize	middle_name: pereira	                   last_name: miagostovich	full_name: marize pereira miagostovich
# Updating entry 3425
# Calling API for name:
# first_name: sonay	middle_name: incesoy	                   last_name: ozdemir	full_name: sonay incesoy ozdemir
# Updating entry 3431
# Calling API for name:
# first_name: sy	middle_name: jye	                   last_name: leu	full_name: sy jye leu
# Updating entry 3446
# Calling API for name:
# first_name: nae	middle_name: choon	                   last_name: yoo	full_name: nae choon yoo
# Updating entry 3451
# Calling API for name:
# first_name: darvi	middle_name: de	                   last_name: andre	full_name: darvi de andre
# Updating entry 3453
# Calling API for name:
# first_name: dulcineia	middle_name: martins	                   last_name: de albuquerque	full_name: dulcineia martins de albuquerque
# Updating entry 3455
# Calling API for name:
# first_name: siaw	middle_name: lin	                   last_name: chan	full_name: siaw lin chan
# Updating entry 3457
# Calling API for name:
# first_name: jung	middle_name: seek	                   last_name: yang	full_name: jung seek yang
# Updating entry 3462
# Calling API for name:
# first_name: hae	middle_name: rang	                   last_name: chung	full_name: hae rang chung
# Updating entry 3471
# Calling API for name:
# first_name: youn	middle_name: ju	                   last_name: choi	full_name: youn ju choi
# Updating entry 3478
# Calling API for name:
# first_name: marilia	middle_name: germanos	                   last_name: castro	full_name: marilia germanos castro
# Updating entry 3485
# Calling API for name:
# first_name: seon	middle_name: kyoung	                   last_name: an	full_name: seon kyoung an
# Updating entry 3497
# Calling API for name:
# first_name: hacer	middle_name: kuzu	                   last_name: okur	full_name: hacer kuzu okur
# Updating entry 3505
# Calling API for name:
# first_name: se	middle_name: na	                   last_name: kim	full_name: se na kim
# Updating entry 3508
# Calling API for name:
# first_name: ji	middle_name: soon	                   last_name: kim	full_name: ji soon kim
# Updating entry 3519
# Calling API for name:
# first_name: maysa	middle_name: de	                   last_name: leite	full_name: maysa de leite
# Updating entry 3523
# Calling API for name:
# first_name: svava	middle_name: osk	                   last_name: jonsdottir	full_name: svava osk jonsdottir
# Updating entry 3530
# Calling API for name:
# first_name: duk	middle_name: yoon	                   last_name: kim	full_name: duk yoon kim
# Updating entry 3538
# Calling API for name:
# first_name: jung	middle_name: sug	                   last_name: lee	full_name: jung sug lee
# Updating entry 3540
# Calling API for name:
# first_name: elisangela	middle_name: franciscon	                   last_name: guimaro dias	full_name: elisangela franciscon guimaro dias
# Updating entry 3547
# Calling API for name:
# first_name: azizeh	middle_name: mitra	                   last_name: yousefi	full_name: azizeh mitra yousefi
# Updating entry 3553
# Calling API for name:
# first_name: roozbeh	middle_name: javad	                   last_name: kalbasi	full_name: roozbeh javad kalbasi
# Updating entry 3595
# Calling API for name:
# first_name: puay	middle_name: hoon	                   last_name: tan	full_name: puay hoon tan
# Updating entry 3598
# Calling API for name:
# first_name: ahter	middle_name: dilsad	                   last_name: sanlioglu	full_name: ahter dilsad sanlioglu
# Updating entry 3602
# Calling API for name:
# first_name: moy	middle_name: fong	                   last_name: chen	full_name: moy fong chen
# Updating entry 3606
# Calling API for name:
# first_name: renny	middle_name: kurnia	                   last_name: hadiaty	full_name: renny kurnia hadiaty
# Updating entry 3607
# Calling API for name:
# first_name: koon	middle_name: gee	                   last_name: neoh	full_name: koon gee neoh
# Updating entry 3610
# Calling API for name:
# first_name: yoon	middle_name: ju	                   last_name: song	full_name: yoon ju song
# Updating entry 3625
# Calling API for name:
# first_name: gulsen	middle_name: tukenmez	                   last_name: demirci	full_name: gulsen tukenmez demirci
# Updating entry 3634
# Calling API for name:
# first_name: kyoung	middle_name: hee	                   last_name: nam	full_name: kyoung hee nam
# Updating entry 3637
# Calling API for name:
# first_name: ju	middle_name: dong	                   last_name: lee	full_name: ju dong lee
# Updating entry 3647
# Calling API for name:
# first_name: kyu	middle_name: han	                   last_name: kim	full_name: kyu han kim
# Updating entry 3648
# Calling API for name:
# first_name: jhi	middle_name: joung	                   last_name: wang	full_name: jhi joung wang
# Updating entry 3674
# Calling API for name:
# first_name: beg	middle_name: hab	                   last_name: kim	full_name: beg hab kim
# Updating entry 3681
# Calling API for name:
# first_name: mou	middle_name: sheng	                   last_name: liu	full_name: mou sheng liu
# Updating entry 3687
# Calling API for name:
# first_name: jeong	middle_name: seop	                   last_name: sim	full_name: jeong seop sim
# Updating entry 3693
# Calling API for name:
# first_name: shyh	middle_name: yuan	                   last_name: lee	full_name: shyh yuan lee
# Updating entry 3699
# Calling API for name:
# first_name: ok	middle_name: keun	                   last_name: song	full_name: ok keun song
# Updating entry 3704
# Calling API for name:
# first_name: seung	middle_name: joo	                   last_name: kim	full_name: seung joo kim
# Updating entry 3719
# Calling API for name:
# first_name: mor	middle_name: mordechai	                   last_name: peretz	full_name: mor mordechai peretz
# Updating entry 3725
# Calling API for name:
# first_name: hyun	middle_name: kuk	                   last_name: park	full_name: hyun kuk park
# Updating entry 3755
# Calling API for name:
# first_name: seog	middle_name: joo	                   last_name: kim	full_name: seog joo kim
# Updating entry 3762
# Calling API for name:
# first_name: sameh	middle_name: saad	                   last_name: ali	full_name: sameh saad ali
# Updating entry 3770
# Calling API for name:
# first_name: cihan	middle_name: cem	                   last_name: gurbuz	full_name: cihan cem gurbuz
# Updating entry 3777
# Calling API for name:
# first_name: jorim	middle_name: sousa	                   last_name: das virgens filho	full_name: jorim sousa das virgens filho
# Updating entry 3782
# Calling API for name:
# first_name: hwan	middle_name: you	                   last_name: chang	full_name: hwan you chang
# Updating entry 3794
# Calling API for name:
# first_name: choon	middle_name: hua	                   last_name: thng	full_name: choon hua thng
# Updating entry 3795
# Calling API for name:
# first_name: woel	middle_name: kyu	                   last_name: ha	full_name: woel kyu ha
# Updating entry 3796
# Calling API for name:
# first_name: won	middle_name: tae	                   last_name: kwon	full_name: won tae kwon
# Updating entry 3799
# Calling API for name:
# first_name: ding	middle_name: ming	                   last_name: wang	full_name: ding ming wang
# Updating entry 3807
# Calling API for name:
# first_name: hang	middle_name: rae	                   last_name: kim	full_name: hang rae kim
# Updating entry 3818
# Calling API for name:
# first_name: shing	middle_name: shun	                   last_name: to	full_name: shing shun to
# Updating entry 3820
# Calling API for name:
# ...
# first_name: min	middle_name: hee	                   last_name: lee	full_name: min hee lee
# Updating entry 5188
# Calling API for name:
# first_name: ji	middle_name: hye	                   last_name: han	full_name: ji hye han
# Updating entry 5190
# Calling API for name:
# first_name: ling	middle_name: yueh	                   last_name: hu	full_name: ling yueh hu
# Updating entry 5197
# Calling API for name:
# first_name: soo	middle_name: kyong	                   last_name: choi	full_name: soo kyong choi
# Updating entry 5198
# Calling API for name:
# first_name: yeon	middle_name: gil	                   last_name: jung	full_name: yeon gil jung
# Updating entry 5201
# Calling API for name:
# first_name: li	middle_name: sha	                   last_name: an	full_name: li sha an
# Updating entry 5211
# Calling API for name:
# first_name: yu	middle_name: lin	                   last_name: lai	full_name: yu lin lai
# Updating entry 5216
# Calling API for name:
# first_name: sang	middle_name: woo	                   last_name: lee	full_name: sang woo lee
# Updating entry 5219
# Calling API for name:
# first_name: jose	middle_name: albertino	                   last_name: bendassoli	full_name: jose albertino bendassoli
# Updating entry 5226
# Calling API for name:
# first_name: gustavo	middle_name: ferreira	                   last_name: leonhardt	full_name: gustavo ferreira leonhardt
# Updating entry 5256
# Calling API for name:
# first_name: vicente	middle_name: paulo	                   last_name: campos	full_name: vicente paulo campos
# Updating entry 5307
# Calling API for name:
# first_name: ferhan	middle_name: sami	                   last_name: atalay	full_name: ferhan sami atalay
# Updating entry 5312
# Calling API for name:
# first_name: eung	middle_name: kwan	                   last_name: lee	full_name: eung kwan lee
# Updating entry 5317
# Calling API for name:
# first_name: guo	middle_name: liang	                   last_name: wang	full_name: guo liang wang
# Updating entry 5334
# Calling API for name:
# first_name: de	middle_name: yi	                   last_name: wang	full_name: de yi wang
# Updating entry 5340
# Calling API for name:
# first_name: yuan	middle_name: hao	                   last_name: liu	full_name: yuan hao liu
# Updating entry 5361
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: tardif	full_name: jean claude tardif
# Updating entry 5363
# Calling API for name:
# first_name: kwang	middle_name: ho	                   last_name: kim	full_name: kwang ho kim
# Updating entry 5364
# Calling API for name:
# first_name: yu	middle_name: jen	                   last_name: chen	full_name: yu jen chen
# Updating entry 5376
# Calling API for name:
# first_name: bibhas	middle_name: ranjan	                   last_name: majhi	full_name: bibhas ranjan majhi
# Updating entry 5377
# Calling API for name:
# first_name: george	middle_name: jiunruey	                   last_name: huang	full_name: george jiunruey huang
# Updating entry 5382
# Calling API for name:
# first_name: antonio	middle_name: macilio	                   last_name: pereira de lucenas	full_name: antonio macilio pereira de lucenas
# Updating entry 5385
# Calling API for name:
# first_name: shi	middle_name: wu	                   last_name: wen	full_name: shi wu wen
# Updating entry 5390
# Calling API for name:
# first_name: sergio	middle_name: gregorio	                   last_name: dasilva	full_name: sergio gregorio dasilva
# Updating entry 5396
# Calling API for name:
# first_name: mustafa	middle_name: serdar	                   last_name: genc	full_name: mustafa serdar genc
# Updating entry 5403
# Calling API for name:
# first_name: manuel	middle_name: pedro	                   last_name: salema fevereiro	full_name: manuel pedro salema fevereiro
# Updating entry 5408
# Calling API for name:
# first_name: adunias	middle_name: dos	                   last_name: teixeira	full_name: adunias dos teixeira
# Updating entry 5414
# Calling API for name:
# first_name: young	middle_name: chul	                   last_name: ghim (kim)	full_name: young chul ghim (kim)
# Updating entry 5422
# Calling API for name:
# first_name: mario	middle_name: marcello	                   last_name: miglietta	full_name: mario marcello miglietta
# Updating entry 5429
# Calling API for name:
# first_name: sung	middle_name: hwa	                   last_name: kim	full_name: sung hwa kim
# Updating entry 5448
# Calling API for name:
# first_name: ethan	middle_name: david	                   last_name: cohen	full_name: ethan david cohen
# Updating entry 5485
# Calling API for name:
# first_name: chul	middle_name: hoon	                   last_name: lee	full_name: chul hoon lee
# Updating entry 5501
# Calling API for name:
# first_name: hong	middle_name: fu	                   last_name: wang	full_name: hong fu wang
# Updating entry 5504
# Calling API for name:
# first_name: fabiano	middle_name: buss	                   last_name: cruz	full_name: fabiano buss cruz
# Updating entry 5525
# Calling API for name:
# first_name: gil	middle_name: ho	                   last_name: kim	full_name: gil ho kim
# Updating entry 5546
# Calling API for name:
# first_name: muhammad	middle_name: saeed	                   last_name: wagan	full_name: muhammad saeed wagan
# Updating entry 5552
# Calling API for name:
# first_name: jin	middle_name: tao	                   last_name: wang	full_name: jin tao wang
# Updating entry 5559
# Calling API for name:
# first_name: george	middle_name: davey	                   last_name: smith	full_name: george davey smith
# Updating entry 5577
# Calling API for name:
# first_name: chiu	middle_name: on	                   last_name: ng	full_name: chiu on ng
# Updating entry 5636
# Calling API for name:
# first_name: sang	middle_name: kyu	                   last_name: ye	full_name: sang kyu ye
# Updating entry 5650
# Calling API for name:
# first_name: sang	middle_name: won	                   last_name: yeo	full_name: sang won yeo
# Updating entry 5655
# Calling API for name:
# first_name: hamid	middle_name: reza	                   last_name: khavasi	full_name: hamid reza khavasi
# Updating entry 5677
# Calling API for name:
# first_name: yves	middle_name: andre	                   last_name: bureau	full_name: yves andre bureau
# Updating entry 5684
# Calling API for name:
# first_name: hasan	middle_name: tahsin	                   last_name: gozdas	full_name: hasan tahsin gozdas
# Updating entry 5701
# Calling API for name:
# first_name: wei	middle_name: dong	                   last_name: zhang	full_name: wei dong zhang
# Updating entry 5704
# Calling API for name:
# first_name: sang	middle_name: hyun	                   last_name: oh	full_name: sang hyun oh
# Updating entry 5710
# Calling API for name:
# first_name: li	middle_name: ming	                   last_name: su	full_name: li ming su
# Updating entry 5711
# Calling API for name:
# first_name: hans	middle_name: joachim	                   last_name: ruscheweyh	full_name: hans joachim ruscheweyh
# Updating entry 5715
# Calling API for name:
# first_name: david	middle_name: henry	                   last_name: jimmy	full_name: david henry jimmy
# Updating entry 5719
# Calling API for name:
# first_name: xue	middle_name: jun	                   last_name: liu	full_name: xue jun liu
# Updating entry 5721
# Calling API for name:
# first_name: ravinder	middle_name: kumar	                   last_name: kohli	full_name: ravinder kumar kohli
# Updating entry 5728
# Calling API for name:
# first_name: ken	middle_name: ichi	                   last_name: fujita	full_name: ken ichi fujita
# Updating entry 5755
# Calling API for name:
# first_name: geon	middle_name: ho	                   last_name: choe	full_name: geon ho choe
# Updating entry 5756
# Calling API for name:
# first_name: young	middle_name: tae	                   last_name: kim	full_name: young tae kim
# Updating entry 5757
# Calling API for name:
# first_name: jose	middle_name: carlos	                   last_name: netto-ferreira	full_name: jose carlos netto-ferreira
# Updating entry 5758
# Calling API for name:
# first_name: noedir	middle_name: antonio	                   last_name: groppo stolf	full_name: noedir antonio groppo stolf
# Updating entry 5771
# Calling API for name:
# first_name: seong	middle_name: heum	                   last_name: park	full_name: seong heum park
# Updating entry 5772
# Calling API for name:
# first_name: wei	middle_name: liang	                   last_name: sun	full_name: wei liang sun
# Updating entry 5795
# Calling API for name:
# first_name: hyo	middle_name: jin	                   last_name: ahn	full_name: hyo jin ahn
# Updating entry 5804
# Calling API for name:
# first_name: fernando	middle_name: augusto	                   last_name: barreiros	full_name: fernando augusto barreiros
# Updating entry 5805
# Calling API for name:
# first_name: eric	middle_name: chieh	                   last_name: chou	full_name: eric chieh chou
# Updating entry 5812
# Calling API for name:
# first_name: jong	middle_name: hu	                   last_name: park	full_name: jong hu park
# Updating entry 5813
# Calling API for name:
# first_name: jin	middle_name: ho	                   last_name: choe	full_name: jin ho choe
# Updating entry 5815
# Calling API for name:
# first_name: hassan	middle_name: mohamed	                   last_name: elsangedy	full_name: hassan mohamed elsangedy
# Updating entry 5841
# Calling API for name:
# first_name: woo	middle_name: ram	                   last_name: lee	full_name: woo ram lee
# Updating entry 5842
# Calling API for name:
# first_name: kyu	middle_name: sung	                   last_name: lee	full_name: kyu sung lee
# Updating entry 5843
# Calling API for name:
# first_name: tulio	middle_name: machado	                   last_name: fumian	full_name: tulio machado fumian
# Updating entry 5845
# Calling API for name:
# first_name: kai	middle_name: hang	                   last_name: yiu	full_name: kai hang yiu
# Updating entry 5847
# Calling API for name:
# first_name: deusdedit	middle_name: cortez	                   last_name: silva neto	full_name: deusdedit cortez silva neto
# Updating entry 5850
# Calling API for name:
# first_name: shi	middle_name: kai	                   last_name: yan	full_name: shi kai yan
# Updating entry 5857
# Calling API for name:
# first_name: sayed	middle_name: hossein	                   last_name: banitaba	full_name: sayed hossein banitaba
# Updating entry 5865
# Calling API for name:
# first_name: yu	middle_name: chen	                   last_name: yang	full_name: yu chen yang
# Updating entry 5866
# Calling API for name:
# first_name: kwon	middle_name: il	                   last_name: na	full_name: kwon il na
# Updating entry 5867
# Calling API for name:
# first_name: emanuel	middle_name: joaquim	                   last_name: victoria monteiro oliveira	full_name: emanuel joaquim victoria monteiro oliveira
# Updating entry 5871
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: chaumeil	full_name: jean claude chaumeil
# Updating entry 5873
# Calling API for name:
# first_name: wan	middle_name: chen	                   last_name: huang	full_name: wan chen huang
# Updating entry 5878
# Calling API for name:
# first_name: hye	middle_name: young	                   last_name: kim	full_name: hye young kim
# Updating entry 5885
# Calling API for name:
# first_name: jian	middle_name: jun	                   last_name: fu	full_name: jian jun fu
# Updating entry 5893
# Calling API for name:
# first_name: luis	middle_name: alberto	                   last_name: oliveira dallan	full_name: luis alberto oliveira dallan
# Updating entry 5894
# Calling API for name:
# first_name: gui	middle_name: xia	                   last_name: lu	full_name: gui xia lu
# Updating entry 5895
# Calling API for name:
# first_name: abu	middle_name: james	                   last_name: sundufu	full_name: abu james sundufu
# Updating entry 5905
# Calling API for name:
# first_name: quan	middle_name: sheng	                   last_name: wang	full_name: quan sheng wang
# Updating entry 5908
# Calling API for name:
# first_name: fabio	middle_name: fernando	                   last_name: de araujo	full_name: fabio fernando de araujo
# Updating entry 5918
# Calling API for name:
# first_name: manas	middle_name: ranjan	                   last_name: pattanayak	full_name: manas ranjan pattanayak
# Updating entry 5919
# Calling API for name:
# first_name: flavio	middle_name: pimenta	                   last_name: de figueiredo	full_name: flavio pimenta de figueiredo
# Updating entry 5936
# Calling API for name:
# first_name: young	middle_name: mo	                   last_name: koo	full_name: young mo koo
# Updating entry 5937
# Calling API for name:
# first_name: long	middle_name: jiang	                   last_name: zhang	full_name: long jiang zhang
# Updating entry 5945
# Calling API for name:
# first_name: kai	middle_name: ming	                   last_name: you	full_name: kai ming you
# Updating entry 5946
# Calling API for name:
# first_name: zhi	middle_name: hui	                   last_name: xu	full_name: zhi hui xu
# Updating entry 5947
# Calling API for name:
# first_name: kuo	middle_name: hung	                   last_name: huang	full_name: kuo hung huang
# Updating entry 5948
# Calling API for name:
# first_name: costin	middle_name: sorin	                   last_name: bildea	full_name: costin sorin bildea
# Updating entry 5950
# Calling API for name:
# first_name: el	middle_name: hassan	                   last_name: hamdani	full_name: el hassan hamdani
# Updating entry 5958
# Calling API for name:
# first_name: acaio	middle_name: zuniga	                   last_name: leite	full_name: acaio zuniga leite
# Updating entry 5959
# Calling API for name:
# first_name: chien	middle_name: ping	                   last_name: chiang	full_name: chien ping chiang
# Updating entry 5967
# Calling API for name:
# first_name: ji	middle_name: heon	                   last_name: park	full_name: ji heon park
# Updating entry 5980
# Calling API for name:
# first_name: leonardo	middle_name: henrique	                   last_name: gomes	full_name: leonardo henrique gomes
# Updating entry 5991
# Calling API for name:
# first_name: ill	middle_name: min	                   last_name: chung	full_name: ill min chung
# Updating entry 5993
# Calling API for name:
# first_name: seung	middle_name: hoon	                   last_name: lee	full_name: seung hoon lee
# Updating entry 5994
# Calling API for name:
# first_name: xiao	middle_name: hua	                   last_name: yuan	full_name: xiao hua yuan
# Updating entry 5998
# Calling API for name:
# first_name: hong	middle_name: yan	                   last_name: lu	full_name: hong yan lu
# Updating entry 6000
# Calling API for name:
# first_name: hao	middle_name: chieh	                   last_name: hsieh	full_name: hao chieh hsieh
# Updating entry 6011
# Calling API for name:
# first_name: sung	middle_name: soo	                   last_name: park	full_name: sung soo park
# Updating entry 6013
# Calling API for name:
# first_name: zheng	middle_name: de	                   last_name: deng	full_name: zheng de deng
# Updating entry 6015
# Calling API for name:
# first_name: cun	middle_name: gang	                   last_name: fan	full_name: cun gang fan
# Updating entry 6016
# Calling API for name:
# first_name: shi	middle_name: yong	                   last_name: fan	full_name: shi yong fan
# Updating entry 6033
# Calling API for name:
# first_name: guang	middle_name: xi	                   last_name: xing	full_name: guang xi xing
# Updating entry 6035
# Calling API for name:
# first_name: pedro	middle_name: luis	                   last_name: da costa aguiar alves	full_name: pedro luis da costa aguiar alves
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-7175e1ae89da> in <module>()
# ----> 1 evaluatorNAF.update_selected_records(to_update_indices)
#
# /Users/lucsan/Work/genderbias/name_gender_inference/evaluator.py in update_selected_records(self, indices)
#     198             api_resp = self._process_row_for_api_call(row)
#     199             api_resp = {'api_{}'.format(k): v for (k,v) in api_resp.items()}
# --> 200             api_resp['gender_infered'] = self.gender_response_mapping[api_resp['api_gender']]
#     201             for (k, v) in api_resp.items():
#     202                 self.test_data.loc[ind, k] = v
#
# KeyError: 'INDETERMINABLE'

# %% [markdown]
# The code couldn't handle the 'INDETERMINABLE' key. Let's fix it manually and commit a patch in evaluators.py.

# %%
evaluatorNAF.test_data[(evaluatorNAF.test_data.index.isin(list(to_update_indices))) \
                       & (evaluatorNAF.test_data.full_name=='pedro luis da costa aguiar alves')]
# Out:
#      first_name middle_name              last_name  \
# 6035      pedro        luis  da costa aguiar alves
#
#                              full_name gender  origin  api_confidence  \
# 6035  pedro luis da costa aguiar alves      u  nature             1.0
#
#           api_gender api_maleProportion  gender_infered
# 6035  INDETERMINABLE                     INDETERMINABLE

# %%
evaluatorNAF.test_data.loc[6035, 'gender_infered'] = 'u'

# %%
to_update_remaining_indices = [ind for ind in to_update_indices if ind>6035]
len(to_update_remaining_indices)
# Out:
# 297

# %%
evaluatorNAF.update_selected_records(to_update_remaining_indices)
# Out:
# Updating entry 6044
# Calling API for name:
# first_name: jose	middle_name: teixeira	                   last_name: de seixas filho	full_name: jose teixeira de seixas filho
# Updating entry 6051
# Calling API for name:
# first_name: beom	middle_name: jin	                   last_name: lee	full_name: beom jin lee
# Updating entry 6052
# Calling API for name:
# first_name: anderson	middle_name: de	                   last_name: barbosa	full_name: anderson de barbosa
# Updating entry 6058
# Calling API for name:
# first_name: min	middle_name: ho	                   last_name: jang	full_name: min ho jang
# Updating entry 6061
# Calling API for name:
# first_name: jia	middle_name: ming	                   last_name: li	full_name: jia ming li
# Updating entry 6067
# Calling API for name:
# first_name: zhi	middle_name: bing	                   last_name: zheng	full_name: zhi bing zheng
# Updating entry 6068
# Calling API for name:
# first_name: chul	middle_name: won	                   last_name: park	full_name: chul won park
# Updating entry 6072
# Calling API for name:
# first_name: lon	middle_name: yen	                   last_name: tsao	full_name: lon yen tsao
# Updating entry 6085
# Calling API for name:
# first_name: jin	middle_name: chun	                   last_name: kim	full_name: jin chun kim
# Updating entry 6087
# Calling API for name:
# first_name: jung	middle_name: hyun	                   last_name: kim	full_name: jung hyun kim
# Updating entry 6094
# Calling API for name:
# first_name: cristiano	middle_name: ragagnin	                   last_name: de menezes	full_name: cristiano ragagnin de menezes
# Updating entry 6105
# Calling API for name:
# first_name: wei	middle_name: ming	                   last_name: wang	full_name: wei ming wang
# Updating entry 6106
# Calling API for name:
# first_name: rolf	middle_name: juergen	                   last_name: schwarz	full_name: rolf juergen schwarz
# Updating entry 6116
# Calling API for name:
# first_name: shiang	middle_name: huei	                   last_name: jiang	full_name: shiang huei jiang
# Updating entry 6119
# Calling API for name:
# first_name: ming	middle_name: ming	                   last_name: guo	full_name: ming ming guo
# Updating entry 6121
# Calling API for name:
# first_name: guo	middle_name: ping	                   last_name: han	full_name: guo ping han
# Updating entry 6122
# Calling API for name:
# first_name: chi	middle_name: ming	                   last_name: hu	full_name: chi ming hu
# Updating entry 6128
# Calling API for name:
# first_name: rong	middle_name: keng	                   last_name: yap	full_name: rong keng yap
# Updating entry 6130
# Calling API for name:
# first_name: chun	middle_name: hung	                   last_name: lai	full_name: chun hung lai
# Updating entry 6137
# Calling API for name:
# first_name: dong	middle_name: hyuk	                   last_name: shin	full_name: dong hyuk shin
# Updating entry 6138
# Calling API for name:
# first_name: hong	middle_name: ru	                   last_name: dong	full_name: hong ru dong
# Updating entry 6142
# Calling API for name:
# first_name: chien	middle_name: hung	                   last_name: yeh	full_name: chien hung yeh
# Updating entry 6144
# Calling API for name:
# first_name: jae	middle_name: keun	                   last_name: kim	full_name: jae keun kim
# Updating entry 6145
# Calling API for name:
# first_name: chang	middle_name: whan	                   last_name: won	full_name: chang whan won
# Updating entry 6150
# Calling API for name:
# first_name: britt	middle_name: maria	                   last_name: beckmann	full_name: britt maria beckmann
# Updating entry 6158
# Calling API for name:
# first_name: jie	middle_name: jin	                   last_name: wang	full_name: jie jin wang
# Updating entry 6173
# Calling API for name:
# first_name: shashi	middle_name: prabha	                   last_name: dubey	full_name: shashi prabha dubey
# Updating entry 6177
# Calling API for name:
# first_name: youn	middle_name: kyung	                   last_name: lim	full_name: youn kyung lim
# Updating entry 6179
# Calling API for name:
# first_name: jin	middle_name: sook	                   last_name: yoon	full_name: jin sook yoon
# Updating entry 6184
# Calling API for name:
# first_name: lee	middle_name: mei	                   last_name: yap	full_name: lee mei yap
# Updating entry 6199
# Calling API for name:
# first_name: kim	middle_name: phuong	                   last_name: vu	full_name: kim phuong vu
# Updating entry 6200
# Calling API for name:
# first_name: sri	middle_name: devi	                   last_name: narasimhan	full_name: sri devi narasimhan
# Updating entry 6203
# Calling API for name:
# first_name: cong	middle_name: xiao	                   last_name: wang	full_name: cong xiao wang
# Updating entry 6204
# Calling API for name:
# first_name: chang	middle_name: hyun	                   last_name: kim	full_name: chang hyun kim
# Updating entry 6211
# Calling API for name:
# first_name: rejane	middle_name: mansur	                   last_name: nogueira	full_name: rejane mansur nogueira
# Updating entry 6216
# Calling API for name:
# first_name: youn	middle_name: soo	                   last_name: kim	full_name: youn soo kim
# Updating entry 6220
# Calling API for name:
# first_name: taciana	middle_name: marco	                   last_name: ferraz caneppele	full_name: taciana marco ferraz caneppele
# Updating entry 6231
# Calling API for name:
# first_name: kim	middle_name: butts	                   last_name: pauly	full_name: kim butts pauly
# Updating entry 6243
# Calling API for name:
# first_name: chris	middle_name: brown	                   last_name: mahoney	full_name: chris brown mahoney
# Updating entry 6245
# Calling API for name:
# first_name: antonia	middle_name: maria	                   last_name: das gracas lopes cito	full_name: antonia maria das gracas lopes cito
# Updating entry 6249
# Calling API for name:
# first_name: jung	middle_name: eun	                   last_name: lee	full_name: jung eun lee
# Updating entry 6257
# Calling API for name:
# first_name: young	middle_name: pil	                   last_name: park	full_name: young pil park
# Updating entry 6259
# Calling API for name:
# first_name: young	middle_name: bum	                   last_name: kim	full_name: young bum kim
# Updating entry 6260
# Calling API for name:
# first_name: jae	middle_name: woong	                   last_name: hwang	full_name: jae woong hwang
# Updating entry 6262
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: vandeweerd	full_name: jean michel vandeweerd
# Updating entry 6264
# Calling API for name:
# first_name: jin	middle_name: hee	                   last_name: woo	full_name: jin hee woo
# Updating entry 6265
# Calling API for name:
# first_name: young	middle_name: han	                   last_name: song	full_name: young han song
# Updating entry 6271
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: marty	full_name: jean louis marty
# Updating entry 6272
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: dognon	full_name: jean pierre dognon
# Updating entry 6273
# Calling API for name:
# first_name: jan	middle_name: ove	                   last_name: ebbestad	full_name: jan ove ebbestad
# Updating entry 6275
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: saudubray	full_name: jean marie saudubray
# Updating entry 6277
# Calling API for name:
# first_name: su	middle_name: young	                   last_name: kim	full_name: su young kim
# Updating entry 6285
# Calling API for name:
# first_name: chi	middle_name: sing	                   last_name: lam	full_name: chi sing lam
# Updating entry 6291
# Calling API for name:
# first_name: chang	middle_name: geun	                   last_name: song	full_name: chang geun song
# Updating entry 6292
# Calling API for name:
# first_name: jan	middle_name: rouke	                   last_name: kuipers	full_name: jan rouke kuipers
# Updating entry 6294
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: diaz	full_name: jean jacques diaz
# Updating entry 6296
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: allegret	full_name: jean pierre allegret
# Updating entry 6300
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: coville	full_name: jean luc coville
# Updating entry 6302
# Calling API for name:
# first_name: pu	middle_name: hong	                   last_name: zhang	full_name: pu hong zhang
# Updating entry 6307
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: merlin	full_name: jean louis merlin
# Updating entry 6311
# Calling API for name:
# first_name: jan	middle_name: erik	                   last_name: fosseidengen	full_name: jan erik fosseidengen
# Updating entry 6313
# Calling API for name:
# first_name: jean	middle_name: patrice	                   last_name: robin	full_name: jean patrice robin
# Updating entry 6314
# Calling API for name:
# first_name: hsin	middle_name: jen	                   last_name: tsai	full_name: hsin jen tsai
# Updating entry 6318
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: brankart	full_name: jean michel brankart
# Updating entry 6324
# Calling API for name:
# first_name: jan	middle_name: haug	                   last_name: anonsen	full_name: jan haug anonsen
# Updating entry 6330
# Calling API for name:
# first_name: chi	middle_name: tim	                   last_name: ng	full_name: chi tim ng
# Updating entry 6336
# Calling API for name:
# first_name: chang	middle_name: young	                   last_name: jang	full_name: chang young jang
# Updating entry 6340
# Calling API for name:
# first_name: jean	middle_name: noel	                   last_name: roux	full_name: jean noel roux
# Updating entry 6341
# Calling API for name:
# first_name: jan	middle_name: hakan	                   last_name: jansson	full_name: jan hakan jansson
# Updating entry 6342
# Calling API for name:
# first_name: jean	middle_name: francos	                   last_name: dartigues	full_name: jean francos dartigues
# Updating entry 6344
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: goujon	full_name: jean michel goujon
# Updating entry 6345
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: saiter	full_name: jean marc saiter
# Updating entry 6352
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: gallo	full_name: jean marc gallo
# Updating entry 6356
# Calling API for name:
# first_name: jean	middle_name: baptiste	                   last_name: sanchez	full_name: jean baptiste sanchez
# Updating entry 6359
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: robin	full_name: jean jacques robin
# Updating entry 6365
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: despres	full_name: jean pierre despres
# Updating entry 6372
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: morel	full_name: jean louis morel
# Updating entry 6374
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: routy	full_name: jean pierre routy
# Updating entry 6380
# Calling API for name:
# first_name: ali	middle_name: esref	                   last_name: mueezzinoglu	full_name: ali esref mueezzinoglu
# Updating entry 6389
# Calling API for name:
# first_name: yong	middle_name: tark	                   last_name: jeon	full_name: yong tark jeon
# Updating entry 6390
# Calling API for name:
# first_name: young	middle_name: tae	                   last_name: chang	full_name: young tae chang
# Updating entry 6395
# Calling API for name:
# first_name: ki	middle_name: chang	                   last_name: keum	full_name: ki chang keum
# Updating entry 6396
# Calling API for name:
# first_name: jean	middle_name: philippe	                   last_name: pin	full_name: jean philippe pin
# Updating entry 6399
# Calling API for name:
# first_name: jan	middle_name: erik	                   last_name: svensson	full_name: jan erik svensson
# Updating entry 6402
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: kraus	full_name: jean louis kraus
# Updating entry 6407
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: deschanvres	full_name: jean luc deschanvres
# Updating entry 6408
# Calling API for name:
# first_name: jean	middle_name: leon	                   last_name: thomas	full_name: jean leon thomas
# Updating entry 6410
# Calling API for name:
# first_name: shun	middle_name: lien	                   last_name: chuang	full_name: shun lien chuang
# Updating entry 6411
# Calling API for name:
# first_name: jean	middle_name: daniel	                   last_name: fekete	full_name: jean daniel fekete
# Updating entry 6412
# Calling API for name:
# first_name: chi	middle_name: wing	                   last_name: fu	full_name: chi wing fu
# Updating entry 6413
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: marier	full_name: jean francois marier
# Updating entry 6418
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: clement	full_name: jean pierre clement
# Updating entry 6421
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: mercier	full_name: jean francois mercier
# Updating entry 6425
# Calling API for name:
# first_name: hong	middle_name: kee	                   last_name: kim	full_name: hong kee kim
# Updating entry 6426
# Calling API for name:
# first_name: young	middle_name: jo	                   last_name: kim	full_name: young jo kim
# Updating entry 6428
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: tadie	full_name: jean marc tadie
# Updating entry 6431
# Calling API for name:
# first_name: jan	middle_name: hendrik	                   last_name: hooijberg	full_name: jan hendrik hooijberg
# Updating entry 6432
# Calling API for name:
# first_name: jan	middle_name: ingvar	                   last_name: jonsson	full_name: jan ingvar jonsson
# Updating entry 6444
# Calling API for name:
# first_name: young	middle_name: don	                   last_name: choi	full_name: young don choi
# Updating entry 6445
# Calling API for name:
# first_name: jean	middle_name: baptiste	                   last_name: michel	full_name: jean baptiste michel
# Updating entry 6449
# Calling API for name:
# first_name: hae	middle_name: ryong	                   last_name: song	full_name: hae ryong song
# Updating entry 6475
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: ploteau	full_name: jean pierre ploteau
# Updating entry 6476
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: besson	full_name: jean luc besson
# Updating entry 6479
# Calling API for name:
# first_name: young	middle_name: tack	                   last_name: lee	full_name: young tack lee
# Updating entry 6481
# Calling API for name:
# first_name: jean	middle_name: philippe	                   last_name: attane	full_name: jean philippe attane
# Updating entry 6492
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: frayret	full_name: jean marc frayret
# Updating entry 6494
# Calling API for name:
# first_name: jaime	middle_name: vilela	                   last_name: de resende	full_name: jaime vilela de resende
# Updating entry 6498
# Calling API for name:
# first_name: chong	middle_name: tin	                   last_name: tan	full_name: chong tin tan
# Updating entry 6500
# Calling API for name:
# first_name: jenn	middle_name: ren	                   last_name: hsiao	full_name: jenn ren hsiao
# Updating entry 6504
# Calling API for name:
# first_name: adrian	middle_name: mihai	                   last_name: ionescu	full_name: adrian mihai ionescu
# Updating entry 6506
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: francois	full_name: jean marie francois
# Updating entry 6508
# Calling API for name:
# first_name: chung	middle_name: yee	                   last_name: lee	full_name: chung yee lee
# Updating entry 6511
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: cornet	full_name: jean francois cornet
# Updating entry 6517
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: lareyre	full_name: jean jacques lareyre
# Updating entry 6519
# Calling API for name:
# first_name: jan	middle_name: peter	                   last_name: embs	full_name: jan peter embs
# Updating entry 6522
# Calling API for name:
# first_name: chung	middle_name: ming	                   last_name: leung	full_name: chung ming leung
# Updating entry 6527
# Calling API for name:
# first_name: ji	middle_name: won	                   last_name: yang	full_name: ji won yang
# Updating entry 6529
# Calling API for name:
# first_name: jan	middle_name: even	                   last_name: nilsen	full_name: jan even nilsen
# Updating entry 6530
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: bonnemain	full_name: jean louis bonnemain
# Updating entry 6531
# Calling API for name:
# first_name: jenn	middle_name: tai	                   last_name: liang	full_name: jenn tai liang
# Updating entry 6535
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: delroisse	full_name: jean marc delroisse
# Updating entry 6536
# Calling API for name:
# first_name: dar	middle_name: ren	                   last_name: ji	full_name: dar ren ji
# Updating entry 6537
# Calling API for name:
# first_name: jan	middle_name: christian	                   last_name: habel	full_name: jan christian habel
# Updating entry 6541
# Calling API for name:
# first_name: chang	middle_name: hyok	                   last_name: choi	full_name: chang hyok choi
# Updating entry 6542
# Calling API for name:
# first_name: man	middle_name: kit	                   last_name: leung	full_name: man kit leung
# Updating entry 6544
# Calling API for name:
# first_name: jaime	middle_name: wilson	                   last_name: vargas de mello	full_name: jaime wilson vargas de mello
# Updating entry 6554
# Calling API for name:
# first_name: ko	middle_name: jiunn	                   last_name: liu	full_name: ko jiunn liu
# Updating entry 6559
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: reubi	full_name: jean claude reubi
# Updating entry 6560
# Calling API for name:
# first_name: jean	middle_name: christophe	                   last_name: rossi	full_name: jean christophe rossi
# Updating entry 6561
# Calling API for name:
# first_name: yong	middle_name: rak	                   last_name: kim	full_name: yong rak kim
# Updating entry 6562
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: probst	full_name: jean luc probst
# Updating entry 6564
# Calling API for name:
# first_name: pak	middle_name: yin	                   last_name: leung	full_name: pak yin leung
# Updating entry 6568
# Calling API for name:
# first_name: jean	middle_name: frederic	                   last_name: gerbeau	full_name: jean frederic gerbeau
# Updating entry 6576
# Calling API for name:
# first_name: chong	middle_name: jai	                   last_name: kim	full_name: chong jai kim
# Updating entry 6583
# Calling API for name:
# first_name: jan	middle_name: maciej	                   last_name: waga	full_name: jan maciej waga
# Updating entry 6588
# Calling API for name:
# first_name: chong	middle_name: yang	                   last_name: liu	full_name: chong yang liu
# Updating entry 6589
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: olie	full_name: jean pierre olie
# Updating entry 6601
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: allain	full_name: jean pierre allain
# Updating entry 6607
# Calling API for name:
# first_name: jean	middle_name: sebastien	                   last_name: sereni	full_name: jean sebastien sereni
# Updating entry 6613
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: huez	full_name: jean francois huez
# Updating entry 6616
# Calling API for name:
# first_name: jean	middle_name: noel	                   last_name: talbot	full_name: jean noel talbot
# Updating entry 6621
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: le galliard	full_name: jean francois le galliard
# Updating entry 6624
# Calling API for name:
# first_name: jan	middle_name: olav	                   last_name: johannessen	full_name: jan olav johannessen
# Updating entry 6626
# Calling API for name:
# first_name: chi	middle_name: hua	                   last_name: chen	full_name: chi hua chen
# Updating entry 6636
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: ndambi	full_name: jean marie ndambi
# Updating entry 6644
# Calling API for name:
# first_name: jan	middle_name: ming	                   last_name: ho	full_name: jan ming ho
# Updating entry 6651
# Calling API for name:
# first_name: jean	middle_name: charles	                   last_name: soria	full_name: jean charles soria
# Updating entry 6655
# Calling API for name:
# first_name: jean	middle_name: baptiste	                   last_name: lattouf	full_name: jean baptiste lattouf
# Updating entry 6664
# Calling API for name:
# first_name: sergey	middle_name: yu	                   last_name: grachev	full_name: sergey yu grachev
# Updating entry 6690
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: nierengarten	full_name: jean francois nierengarten
# Updating entry 6693
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: sauvage	full_name: jean pierre sauvage
# Updating entry 6698
# Calling API for name:
# first_name: jean	middle_name: eric	                   last_name: tarride	full_name: jean eric tarride
# Updating entry 6699
# Calling API for name:
# first_name: jean	middle_name: frederic	                   last_name: colombel	full_name: jean frederic colombel
# Updating entry 6700
# Calling API for name:
# first_name: jean	middle_name: sebastien	                   last_name: rachoin	full_name: jean sebastien rachoin
# Updating entry 6706
# Calling API for name:
# first_name: sung	middle_name: kew	                   last_name: kim	full_name: sung kew kim
# Updating entry 6709
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: etard	full_name: jean francois etard
# Updating entry 6710
# Calling API for name:
# first_name: xue	middle_name: ru	                   last_name: wu	full_name: xue ru wu
# Updating entry 6711
# Calling API for name:
# first_name: jean	middle_name: paul	                   last_name: klein	full_name: jean paul klein
# Updating entry 6713
# Calling API for name:
# first_name: christian	middle_name: meyer	                   last_name: zum bueschenfelde	full_name: christian meyer zum bueschenfelde
# Updating entry 6719
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: beny	full_name: jean louis beny
# Updating entry 6723
# Calling API for name:
# first_name: jean	middle_name: christophe	                   last_name: leroux	full_name: jean christophe leroux
# Updating entry 6727
# Calling API for name:
# first_name: chong	middle_name: shu	                   last_name: zhu	full_name: chong shu zhu
# Updating entry 6728
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: devoisselle	full_name: jean marie devoisselle
# Updating entry 6730
# Calling API for name:
# first_name: pier	middle_name: nicola	                   last_name: sergi	full_name: pier nicola sergi
# Updating entry 6734
# Calling API for name:
# first_name: ali	middle_name: ahmadi	                   last_name: peyghan	full_name: ali ahmadi peyghan
# Updating entry 6735
# Calling API for name:
# first_name: ali	middle_name: osman	                   last_name: solak	full_name: ali osman solak
# Updating entry 6739
# Calling API for name:
# first_name: man	middle_name: bo	                   last_name: li	full_name: man bo li
# Updating entry 6741
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: silvain	full_name: jean francois silvain
# Updating entry 6746
# Calling API for name:
# first_name: jean	middle_name: sebastien	                   last_name: pierre	full_name: jean sebastien pierre
# Updating entry 6748
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: saliege	full_name: jean francois saliege
# Updating entry 6758
# Calling API for name:
# first_name: chong	middle_name: lye	                   last_name: ang	full_name: chong lye ang
# Updating entry 6760
# Calling API for name:
# first_name: young	middle_name: hyun	                   last_name: yoo	full_name: young hyun yoo
# Updating entry 6761
# Calling API for name:
# first_name: hong	middle_name: guo	                   last_name: jin	full_name: hong guo jin
# Updating entry 6766
# Calling API for name:
# first_name: shin	middle_name: young	                   last_name: park	full_name: shin young park
# Updating entry 6767
# Calling API for name:
# first_name: yeon	middle_name: woo	                   last_name: jeong	full_name: yeon woo jeong
# Updating entry 6770
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: vila	full_name: jean marie vila
# Updating entry 6772
# Calling API for name:
# first_name: xing	middle_name: yu	                   last_name: jin	full_name: xing yu jin
# Updating entry 6773
# Calling API for name:
# first_name: young	middle_name: kul	                   last_name: jung	full_name: young kul jung
# Updating entry 6776
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: seigneurin	full_name: jean marie seigneurin
# Updating entry 6780
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: patard	full_name: jean jacques patard
# Updating entry 6782
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: morfin	full_name: jean francois morfin
# Updating entry 6784
# Calling API for name:
# first_name: hong	middle_name: quan	                   last_name: he	full_name: hong quan he
# Updating entry 6790
# Calling API for name:
# first_name: jan	middle_name: roelof	                   last_name: polling	full_name: jan roelof polling
# Updating entry 6793
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: berges	full_name: jean claude berges
# Updating entry 6795
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: savard	full_name: jean francois savard
# Updating entry 6796
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: fagon	full_name: jean yves fagon
# Updating entry 6797
# Calling API for name:
# first_name: jean	middle_name: lacau	                   last_name: guily	full_name: jean lacau guily
# Updating entry 6804
# Calling API for name:
# first_name: li	middle_name: sung	                   last_name: tsao	full_name: li sung tsao
# Updating entry 6805
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: sollet	full_name: jean pierre sollet
# Updating entry 6808
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: reperant	full_name: jean michel reperant
# Updating entry 6809
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: leyssale	full_name: jean marc leyssale
# Updating entry 6814
# Calling API for name:
# first_name: chi	middle_name: wang	                   last_name: ip	full_name: chi wang ip
# Updating entry 6816
# Calling API for name:
# first_name: yong	middle_name: lie	                   last_name: chu	full_name: yong lie chu
# Updating entry 6821
# Calling API for name:
# first_name: young	middle_name: bok	                   last_name: lee	full_name: young bok lee
# Updating entry 6822
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: pitetti	full_name: jean luc pitetti
# Updating entry 6826
# Calling API for name:
# first_name: tie	middle_name: hong	                   last_name: chen	full_name: tie hong chen
# Updating entry 6831
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: descotes	full_name: jean luc descotes
# Updating entry 6832
# Calling API for name:
# first_name: chong	middle_name: kil	                   last_name: lee	full_name: chong kil lee
# Updating entry 6836
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: colleau	full_name: jean jacques colleau
# Updating entry 6838
# Calling API for name:
# first_name: man	middle_name: soo	                   last_name: choi	full_name: man soo choi
# Updating entry 6841
# Calling API for name:
# first_name: young	middle_name: geun	                   last_name: lee	full_name: young geun lee
# Updating entry 6845
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: guillaume	full_name: jean marc guillaume
# Updating entry 6846
# Calling API for name:
# first_name: chang	middle_name: wook	                   last_name: baek	full_name: chang wook baek
# Updating entry 6847
# Calling API for name:
# first_name: jean	middle_name: ching	                   last_name: tien	full_name: jean ching tien
# Updating entry 6848
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: winum	full_name: jean yves winum
# Updating entry 6851
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: petit	full_name: jean michel petit
# Updating entry 6853
# Calling API for name:
# first_name: eun	middle_name: soo	                   last_name: an	full_name: eun soo an
# Updating entry 6858
# Calling API for name:
# first_name: jan	middle_name: harry	                   last_name: storksen	full_name: jan harry storksen
# Updating entry 6860
# Calling API for name:
# first_name: sang	middle_name: yoo	                   last_name: park	full_name: sang yoo park
# Updating entry 6861
# Calling API for name:
# first_name: ki	middle_name: yong	                   last_name: jeon	full_name: ki yong jeon
# Updating entry 6865
# Calling API for name:
# first_name: eun	middle_name: soo	                   last_name: youk	full_name: eun soo youk
# Updating entry 6868
# Calling API for name:
# first_name: su	middle_name: hyeong	                   last_name: kim	full_name: su hyeong kim
# Updating entry 6870
# Calling API for name:
# first_name: chang	middle_name: keun	                   last_name: sung	full_name: chang keun sung
# Updating entry 6871
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: mansuy	full_name: jean michel mansuy
# Updating entry 6872
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: peron	full_name: jean marie peron
# Updating entry 6874
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: girard	full_name: jean marie girard
# Updating entry 6875
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: bouquard	full_name: jean louis bouquard
# Updating entry 6878
# Calling API for name:
# first_name: young	middle_name: woo	                   last_name: kim	full_name: young woo kim
# Updating entry 6879
# Calling API for name:
# first_name: young	middle_name: gil	                   last_name: jeong	full_name: young gil jeong
# Updating entry 6881
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: menetret	full_name: jean francois menetret
# Updating entry 6884
# Calling API for name:
# first_name: qiao	middle_name: bing	                   last_name: wang	full_name: qiao bing wang
# Updating entry 6887
# Calling API for name:
# first_name: britt	middle_name: bang	                   last_name: jensen	full_name: britt bang jensen
# Updating entry 6889
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: marigo	full_name: jean jacques marigo
# Updating entry 6890
# Calling API for name:
# first_name: ji	middle_name: won	                   last_name: kim	full_name: ji won kim
# Updating entry 6892
# Calling API for name:
# first_name: chung	middle_name: shou	                   last_name: chen	full_name: chung shou chen
# Updating entry 6893
# Calling API for name:
# first_name: jean	middle_name: phillipe	                   last_name: avaro	full_name: jean phillipe avaro
# Updating entry 6899
# Calling API for name:
# first_name: chang	middle_name: sup	                   last_name: oh	full_name: chang sup oh
# Updating entry 6900
# Calling API for name:
# first_name: young	middle_name: tai	                   last_name: choi	full_name: young tai choi
# Updating entry 6901
# Calling API for name:
# first_name: sai	middle_name: ming	                   last_name: cheung	full_name: sai ming cheung
# Updating entry 6902
# Calling API for name:
# first_name: ali	middle_name: asghar	                   last_name: rastegari	full_name: ali asghar rastegari
# Updating entry 6903
# Calling API for name:
# first_name: jean	middle_name: rene	                   last_name: lusson	full_name: jean rene lusson
# Updating entry 6905
# Calling API for name:
# first_name: chang	middle_name: hsin	                   last_name: chien	full_name: chang hsin chien
# Updating entry 6907
# Calling API for name:
# first_name: su	middle_name: jae	                   last_name: kim	full_name: su jae kim
# Updating entry 6910
# Calling API for name:
# first_name: youn	middle_name: sun	                   last_name: chung	full_name: youn sun chung
# Updating entry 6913
# Calling API for name:
# first_name: kan	middle_name: shan	                   last_name: shih	full_name: kan shan shih
# Updating entry 6917
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: dufour	full_name: jean francois dufour
# Updating entry 6918
# Calling API for name:
# first_name: shun	middle_name: ichi	                   last_name: kuwana	full_name: shun ichi kuwana
# Updating entry 6927
# Calling API for name:
# first_name: da	middle_name: hong	                   last_name: wang	full_name: da hong wang
# Updating entry 6928
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: prioul	full_name: jean louis prioul
# Updating entry 6929
# Calling API for name:
# first_name: taylor	middle_name: price	                   last_name: frazier	full_name: taylor price frazier
# Updating entry 6932
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: finet	full_name: jean pierre finet
# Updating entry 6935
# Calling API for name:
# first_name: kei	middle_name: ichi	                   last_name: maeda	full_name: kei ichi maeda
# Updating entry 6941
# Calling API for name:
# first_name: young	middle_name: kuk	                   last_name: cho	full_name: young kuk cho
# Updating entry 6944
# Calling API for name:
# first_name: ilham	middle_name: zainal	                   last_name: abidin	full_name: ilham zainal abidin
# Updating entry 6945
# Calling API for name:
# first_name: soo	middle_name: yeon	                   last_name: seo	full_name: soo yeon seo
# Updating entry 6946
# Calling API for name:
# first_name: chang	middle_name: soo	                   last_name: eun	full_name: chang soo eun
# Updating entry 6947
# Calling API for name:
# first_name: jean	middle_name: pascal	                   last_name: lefaucheur	full_name: jean pascal lefaucheur
# Updating entry 6952
# Calling API for name:
# first_name: zi	middle_name: niu	                   last_name: yu	full_name: zi niu yu
# Updating entry 6955
# Calling API for name:
# first_name: kelly	middle_name: cristiane	                   last_name: ito	full_name: kelly cristiane ito
# Updating entry 6956
# Calling API for name:
# first_name: young	middle_name: chan	                   last_name: choe	full_name: young chan choe
# Updating entry 6957
# Calling API for name:
# first_name: jan	middle_name: jaap	                   last_name: van lier	full_name: jan jaap van lier
# Updating entry 6959
# Calling API for name:
# first_name: jean	middle_name: christophe	                   last_name: mulatier	full_name: jean christophe mulatier
# Updating entry 6967
# Calling API for name:
# first_name: jeong	middle_name: hyun	                   last_name: lee	full_name: jeong hyun lee
# Updating entry 6968
# Calling API for name:
# first_name: jean	middle_name: laurent	                   last_name: codaccioni	full_name: jean laurent codaccioni
# Updating entry 6969
# Calling API for name:
# first_name: oi	middle_name: hong	                   last_name: tung	full_name: oi hong tung
# Updating entry 6971
# Calling API for name:
# first_name: jean	middle_name: dominique	                   last_name: luporsi	full_name: jean dominique luporsi
# Updating entry 6972
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: pasquie	full_name: jean luc pasquie
# Updating entry 6974
# Calling API for name:
# first_name: jean	middle_name: nicolas	                   last_name: cornu	full_name: jean nicolas cornu
# Updating entry 6978
# Calling API for name:
# first_name: jie	middle_name: lun	                   last_name: chiang	full_name: jie lun chiang
# Updating entry 6981
# Calling API for name:
# first_name: chi	middle_name: leung	                   last_name: watt	full_name: chi leung watt
# Updating entry 6984
# Calling API for name:
# first_name: elisha	middle_name: raju	                   last_name: repalle	full_name: elisha raju repalle
# Updating entry 6986
# Calling API for name:
# first_name: chong	middle_name: xin	                   last_name: liu	full_name: chong xin liu
# Updating entry 6987
# Calling API for name:
# first_name: jan	middle_name: eric	                   last_name: grunwald	full_name: jan eric grunwald
# Updating entry 6989
# Calling API for name:
# first_name: dong	middle_name: xin	                   last_name: liu	full_name: dong xin liu
# Updating entry 6990
# Calling API for name:
# first_name: jae	middle_name: soo	                   last_name: koh	full_name: jae soo koh
# Updating entry 6992
# Calling API for name:
# first_name: kuo	middle_name: shun	                   last_name: sun	full_name: kuo shun sun
# Updating entry 6994
# Calling API for name:
# first_name: cao	middle_name: ying	                   last_name: yang	full_name: cao ying yang
# Updating entry 6995
# Calling API for name:
# first_name: bi	middle_name: dong	                   last_name: fang	full_name: bi dong fang
# Updating entry 7003
# Calling API for name:
# first_name: chang	middle_name: sup	                   last_name: kim	full_name: chang sup kim
# Updating entry 7005
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: baulieu	full_name: jean louis baulieu
# Updating entry 7008
# Calling API for name:
# first_name: francis	middle_name: raymond	                   last_name: arkoncel	full_name: francis raymond arkoncel
# Updating entry 7011
# Calling API for name:
# first_name: jin	middle_name: young	                   last_name: bae	full_name: jin young bae
# Updating entry 7012
# Calling API for name:
# first_name: jae	middle_name: sin	                   last_name: choi	full_name: jae sin choi
# Updating entry 7016
# Calling API for name:
# first_name: chang	middle_name: hyeon	                   last_name: joh	full_name: chang hyeon joh
# Updating entry 7019
# Calling API for name:
# first_name: chong	middle_name: woo	                   last_name: chu	full_name: chong woo chu
# Updating entry 7023
# Calling API for name:
# first_name: jin	middle_name: young	                   last_name: kim	full_name: jin young kim
# Updating entry 7026
# Calling API for name:
# first_name: chang	middle_name: keun	                   last_name: jo	full_name: chang keun jo
# Updating entry 7032
# Calling API for name:
# first_name: chang	middle_name: woon	                   last_name: choi	full_name: chang woon choi
# Updating entry 7034
# Calling API for name:
# first_name: kyung	middle_name: hwa	                   last_name: han	full_name: kyung hwa han
# Updating entry 7037
# Calling API for name:
# first_name: jean	middle_name: paul	                   last_name: callot	full_name: jean paul callot
# Updating entry 7038
# Calling API for name:
# first_name: chang	middle_name: su	                   last_name: kim	full_name: chang su kim
# Updating entry 7039
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: meister	full_name: jean jacques meister
# Updating entry 7041
# Calling API for name:
# first_name: chang	middle_name: woo	                   last_name: lee	full_name: chang woo lee
# Updating entry 7045
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: bonnetblanc	full_name: jean marie bonnetblanc
# Updating entry 7046
# Calling API for name:
# first_name: hong	middle_name: yeol	                   last_name: kim	full_name: hong yeol kim
# Updating entry 7047
# Calling API for name:
# first_name: lee	middle_name: wen	                   last_name: huang	full_name: lee wen huang
# Updating entry 7049
# Calling API for name:
# first_name: young	middle_name: dok	                   last_name: kim	full_name: young dok kim
# Updating entry 7050
# Calling API for name:
# first_name: qi	middle_name: cai	                   last_name: chen	full_name: qi cai chen
# Updating entry 7051
# Calling API for name:
# first_name: lian	middle_name: bing	                   last_name: lin	full_name: lian bing lin
# Updating entry 7056
# Calling API for name:
# first_name: kei	middle_name: ichi	                   last_name: tainaka	full_name: kei ichi tainaka
# Updating entry 7057
# Calling API for name:
# first_name: guo	middle_name: wen	                   last_name: liu	full_name: guo wen liu
# Updating entry 7062
# Calling API for name:
# first_name: chong	middle_name: jun	                   last_name: li	full_name: chong jun li
# Updating entry 7063
# Calling API for name:
# first_name: jean	middle_name: jules	                   last_name: tewa	full_name: jean jules tewa
# Updating entry 7064
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: rauch	full_name: jean yves rauch
# Updating entry 7068
# Calling API for name:
# first_name: chung	middle_name: hyun	                   last_name: cho	full_name: chung hyun cho
# Updating entry 7073
# Calling API for name:
# first_name: pier	middle_name: andrea	                   last_name: de iaco	full_name: pier andrea de iaco
# Updating entry 7074
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: scoazec	full_name: jean yves scoazec
# Data updated in dump file test_data/names_api_full/test_data_all_names_api_full.csv

# %%
evaluatorNAF.compute_all_errors()
evaluatorNAF.confusion_matrix
# Out:
#    f_pred  m_pred  u_pred
# f    1595      89     277
# m     124    3113     588
# u     242     650     393

# %% [markdown]
# ### NamesAPI

# %%
data_source = 'all'
service_name = NamesAPIEvaluator

# %%
evaluatorNA = service_name(data_source)
evaluatorNA.load_data()
evaluatorNA.fetch_gender()
# Out:
# Reading data from dump file test_data/names_api/test_data_all_names_api.csv

# %% [markdown]
# #### Fix problem with 'nan' name

# %%
check_match_test_evaluated_data(evaluatorNA)
# Out:
# There is a mismatch between raw and evaluated datasets. Please fix.
# right_only are entries in the raw data set. left_only in the evaluated one.
#      first_name middle_name last_name      full_name gender  origin  \
# 5038                   xian      chen  nan xian chen      m  nature
# 7076        nan        xian      chen  nan xian chen      m  nature
#
#       api_confidence api_gender gender_infered      _merge
# 5038        0.908388       MALE              m   left_only
# 7076             NaN        NaN            NaN  right_only

# %%
# In the old test data file the first name had been incorrectly read as NaN. Put 'nan' back in
evaluatorNA.test_data.loc[5038, 'first_name'] = 'nan'

# %%
evaluatorNA.update_selected_records([5038])
# Out:
# Updating entry 5038
# Calling API for name:
# first_name: nan	middle_name: xian	                   last_name: chen	full_name: nan xian chen
# Data updated in dump file test_data/names_api/test_data_all_names_api.csv

# %%
evaluatorNA.fetch_gender()
# Out:
# Reading data from dump file test_data/names_api/test_data_all_names_api.csv

# %%
check_match_test_evaluated_data(evaluatorNA)
# Out:
# Evaluated data set matches contents of test data set. Good!
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_confidence, api_gender, gender_infered, _merge]
# Index: []

# %% [markdown]
# #### Re-do names with middle name - since handling of connectors in the code changed after loop refactoring

# %%
evaluatorNA.test_data[evaluatorNA.test_data.middle_name!=''].head()
# Out:
#    first_name middle_name   last_name                  full_name gender  \
# 0      pierre        paul      grivel         pierre paul grivel      m
# 6   catherine     bouloux     marquet  catherine bouloux marquet      f
# 14     claude     joachim      hamann      claude joachim hamann      m
# 22      jorge     drumond       silva        jorge drumond silva      m
# 25       jost     hinrich  eschenburg    jost hinrich eschenburg      m
#
#     origin  api_confidence api_gender gender_infered
# 0   zbmath        0.873016       MALE              m
# 6   zbmath        0.901827     FEMALE              f
# 14  zbmath        1.000000       MALE              m
# 22  zbmath        0.896182       MALE              m
# 25  zbmath        0.866667       MALE              m

# %%
len(evaluatorNA.test_data[evaluatorNAF.test_data.middle_name!=''])
# Out:
# 913

# %% [markdown]
# We need to re-do all those 913 cases above, since we do not know which ones came from joining first and middle name with empty connector.

# %%
evaluatorNA.test_data[(evaluatorNA.test_data.middle_name!='')].head(10)
# Out:
#     first_name  middle_name   last_name                  full_name gender  \
# 0       pierre         paul      grivel         pierre paul grivel      m
# 6    catherine      bouloux     marquet  catherine bouloux marquet      f
# 14      claude      joachim      hamann      claude joachim hamann      m
# 22       jorge      drumond       silva        jorge drumond silva      m
# 25        jost      hinrich  eschenburg    jost hinrich eschenburg      m
# 44         jae           il         lee                 jae il lee      u
# 50       boris  yakovlevich       levin    boris yakovlevich levin      m
# 71       marek       cezary        zdun          marek cezary zdun      m
# 88      pierre         loic      meliot         pierre loic meliot      m
# 110    douglas         john       white         douglas john white      m
#
#      origin  api_confidence api_gender gender_infered
# 0    zbmath        0.873016       MALE              m
# 6    zbmath        0.901827     FEMALE              f
# 14   zbmath        1.000000       MALE              m
# 22   zbmath        0.896182       MALE              m
# 25   zbmath        0.866667       MALE              m
# 44   zbmath        0.996571       MALE              m
# 50   zbmath        0.931624       MALE              m
# 71   zbmath        1.000000       MALE              m
# 88   zbmath        1.000000       MALE              m
# 110  zbmath        1.000000       MALE              m

# %%
len(evaluatorNA.test_data[(evaluatorNA.test_data.middle_name!='')])
# Out:
# 913

# %%
to_update_indices = evaluatorNA.test_data[(evaluatorNA.test_data.middle_name!='')].index
to_update_indices
# Out:
# Int64Index([   0,    6,   14,   22,   25,   44,   50,   71,   88,  110,
#             ...
#             7050, 7051, 7056, 7057, 7062, 7063, 7064, 7068, 7073, 7074],
#            dtype='int64', length=913)

# %%
evaluatorNA.update_selected_records(to_update_indices)
# Out:
# Updating entry 0
# Calling API for name:
# first_name: pierre	middle_name: paul	                   last_name: grivel	full_name: pierre paul grivel
# Updating entry 6
# Calling API for name:
# first_name: catherine	middle_name: bouloux	                   last_name: marquet	full_name: catherine bouloux marquet
# Updating entry 14
# Calling API for name:
# first_name: claude	middle_name: joachim	                   last_name: hamann	full_name: claude joachim hamann
# Updating entry 22
# Calling API for name:
# first_name: jorge	middle_name: drumond	                   last_name: silva	full_name: jorge drumond silva
# Updating entry 25
# Calling API for name:
# first_name: jost	middle_name: hinrich	                   last_name: eschenburg	full_name: jost hinrich eschenburg
# Updating entry 44
# Calling API for name:
# first_name: jae	middle_name: il	                   last_name: lee	full_name: jae il lee
# Updating entry 50
# Calling API for name:
# first_name: boris	middle_name: yakovlevich	                   last_name: levin	full_name: boris yakovlevich levin
# Updating entry 71
# Calling API for name:
# first_name: marek	middle_name: cezary	                   last_name: zdun	full_name: marek cezary zdun
# Updating entry 88
# Calling API for name:
# first_name: pierre	middle_name: loic	                   last_name: meliot	full_name: pierre loic meliot
# Updating entry 110
# Calling API for name:
# first_name: douglas	middle_name: john	                   last_name: white	full_name: douglas john white
# Updating entry 111
# Calling API for name:
# first_name: davy	middle_name: ho	                   last_name: chan	full_name: davy ho chan
# Updating entry 114
# Calling API for name:
# first_name: isabel	middle_name: fraga	                   last_name: alves	full_name: isabel fraga alves
# Updating entry 115
# Calling API for name:
# first_name: jin	middle_name: ho	                   last_name: choi	full_name: jin ho choi
# Updating entry 121
# Calling API for name:
# first_name: john	middle_name: ren	                   last_name: chen	full_name: john ren chen
# Updating entry 134
# Calling API for name:
# first_name: outi	middle_name: elina	                   last_name: maasalo	full_name: outi elina maasalo
# Updating entry 139
# Calling API for name:
# first_name: marie	middle_name: francoise	                   last_name: delcroix	full_name: marie francoise delcroix
# Updating entry 145
# Calling API for name:
# first_name: suhasini	middle_name: subba	                   last_name: rao	full_name: suhasini subba rao
# Updating entry 147
# Calling API for name:
# first_name: david	middle_name: matthew	                   last_name: kelly	full_name: david matthew kelly
# Updating entry 163
# Calling API for name:
# first_name: james	middle_name: murray	                   last_name: hill	full_name: james murray hill
# Updating entry 180
# Calling API for name:
# first_name: maria	middle_name: zofia	                   last_name: banaszczyk	full_name: maria zofia banaszczyk
# Updating entry 181
# Calling API for name:
# first_name: mehmet	middle_name: namik	                   last_name: oguztoereli	full_name: mehmet namik oguztoereli
# Updating entry 187
# Calling API for name:
# first_name: alexei	middle_name: yu	                   last_name: karlovich	full_name: alexei yu karlovich
# Updating entry 195
# Calling API for name:
# first_name: soo	middle_name: jin	                   last_name: kim	full_name: soo jin kim
# Updating entry 218
# Calling API for name:
# first_name: sung	middle_name: hoon	                   last_name: hong	full_name: sung hoon hong
# Updating entry 224
# Calling API for name:
# first_name: figen	middle_name: acil	                   last_name: kiraz	full_name: figen acil kiraz
# Updating entry 238
# Calling API for name:
# first_name: asim	middle_name: kumar	                   last_name: mandal	full_name: asim kumar mandal
# Updating entry 256
# Calling API for name:
# first_name: alf	middle_name: birger	                   last_name: rustad	full_name: alf birger rustad
# Updating entry 266
# Calling API for name:
# first_name: abdel	middle_name: hadi	                   last_name: ahmed	full_name: abdel hadi ahmed
# Updating entry 292
# Calling API for name:
# first_name: razvan	middle_name: alin	                   last_name: satnoianu	full_name: razvan alin satnoianu
# Updating entry 295
# Calling API for name:
# first_name: huy	middle_name: thang	                   last_name: cao	full_name: huy thang cao
# Updating entry 300
# Calling API for name:
# first_name: ben	middle_name: da	                   last_name: zhou	full_name: ben da zhou
# Updating entry 310
# Calling API for name:
# first_name: hon	middle_name: kit	                   last_name: wai	full_name: hon kit wai
# Updating entry 311
# Calling API for name:
# first_name: bao	middle_name: wen	                   last_name: sun	full_name: bao wen sun
# Updating entry 312
# Calling API for name:
# first_name: byoung	middle_name: chan	                   last_name: lee	full_name: byoung chan lee
# Updating entry 325
# Calling API for name:
# first_name: carlos	middle_name: renato	                   last_name: vazquez	full_name: carlos renato vazquez
# Updating entry 327
# Calling API for name:
# first_name: b	middle_name: jo	                   last_name: ptashnyk	full_name: b jo ptashnyk
# Updating entry 333
# Calling API for name:
# first_name: chao	middle_name: zhu	                   last_name: zhang	full_name: chao zhu zhang
# Updating entry 342
# Calling API for name:
# first_name: jwu	middle_name: sheng	                   last_name: hu	full_name: jwu sheng hu
# Updating entry 347
# Calling API for name:
# first_name: wai	middle_name: king	                   last_name: ching	full_name: wai king ching
# Updating entry 348
# Calling API for name:
# first_name: maria	middle_name: conception	                   last_name: carvalho	full_name: maria conception carvalho
# Updating entry 357
# Calling API for name:
# first_name: cai	middle_name: gui	                   last_name: liu	full_name: cai gui liu
# Updating entry 359
# Calling API for name:
# first_name: jan	middle_name: tijmen	                   last_name: udding	full_name: jan tijmen udding
# Updating entry 361
# Calling API for name:
# first_name: hsueh	middle_name: chuan	                   last_name: liu	full_name: hsueh chuan liu
# Updating entry 366
# Calling API for name:
# first_name: frieder	middle_name: jens	                   last_name: lange	full_name: frieder jens lange
# Updating entry 373
# Calling API for name:
# first_name: cheng	middle_name: wei	                   last_name: chen	full_name: cheng wei chen
# Updating entry 378
# Calling API for name:
# first_name: john	middle_name: wilson	                   last_name: calkin	full_name: john wilson calkin
# Updating entry 389
# Calling API for name:
# first_name: tack	middle_name: wang	                   last_name: lee	full_name: tack wang lee
# Updating entry 422
# Calling API for name:
# first_name: judith	middle_name: louisa	                   last_name: schmid	full_name: judith louisa schmid
# Updating entry 482
# Calling API for name:
# first_name: yves	middle_name: marie	                   last_name: allioux	full_name: yves marie allioux
# Updating entry 495
# Calling API for name:
# first_name: linda	middle_name: esther	                   last_name: oray	full_name: linda esther oray
# Updating entry 514
# Calling API for name:
# first_name: shing	middle_name: tung	                   last_name: yau	full_name: shing tung yau
# Updating entry 570
# Calling API for name:
# first_name: diane	middle_name: romayne	                   last_name: baker	full_name: diane romayne baker
# Updating entry 572
# Calling API for name:
# first_name: dusanka	middle_name: savic	                   last_name: pavicevic	full_name: dusanka savic pavicevic
# Updating entry 589
# Calling API for name:
# first_name: geraldo	middle_name: vicente	                   last_name: de almeida	full_name: geraldo vicente de almeida
# Updating entry 602
# Calling API for name:
# first_name: hyoung	middle_name: gon	                   last_name: lee	full_name: hyoung gon lee
# Updating entry 606
# Calling API for name:
# first_name: ronald	middle_name: grigor	                   last_name: suny	full_name: ronald grigor suny
# Updating entry 666
# Calling API for name:
# first_name: pedro	middle_name: ramon	                   last_name: gutierrez hernandez	full_name: pedro ramon gutierrez hernandez
# Updating entry 705
# Calling API for name:
# first_name: nirmal	middle_name: kumar	                   last_name: chandra	full_name: nirmal kumar chandra
# Updating entry 717
# Calling API for name:
# first_name: charlotte	middle_name: pomerantz	                   last_name: marzani	full_name: charlotte pomerantz marzani
# Updating entry 739
# Calling API for name:
# first_name: pierre	middle_name: sylvain	                   last_name: filliozat	full_name: pierre sylvain filliozat
# Updating entry 751
# Calling API for name:
# first_name: anne	middle_name: hudson	                   last_name: jones	full_name: anne hudson jones
# Updating entry 782
# Calling API for name:
# first_name: hans	middle_name: peter	                   last_name: bruch	full_name: hans peter bruch
# Updating entry 789
# Calling API for name:
# first_name: carol	middle_name: anne	                   last_name: costabile-heming	full_name: carol anne costabile-heming
# Updating entry 795
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: pujol	full_name: jean louis pujol
# Updating entry 802
# Calling API for name:
# first_name: karl	middle_name: heinz	                   last_name: schwalbe	full_name: karl heinz schwalbe
# Updating entry 833
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: bardon	full_name: jean pierre bardon
# Updating entry 885
# Calling API for name:
# first_name: jose	middle_name: carlos	                   last_name: mainer	full_name: jose carlos mainer
# Updating entry 888
# Calling API for name:
# first_name: rolf	middle_name: tore	                   last_name: ottesen	full_name: rolf tore ottesen
# Updating entry 898
# Calling API for name:
# first_name: mary	middle_name: rose	                   last_name: couper	full_name: mary rose couper
# Updating entry 952
# Calling API for name:
# first_name: cindy	middle_name: fabian	                   last_name: mascone	full_name: cindy fabian mascone
# Updating entry 967
# Calling API for name:
# first_name: nancy	middle_name: mary	                   last_name: adams	full_name: nancy mary adams
# Updating entry 984
# Calling API for name:
# first_name: rob	middle_name: roy	                   last_name: kelly	full_name: rob roy kelly
# Updating entry 988
# Calling API for name:
# first_name: allen	middle_name: purdue	                   last_name: britton	full_name: allen purdue britton
# Updating entry 992
# Calling API for name:
# first_name: aage	middle_name: niels	                   last_name: bohr	full_name: aage niels bohr
# Updating entry 995
# Calling API for name:
# first_name: alastair	middle_name: michael	                   last_name: porter	full_name: alastair michael douglas porter
# Updating entry 996
# Calling API for name:
# first_name: alastair	middle_name: vincent	                   last_name: campbell	full_name: alastair vincent campbell
# Updating entry 997
# Calling API for name:
# first_name: aldo	middle_name: ricardo	                   last_name: castaneda	full_name: aldo ricardo castaneda
# Updating entry 998
# Calling API for name:
# first_name: aleksandr	middle_name: aleksandrovich	                   last_name: kaplyanskii	full_name: aleksandr aleksandrovich kaplyanskii
# Updating entry 999
# Calling API for name:
# first_name: aleksandr	middle_name: petrovich	                   last_name: krylov	full_name: aleksandr petrovich krylov
# Updating entry 1000
# Calling API for name:
# first_name: aleksandr	middle_name: yakovlevich	                   last_name: lerner	full_name: aleksandr yakovlevich lerner
# Updating entry 1002
# Calling API for name:
# first_name: alexander	middle_name: yakovlevich	                   last_name: lerner	full_name: alexander yakovlevich lerner
# Updating entry 1004
# Calling API for name:
# first_name: anatolii	middle_name: aleksandrovich	                   last_name: ishchenko	full_name: anatolii aleksandrovich ishchenko
# Updating entry 1006
# Calling API for name:
# first_name: andre	middle_name: stephane	                   last_name: hamer	full_name: andre stephane hamer
# Updating entry 1008
# Calling API for name:
# first_name: anna	middle_name: isabella	                   last_name: davison	full_name: anna isabella davison
# Updating entry 1009
# Calling API for name:
# first_name: anne	middle_name: mary	                   last_name: buck	full_name: anne mary buck
# Updating entry 1011
# Calling API for name:
# first_name: anthony	middle_name: francis	                   last_name: rickards	full_name: anthony francis rickards
# Updating entry 1012
# Calling API for name:
# first_name: antony	middle_name: frank	                   last_name: francis	full_name: antony frank francis
# Updating entry 1013
# Calling API for name:
# first_name: arsen	middle_name: ralph	                   last_name: papakhian	full_name: arsen ralph papakhian
# Updating entry 1016
# Calling API for name:
# first_name: arthur	middle_name: philip	                   last_name: waind	full_name: arthur philip booth waind
# Updating entry 1024
# Calling API for name:
# first_name: benedict	middle_name: john	                   last_name: barry	full_name: benedict john barry
# Updating entry 1026
# Calling API for name:
# first_name: bertram	middle_name: neville	                   last_name: brockhouse	full_name: bertram neville brockhouse
# Updating entry 1036
# Calling API for name:
# first_name: campbell	middle_name: grieve	                   last_name: stalker	full_name: campbell grieve stalker
# Updating entry 1037
# Calling API for name:
# first_name: carl	middle_name: gottfried	                   last_name: semper	full_name: carl gottfried semper
# Updating entry 1038
# Calling API for name:
# first_name: carl	middle_name: gustav	                   last_name: jung	full_name: carl gustav jung
# Updating entry 1052
# Calling API for name:
# first_name: david	middle_name: abraham	                   last_name: katcher	full_name: david abraham katcher
# Updating entry 1053
# Calling API for name:
# first_name: david	middle_name: hamilton	                   last_name: smith	full_name: david hamilton smith
# Updating entry 1054
# Calling API for name:
# first_name: david	middle_name: herbert	                   last_name: donald	full_name: david herbert donald
# Updating entry 1056
# Calling API for name:
# first_name: david	middle_name: morris	                   last_name: welborn	full_name: david morris welborn
# Updating entry 1058
# Calling API for name:
# first_name: david	middle_name: schofield	                   last_name: jeffery	full_name: david schofield jeffery
# Updating entry 1062
# Calling API for name:
# first_name: derek	middle_name: charles	                   last_name: robinson	full_name: derek charles robinson
# Updating entry 1067
# Calling API for name:
# first_name: donald	middle_name: morgan	                   last_name: anderson	full_name: donald morgan anderson
# Updating entry 1068
# Calling API for name:
# first_name: donald	middle_name: redfield	                   last_name: griffin	full_name: donald redfield griffin
# Updating entry 1069
# Calling API for name:
# first_name: donald	middle_name: stevenson	                   last_name: pitkin	full_name: donald stevenson pitkin
# Updating entry 1070
# Calling API for name:
# first_name: donald	middle_name: william	                   last_name: gau	full_name: donald william gau
# Updating entry 1073
# Calling API for name:
# first_name: richard	middle_name: moreton	                   last_name: ellison	full_name: richard moreton ellison
# Updating entry 1076
# Calling API for name:
# first_name: clifton	middle_name: fletcher	                   last_name: mountain	full_name: clifton fletcher mountain
# Updating entry 1080
# Calling API for name:
# first_name: peer	middle_name: michael	                   last_name: portner	full_name: peer michael portner
# Updating entry 1088
# Calling API for name:
# first_name: edmund	middle_name: neville	                   last_name: hey	full_name: edmund neville hey
# Updating entry 1091
# Calling API for name:
# first_name: edwin	middle_name: sinclair	                   last_name: young	full_name: edwin sinclair young
# Updating entry 1094
# Calling API for name:
# first_name: eloge	middle_name: john	                   last_name: greene	full_name: eloge john colton greene
# Updating entry 1095
# Calling API for name:
# first_name: eric	middle_name: matheson	                   last_name: dunlop	full_name: eric matheson dunlop
# Updating entry 1098
# Calling API for name:
# first_name: evgenii	middle_name: akimovich	                   last_name: turov	full_name: evgenii akimovich turov
# Updating entry 1099
# Calling API for name:
# first_name: evgenii	middle_name: nikolaevich	                   last_name: avrorin	full_name: evgenii nikolaevich avrorin
# Updating entry 1106
# Calling API for name:
# first_name: garry	middle_name: davis	                   last_name: jones	full_name: garry davis jones
# Updating entry 1108
# Calling API for name:
# first_name: geoffrey	middle_name: john	                   last_name: pugh	full_name: geoffrey john frederick pugh
# Updating entry 1109
# Calling API for name:
# first_name: george	middle_name: adam	                   last_name: newsholme	full_name: george adam newsholme
# Updating entry 1111
# Calling API for name:
# first_name: george	middle_name: alfred	                   last_name: quinnell	full_name: george alfred fiske quinnell
# Updating entry 1113
# Calling API for name:
# first_name: george	middle_name: william	                   last_name: blair	full_name: george william scott blair
# Updating entry 1117
# Calling API for name:
# first_name: graham	middle_name: martin	                   last_name: pizzey	full_name: graham martin pizzey
# Updating entry 1118
# Calling API for name:
# first_name: graham	middle_name: warner	                   last_name: ward	full_name: graham warner ward
# Updating entry 1119
# Calling API for name:
# first_name: griff	middle_name: terry	                   last_name: ross	full_name: griff terry ross
# Updating entry 1120
# Calling API for name:
# first_name: guillermo	middle_name: lohmann	                   last_name: villena	full_name: guillermo lohmann villena
# Updating entry 1121
# Calling API for name:
# first_name: gwilym	middle_name: kenneth	                   last_name: davies	full_name: gwilym kenneth davies
# Updating entry 1124
# Calling API for name:
# first_name: harry	middle_name: francis	                   last_name: taylor	full_name: harry francis west taylor
# Updating entry 1128
# Calling API for name:
# first_name: herta	middle_name: julie	                   last_name: altschulova	full_name: herta julie altschulova
# Updating entry 1134
# Calling API for name:
# first_name: john	middle_name: szentagothai	                   last_name: centennial	full_name: john szentagothai centennial
# Updating entry 1144
# Calling API for name:
# first_name: joseph	middle_name: michael	                   last_name: foley	full_name: joseph michael foley
# Updating entry 1151
# Calling API for name:
# first_name: igor	middle_name: ivanovich	                   last_name: volkov	full_name: igor ivanovich volkov
# Updating entry 1158
# Calling API for name:
# first_name: leonid	middle_name: nikitovich	                   last_name: barabanov	full_name: leonid nikitovich barabanov
# Updating entry 1164
# Calling API for name:
# first_name: frederic	middle_name: louis	                   last_name: lizzi	full_name: frederic louis lizzi
# Updating entry 1165
# Calling API for name:
# first_name: george	middle_name: alex	                   last_name: mills	full_name: george alex mills
# Updating entry 1168
# Calling API for name:
# first_name: lawrence	middle_name: gideon	                   last_name: raisz	full_name: lawrence gideon raisz
# Updating entry 1171
# Calling API for name:
# first_name: margaret	middle_name: byrd	                   last_name: rawson	full_name: margaret byrd rawson
# Updating entry 1176
# Calling API for name:
# first_name: alexei	middle_name: borisovich	                   last_name: kaidalov	full_name: alexei borisovich kaidalov
# Updating entry 1186
# Calling API for name:
# first_name: john	middle_name: maxwell	                   last_name: cowley	full_name: john maxwell cowley
# Updating entry 1187
# Calling API for name:
# first_name: janet	middle_name: marion	                   last_name: martin	full_name: janet marion martin
# Updating entry 1192
# Calling API for name:
# first_name: jeanne	middle_name: allen	                   last_name: smith	full_name: jeanne allen smith
# Updating entry 1193
# Calling API for name:
# first_name: jeffery	middle_name: raymond	                   last_name: ede	full_name: jeffery raymond ede
# Updating entry 1194
# Calling API for name:
# first_name: johann	middle_name: christian	                   last_name: heinroth	full_name: johann christian august heinroth
# Updating entry 1195
# Calling API for name:
# first_name: john	middle_name: atherton	                   last_name: young	full_name: john atherton young
# Updating entry 1197
# Calling API for name:
# first_name: john	middle_name: frederick	                   last_name: reading	full_name: john frederick reading
# Updating entry 1198
# Calling API for name:
# first_name: john	middle_name: paton	                   last_name: erskine	full_name: john paton erskine
# Updating entry 1200
# Calling API for name:
# first_name: john	middle_name: robinson	                   last_name: pierce	full_name: john robinson pierce
# Updating entry 1204
# Calling API for name:
# first_name: jose	middle_name: juan	                   last_name: arrom	full_name: jose juan arrom
# Updating entry 1205
# Calling API for name:
# first_name: jose	middle_name: manuel	                   last_name: esteve	full_name: jose manuel esteve
# Updating entry 1206
# Calling API for name:
# first_name: jose	middle_name: maria	                   last_name: neves	full_name: jose maria neves
# Updating entry 1207
# Calling API for name:
# first_name: joseph	middle_name: periam	                   last_name: danton	full_name: joseph periam danton
# Updating entry 1209
# Calling API for name:
# first_name: julius	middle_name: erich	                   last_name: wess	full_name: julius erich wess
# Updating entry 1215
# Calling API for name:
# first_name: kenneth	middle_name: alan	                   last_name: johnson	full_name: kenneth alan johnson
# Updating entry 1216
# Calling API for name:
# first_name: kenneth	middle_name: crossley	                   last_name: mcwalter	full_name: kenneth crossley mcwalter
# Updating entry 1219
# Calling API for name:
# first_name: klaus	middle_name: dieter	                   last_name: seemann	full_name: klaus dieter seemann
# Updating entry 1226
# Calling API for name:
# first_name: leonid	middle_name: ivanovich	                   last_name: korochkin	full_name: leonid ivanovich korochkin
# Updating entry 1227
# Calling API for name:
# first_name: leslie	middle_name: alan	                   last_name: shepard	full_name: leslie alan shepard
# Updating entry 1228
# Calling API for name:
# first_name: abraham	middle_name: louis	                   last_name: levin	full_name: abraham louis levin
# Updating entry 1232
# Calling API for name:
# first_name: ludwig	middle_name: karl	                   last_name: ratschiller	full_name: ludwig karl ratschiller
# Updating entry 1234
# Calling API for name:
# first_name: luigi	middle_name: guglielmo	                   last_name: moncada	full_name: luigi guglielmo moncada
# Updating entry 1238
# Calling API for name:
# first_name: malcolm	middle_name: alexander	                   last_name: ramsay	full_name: malcolm alexander ramsay
# Updating entry 1241
# Calling API for name:
# first_name: mary	middle_name: kathleen	                   last_name: marchant	full_name: mary kathleen marchant
# Updating entry 1243
# Calling API for name:
# first_name: richard	middle_name: wesley	                   last_name: telinde	full_name: richard wesley telinde
# Updating entry 1248
# Calling API for name:
# first_name: merrick	middle_name: edward	                   last_name: abrahams	full_name: merrick edward peltier abrahams
# Updating entry 1250
# Calling API for name:
# first_name: michael	middle_name: dudley	                   last_name: sturge	full_name: michael dudley sturge
# Updating entry 1256
# Calling API for name:
# first_name: nadezhda	middle_name: borisovna	                   last_name: bolotina	full_name: nadezhda borisovna bolotina
# Updating entry 1257
# Calling API for name:
# first_name: nicholas	middle_name: john	                   last_name: mills	full_name: nicholas john mills
# Updating entry 1258
# Calling API for name:
# first_name: nikolai	middle_name: alekseevich	                   last_name: chernoplekov	full_name: nikolai alekseevich chernoplekov
# Updating entry 1263
# Calling API for name:
# first_name: james	middle_name: wardrop	                   last_name: telford	full_name: james wardrop telford
# Updating entry 1272
# Calling API for name:
# first_name: paul	middle_name: walter	                   last_name: hartl	full_name: paul walter hartl
# Updating entry 1274
# Calling API for name:
# first_name: christopher	middle_name: kevin	                   last_name: boyle	full_name: christopher kevin boyle
# Updating entry 1275
# Calling API for name:
# first_name: william	middle_name: alfred	                   last_name: read	full_name: william alfred read
# Updating entry 1278
# Calling API for name:
# first_name: leon	middle_name: anthony	                   last_name: fennessy	full_name: leon anthony fennessy
# Updating entry 1281
# Calling API for name:
# first_name: rosalind	middle_name: hauk	                   last_name: kornfeld	full_name: rosalind hauk kornfeld
# Updating entry 1287
# Calling API for name:
# first_name: friedrich	middle_name: wilhelm	                   last_name: ahnefeld	full_name: friedrich wilhelm ahnefeld
# Updating entry 1292
# Calling API for name:
# first_name: oleg	middle_name: aleksandrovich	                   last_name: petrii	full_name: oleg aleksandrovich petrii
# Updating entry 1293
# Calling API for name:
# first_name: oscar	middle_name: davis	                   last_name: ratnoff	full_name: oscar davis ratnoff
# Updating entry 1297
# Calling API for name:
# first_name: otto	middle_name: wilhelm	                   last_name: madelung	full_name: otto wilhelm madelung
# Updating entry 1301
# Calling API for name:
# first_name: paul	middle_name: dudley	                   last_name: white	full_name: paul dudley white
# Updating entry 1302
# Calling API for name:
# first_name: pauline	middle_name: atherton	                   last_name: cochrane	full_name: pauline atherton cochrane
# Updating entry 1303
# Calling API for name:
# first_name: pax	middle_name: allan	                   last_name: chingawale	full_name: pax allan chingawale
# Updating entry 1305
# Calling API for name:
# first_name: claude	middle_name: michel	                   last_name: cluny	full_name: claude michel cluny
# Updating entry 1306
# Calling API for name:
# first_name: peter	middle_name: clay	                   last_name: eklund	full_name: peter clay eklund
# Updating entry 1307
# Calling API for name:
# first_name: peter	middle_name: edgerly	                   last_name: firchow	full_name: peter edgerly firchow
# Updating entry 1308
# Calling API for name:
# first_name: petrovsky	middle_name: arthur	                   last_name: vladimirovich	full_name: petrovsky arthur vladimirovich
# Updating entry 1309
# Calling API for name:
# first_name: philip	middle_name: john	                   last_name: kingston	full_name: philip john kingston
# Updating entry 1311
# Calling API for name:
# first_name: phyllis	middle_name: louisa	                   last_name: botha	full_name: phyllis louisa botha
# Updating entry 1312
# Calling API for name:
# first_name: pieter	middle_name: joost	                   last_name: goedhart	full_name: pieter joost goedhart
# Updating entry 1314
# Calling API for name:
# first_name: ignaz	middle_name: joseph	                   last_name: pleyel	full_name: ignaz joseph pleyel
# Updating entry 1325
# Calling API for name:
# first_name: phillip	middle_name: vallentine	                   last_name: tobias	full_name: phillip vallentine tobias
# Updating entry 1331
# Calling API for name:
# first_name: michael	middle_name: alan	                   last_name: cooper	full_name: michael alan ralph cooper
# Updating entry 1363
# Calling API for name:
# first_name: richard	middle_name: charles	                   last_name: pfister	full_name: richard charles pfister
# Updating entry 1364
# Calling API for name:
# first_name: richard	middle_name: lee	                   last_name: hester	full_name: richard lee hester
# Updating entry 1366
# Calling API for name:
# first_name: richard	middle_name: penrose	                   last_name: schmidt	full_name: richard penrose schmidt
# Updating entry 1367
# Calling API for name:
# first_name: richard	middle_name: starr	                   last_name: ross	full_name: richard starr ross
# Updating entry 1368
# Calling API for name:
# first_name: richard	middle_name: thomas	                   last_name: robiscoe	full_name: richard thomas robiscoe
# Updating entry 1369
# Calling API for name:
# first_name: thomas	middle_name: jefferson	                   last_name: jarrell	full_name: thomas jefferson jarrell
# Updating entry 1371
# Calling API for name:
# first_name: roselyn	middle_name: adele	                   last_name: walker	full_name: roselyn adele walker
# Updating entry 1372
# Calling API for name:
# first_name: ross	middle_name: galbraith	                   last_name: mitchell	full_name: ross galbraith mitchell
# Updating entry 1378
# Calling API for name:
# first_name: samuel	middle_name: roger	                   last_name: rimmer	full_name: samuel roger rimmer
# Updating entry 1379
# Calling API for name:
# first_name: mary	middle_name: jo	                   last_name: nye	full_name: mary jo nye
# Updating entry 1382
# Calling API for name:
# first_name: sergei	middle_name: anatolyevich	                   last_name: starostin	full_name: sergei anatolyevich starostin
# Updating entry 1383
# Calling API for name:
# first_name: sergei	middle_name: petrovich	                   last_name: denisov	full_name: sergei petrovich denisov
# Updating entry 1398
# Calling API for name:
# first_name: paul	middle_name: peter	                   last_name: rosen	full_name: paul peter rosen
# Updating entry 1404
# Calling API for name:
# first_name: guida	middle_name: mary	                   last_name: crowley	full_name: guida mary crowley
# Updating entry 1406
# Calling API for name:
# first_name: thomas	middle_name: joseph	                   last_name: delaney	full_name: thomas joseph delaney
# Updating entry 1407
# Calling API for name:
# first_name: thomas	middle_name: vincent	                   last_name: santulli	full_name: thomas vincent santulli
# Updating entry 1416
# Calling API for name:
# first_name: umesh	middle_name: chandra	                   last_name: pati	full_name: umesh chandra pati
# Updating entry 1418
# Calling API for name:
# first_name: vasilii	middle_name: zakharovich	                   last_name: vlasov	full_name: vasilii zakharovich vlasov
# Updating entry 1419
# Calling API for name:
# first_name: viktor	middle_name: matveevich	                   last_name: bukhshtaber	full_name: viktor matveevich bukhshtaber
# Updating entry 1420
# Calling API for name:
# first_name: vladimir	middle_name: leonidovitch	                   last_name: doshchitsyn	full_name: vladimir leonidovitch doshchitsyn
# Updating entry 1421
# Calling API for name:
# first_name: vladimir	middle_name: mikhailovich	                   last_name: fridkin	full_name: vladimir mikhailovich fridkin
# Updating entry 1422
# Calling API for name:
# first_name: william	middle_name: daniel	                   last_name: sudia	full_name: william daniel sudia
# Updating entry 1423
# Calling API for name:
# first_name: walter	middle_name: thomas	                   last_name: morgan	full_name: walter thomas james morgan
# Updating entry 1424
# Calling API for name:
# first_name: william	middle_name: craig	                   last_name: reynolds	full_name: william craig reynolds
# Updating entry 1425
# Calling API for name:
# first_name: william	middle_name: glenn	                   last_name: sly	full_name: william glenn sly
# Updating entry 1426
# Calling API for name:
# first_name: william	middle_name: joseph	                   last_name: reals	full_name: william joseph reals
# Updating entry 1428
# Calling API for name:
# first_name: william	middle_name: sprott	                   last_name: pollitzer	full_name: william sprott pollitzer
# Updating entry 1431
# Calling API for name:
# first_name: yakov	middle_name: zalmanovich	                   last_name: tsypkin	full_name: yakov zalmanovich tsypkin
# Updating entry 1435
# Calling API for name:
# first_name: yury	middle_name: akhmetovich	                   last_name: aminov	full_name: yury akhmetovich aminov
# Updating entry 1436
# Calling API for name:
# first_name: zhores	middle_name: ivanovich	                   last_name: alferov	full_name: zhores ivanovich alferov
# Updating entry 1447
# Calling API for name:
# first_name: jane	middle_name: ruth	                   last_name: aceng	full_name: jane ruth aceng
# Updating entry 1466
# Calling API for name:
# first_name: lorraine	middle_name: niño	                   last_name: alexander	full_name: lorraine niño alexander
# Updating entry 1469
# Calling API for name:
# first_name: graziella	middle_name: badin	                   last_name: aliti	full_name: graziella badin aliti
# Updating entry 1485
# Calling API for name:
# first_name: johan	middle_name: hviid	                   last_name: andersen	full_name: johan hviid andersen
# Updating entry 1536
# Calling API for name:
# first_name: josé	middle_name: augusto	                   last_name: barreto-filho	full_name: josé augusto barreto-filho
# Updating entry 1614
# Calling API for name:
# first_name: kaare	middle_name: harald	                   last_name: bønaa	full_name: kaare harald bønaa
# Updating entry 1698
# Calling API for name:
# first_name: henry	middle_name: lik-yuen	                   last_name: chan	full_name: henry lik-yuen chan
# Updating entry 1702
# Calling API for name:
# first_name: kit	middle_name: yee	                   last_name: chan	full_name: kit yee chan
# Updating entry 1726
# Calling API for name:
# first_name: elaine	middle_name: w-t	                   last_name: chong	full_name: elaine w-t chong
# Updating entry 1728
# Calling API for name:
# first_name: mahbub	middle_name: elahi	                   last_name: chowdhury	full_name: mahbub elahi chowdhury
# Updating entry 1838
# Calling API for name:
# first_name: gian	middle_name: luca	                   last_name: di tanna	full_name: gian luca di tanna
# Updating entry 1842
# Calling API for name:
# first_name: binh	middle_name: an	                   last_name: diep	full_name: binh an diep
# Updating entry 2010
# Calling API for name:
# first_name: tara	middle_name: bridget	                   last_name: giblin	full_name: tara bridget giblin
# Updating entry 2090
# Calling API for name:
# first_name: chanita	middle_name: hughes	                   last_name: halbert	full_name: chanita hughes halbert
# Updating entry 2218
# Calling API for name:
# first_name: poul	middle_name: harboe	                   last_name: jacobsen	full_name: poul harboe jacobsen
# Updating entry 2235
# Calling API for name:
# first_name: sun	middle_name: ha	                   last_name: jee	full_name: sun ha jee
# Updating entry 2281
# Calling API for name:
# first_name: young	middle_name: ae	                   last_name: kang	full_name: young ae kang
# Updating entry 2282
# Calling API for name:
# first_name: jae	middle_name: hee	                   last_name: kang	full_name: jae hee kang
# Updating entry 2283
# Calling API for name:
# first_name: liew	middle_name: woei	                   last_name: kang	full_name: liew woei kang
# Updating entry 2317
# Calling API for name:
# first_name: mishal	middle_name: sameer	                   last_name: khan	full_name: mishal sameer khan
# Updating entry 2322
# Calling API for name:
# first_name: hae	middle_name: jin	                   last_name: kim	full_name: hae jin kim
# Updating entry 2379
# Calling API for name:
# first_name: geeta	middle_name: trilok	                   last_name: kumar	full_name: geeta trilok kumar
# Updating entry 2439
# Calling API for name:
# first_name: ka	middle_name: lau	                   last_name: leung	full_name: ka lau leung
# Updating entry 2489
# Calling API for name:
# first_name: yoon	middle_name: kong	                   last_name: loke	full_name: yoon kong loke
# Updating entry 2547
# Calling API for name:
# first_name: maría	middle_name: elena	                   last_name: martínez	full_name: maría elena martínez
# Updating entry 2571
# Calling API for name:
# first_name: mary	middle_name: mcgrae	                   last_name: mcdermott	full_name: mary mcgrae mcdermott
# Updating entry 2670
# Calling API for name:
# first_name: ann	middle_name: marie	                   last_name: navar-boggan	full_name: ann marie navar-boggan
# Updating entry 2691
# Calling API for name:
# first_name: linda	middle_name: olivia	                   last_name: nichols	full_name: linda olivia nichols
# Updating entry 2729
# Calling API for name:
# first_name: marcus	middle_name: eng	                   last_name: ong	full_name: marcus eng ong
# Updating entry 2731
# Calling API for name:
# first_name: jan	middle_name: jelrik	                   last_name: oosterheert	full_name: jan jelrik oosterheert
# Updating entry 2757
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: parienti	full_name: jean jacques parienti
# Updating entry 2786
# Calling API for name:
# first_name: john	middle_name: victor	                   last_name: peter	full_name: john victor peter
# Updating entry 2805
# Calling API for name:
# first_name: rafael	middle_name: zambelli	                   last_name: pinto	full_name: rafael zambelli pinto
# Updating entry 2830
# Calling API for name:
# first_name: adria	middle_name: tassy	                   last_name: prosser	full_name: adria tassy prosser
# Updating entry 2921
# Calling API for name:
# first_name: hanna	middle_name: bloomfield	                   last_name: rubins	full_name: hanna bloomfield rubins
# Updating entry 2925
# Calling API for name:
# first_name: luis	middle_name: miguel	                   last_name: ruilope	full_name: luis miguel ruilope
# Updating entry 2949
# Calling API for name:
# first_name: charles	middle_name: marc	                   last_name: samama	full_name: charles marc samama
# Updating entry 2965
# Calling API for name:
# first_name: elizabeth	middle_name: sumamo	                   last_name: schellenberg	full_name: elizabeth sumamo schellenberg
# Updating entry 3031
# Calling API for name:
# first_name: jacqueline	middle_name: baras	                   last_name: shreibati	full_name: jacqueline baras shreibati
# Updating entry 3055
# Calling API for name:
# first_name: håvard	middle_name: ove	                   last_name: skjerven	full_name: håvard ove skjerven
# Updating entry 3071
# Calling API for name:
# first_name: henrik	middle_name: toft	                   last_name: sørensen	full_name: henrik toft sørensen
# Updating entry 3085
# Calling API for name:
# first_name: philippe	middle_name: gabriel	                   last_name: steg	full_name: philippe gabriel steg
# Updating entry 3089
# Calling API for name:
# first_name: henry	middle_name: thomas	                   last_name: stelfox	full_name: henry thomas stelfox
# Updating entry 3147
# Calling API for name:
# first_name: milena	middle_name: gurgel	                   last_name: teles	full_name: milena gurgel teles
# Updating entry 3292
# Calling API for name:
# first_name: chi	middle_name: pang	                   last_name: wen	full_name: chi pang wen
# Updating entry 3313
# Calling API for name:
# first_name: renda	middle_name: soylemez	                   last_name: wiener	full_name: renda soylemez wiener
# Updating entry 3336
# Calling API for name:
# first_name: tien	middle_name: yin	                   last_name: wong	full_name: tien yin wong
# Updating entry 3362
# Calling API for name:
# first_name: kol	middle_name: jia	                   last_name: yong	full_name: kol jia yong
# Updating entry 3363
# Calling API for name:
# first_name: marianne	middle_name: ulcickas	                   last_name: yood	full_name: marianne ulcickas yood
# Updating entry 3389
# Calling API for name:
# first_name: ha	middle_name: lim	                   last_name: oh	full_name: ha lim oh
# Updating entry 3393
# Calling API for name:
# first_name: shiao	middle_name: tong	                   last_name: kong	full_name: shiao tong kong
# Updating entry 3397
# Calling API for name:
# first_name: moon	middle_name: jeong	                   last_name: chang	full_name: moon jeong chang
# Updating entry 3401
# Calling API for name:
# first_name: hae	middle_name: yun	                   last_name: nam	full_name: hae yun nam
# Updating entry 3417
# Calling API for name:
# first_name: ji	middle_name: in	                   last_name: kang	full_name: ji in kang
# Updating entry 3420
# Calling API for name:
# first_name: marize	middle_name: pereira	                   last_name: miagostovich	full_name: marize pereira miagostovich
# Updating entry 3425
# Calling API for name:
# first_name: sonay	middle_name: incesoy	                   last_name: ozdemir	full_name: sonay incesoy ozdemir
# Updating entry 3431
# Calling API for name:
# first_name: sy	middle_name: jye	                   last_name: leu	full_name: sy jye leu
# Updating entry 3446
# Calling API for name:
# first_name: nae	middle_name: choon	                   last_name: yoo	full_name: nae choon yoo
# Updating entry 3451
# Calling API for name:
# first_name: darvi	middle_name: de	                   last_name: andre	full_name: darvi de andre
# Bad HTTP status code: 502 Server Error: Bad Gateway for url: http://rc50-api.nameapi.org/rest/v5.0/genderizer/persongenderizer?apiKey=725a6a1ddf0d0f16f7dc3a6a73a9ac5b-user1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-cc5d6fe69839> in <module>()
# ----> 1 evaluatorNA.update_selected_records(to_update_indices)
#
# /Users/lucsan/Work/genderbias/name_gender_inference/evaluator.py in update_selected_records(self, indices)
#     197                                                          row.last_name, row.full_name))
#     198             api_resp = self._process_row_for_api_call(row)
# --> 199             api_resp = {'api_{}'.format(k): v for (k,v) in api_resp.items()}
#     200             api_resp['gender_infered'] = self.gender_response_mapping[api_resp['api_gender']]
#     201             for (k, v) in api_resp.items():
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
to_update_remaining_indices = [ind for ind in to_update_indices if ind>3446]
len(to_update_remaining_indices)
# Out:
# 638

# %%
evaluatorNA.update_selected_records(to_update_remaining_indices)
# Out:
# Updating entry 3451
# Calling API for name:
# first_name: darvi	middle_name: de	                   last_name: andre	full_name: darvi de andre
# Updating entry 3453
# Calling API for name:
# first_name: dulcineia	middle_name: martins	                   last_name: de albuquerque	full_name: dulcineia martins de albuquerque
# Updating entry 3455
# Calling API for name:
# first_name: siaw	middle_name: lin	                   last_name: chan	full_name: siaw lin chan
# Updating entry 3457
# Calling API for name:
# first_name: jung	middle_name: seek	                   last_name: yang	full_name: jung seek yang
# Updating entry 3462
# Calling API for name:
# first_name: hae	middle_name: rang	                   last_name: chung	full_name: hae rang chung
# Updating entry 3471
# Calling API for name:
# first_name: youn	middle_name: ju	                   last_name: choi	full_name: youn ju choi
# Updating entry 3478
# Calling API for name:
# first_name: marilia	middle_name: germanos	                   last_name: castro	full_name: marilia germanos castro
# Updating entry 3485
# Calling API for name:
# first_name: seon	middle_name: kyoung	                   last_name: an	full_name: seon kyoung an
# Updating entry 3497
# Calling API for name:
# first_name: hacer	middle_name: kuzu	                   last_name: okur	full_name: hacer kuzu okur
# Updating entry 3505
# Calling API for name:
# first_name: se	middle_name: na	                   last_name: kim	full_name: se na kim
# Updating entry 3508
# Calling API for name:
# first_name: ji	middle_name: soon	                   last_name: kim	full_name: ji soon kim
# Updating entry 3519
# Calling API for name:
# first_name: maysa	middle_name: de	                   last_name: leite	full_name: maysa de leite
# Updating entry 3523
# Calling API for name:
# first_name: svava	middle_name: osk	                   last_name: jonsdottir	full_name: svava osk jonsdottir
# Updating entry 3530
# Calling API for name:
# first_name: duk	middle_name: yoon	                   last_name: kim	full_name: duk yoon kim
# Updating entry 3538
# Calling API for name:
# first_name: jung	middle_name: sug	                   last_name: lee	full_name: jung sug lee
# Updating entry 3540
# Calling API for name:
# first_name: elisangela	middle_name: franciscon	                   last_name: guimaro dias	full_name: elisangela franciscon guimaro dias
# Updating entry 3547
# Calling API for name:
# first_name: azizeh	middle_name: mitra	                   last_name: yousefi	full_name: azizeh mitra yousefi
# Updating entry 3553
# Calling API for name:
# first_name: roozbeh	middle_name: javad	                   last_name: kalbasi	full_name: roozbeh javad kalbasi
# Updating entry 3595
# Calling API for name:
# first_name: puay	middle_name: hoon	                   last_name: tan	full_name: puay hoon tan
# Updating entry 3598
# Calling API for name:
# first_name: ahter	middle_name: dilsad	                   last_name: sanlioglu	full_name: ahter dilsad sanlioglu
# Updating entry 3602
# Calling API for name:
# first_name: moy	middle_name: fong	                   last_name: chen	full_name: moy fong chen
# Updating entry 3606
# Calling API for name:
# first_name: renny	middle_name: kurnia	                   last_name: hadiaty	full_name: renny kurnia hadiaty
# Updating entry 3607
# Calling API for name:
# first_name: koon	middle_name: gee	                   last_name: neoh	full_name: koon gee neoh
# Updating entry 3610
# Calling API for name:
# first_name: yoon	middle_name: ju	                   last_name: song	full_name: yoon ju song
# Updating entry 3625
# Calling API for name:
# first_name: gulsen	middle_name: tukenmez	                   last_name: demirci	full_name: gulsen tukenmez demirci
# Updating entry 3634
# Calling API for name:
# first_name: kyoung	middle_name: hee	                   last_name: nam	full_name: kyoung hee nam
# Updating entry 3637
# Calling API for name:
# first_name: ju	middle_name: dong	                   last_name: lee	full_name: ju dong lee
# Updating entry 3647
# Calling API for name:
# first_name: kyu	middle_name: han	                   last_name: kim	full_name: kyu han kim
# Updating entry 3648
# Calling API for name:
# first_name: jhi	middle_name: joung	                   last_name: wang	full_name: jhi joung wang
# Updating entry 3674
# Calling API for name:
# first_name: beg	middle_name: hab	                   last_name: kim	full_name: beg hab kim
# Updating entry 3681
# Calling API for name:
# first_name: mou	middle_name: sheng	                   last_name: liu	full_name: mou sheng liu
# Updating entry 3687
# Calling API for name:
# first_name: jeong	middle_name: seop	                   last_name: sim	full_name: jeong seop sim
# Updating entry 3693
# Calling API for name:
# first_name: shyh	middle_name: yuan	                   last_name: lee	full_name: shyh yuan lee
# Updating entry 3699
# Calling API for name:
# first_name: ok	middle_name: keun	                   last_name: song	full_name: ok keun song
# Updating entry 3704
# Calling API for name:
# first_name: seung	middle_name: joo	                   last_name: kim	full_name: seung joo kim
# Updating entry 3719
# Calling API for name:
# first_name: mor	middle_name: mordechai	                   last_name: peretz	full_name: mor mordechai peretz
# Updating entry 3725
# Calling API for name:
# first_name: hyun	middle_name: kuk	                   last_name: park	full_name: hyun kuk park
# Updating entry 3755
# Calling API for name:
# first_name: seog	middle_name: joo	                   last_name: kim	full_name: seog joo kim
# Updating entry 3762
# Calling API for name:
# first_name: sameh	middle_name: saad	                   last_name: ali	full_name: sameh saad ali
# Updating entry 3770
# Calling API for name:
# first_name: cihan	middle_name: cem	                   last_name: gurbuz	full_name: cihan cem gurbuz
# Updating entry 3777
# Calling API for name:
# first_name: jorim	middle_name: sousa	                   last_name: das virgens filho	full_name: jorim sousa das virgens filho
# Updating entry 3782
# Calling API for name:
# first_name: hwan	middle_name: you	                   last_name: chang	full_name: hwan you chang
# Updating entry 3794
# Calling API for name:
# first_name: choon	middle_name: hua	                   last_name: thng	full_name: choon hua thng
# Updating entry 3795
# Calling API for name:
# first_name: woel	middle_name: kyu	                   last_name: ha	full_name: woel kyu ha
# Updating entry 3796
# Calling API for name:
# first_name: won	middle_name: tae	                   last_name: kwon	full_name: won tae kwon
# Updating entry 3799
# Calling API for name:
# first_name: ding	middle_name: ming	                   last_name: wang	full_name: ding ming wang
# Updating entry 3807
# Calling API for name:
# first_name: hang	middle_name: rae	                   last_name: kim	full_name: hang rae kim
# Updating entry 3818
# Calling API for name:
# first_name: shing	middle_name: shun	                   last_name: to	full_name: shing shun to
# Updating entry 3820
# Calling API for name:
# first_name: augusciak	middle_name: duma	                   last_name: aleksandra	full_name: augusciak duma aleksandra
# Updating entry 3837
# Calling API for name:
# first_name: sok	middle_name: kyu	                   last_name: lee	full_name: sok kyu lee
# Updating entry 3844
# Calling API for name:
# first_name: ik	middle_name: jin	                   last_name: kim	full_name: ik jin kim
# Updating entry 3858
# Calling API for name:
# first_name: boon	middle_name: chye	                   last_name: ching	full_name: boon chye ching
# Updating entry 3878
# Calling API for name:
# first_name: zhang	middle_name: wei	                   last_name: song	full_name: zhang wei song
# Updating entry 3892
# Calling API for name:
# first_name: wing	middle_name: leong	                   last_name: teo	full_name: wing leong teo
# Updating entry 3910
# Calling API for name:
# first_name: nor	middle_name: eddine	                   last_name: sounni	full_name: nor eddine sounni
# Updating entry 3914
# Calling API for name:
# first_name: hoang	middle_name: viet	                   last_name: nguyen	full_name: hoang viet nguyen
# Updating entry 3915
# Calling API for name:
# first_name: chilla	middle_name: malla	                   last_name: reddy	full_name: chilla malla reddy
# Updating entry 3925
# Calling API for name:
# first_name: kyu	middle_name: hwang	                   last_name: yeon	full_name: kyu hwang yeon
# Updating entry 3936
# Calling API for name:
# first_name: hyung	middle_name: joun	                   last_name: yoo	full_name: hyung joun yoo
# Updating entry 3961
# Calling API for name:
# first_name: woon	middle_name: khiong	                   last_name: chan	full_name: woon khiong chan
# Updating entry 3992
# Calling API for name:
# first_name: hyun	middle_name: myung	                   last_name: jang	full_name: hyun myung jang
# Updating entry 3997
# Calling API for name:
# first_name: jeong	middle_name: gu	                   last_name: lee	full_name: jeong gu lee
# Updating entry 3999
# Calling API for name:
# first_name: hyun	middle_name: gyoo	                   last_name: shin	full_name: hyun gyoo shin
# Updating entry 4002
# Calling API for name:
# first_name: seyed	middle_name: abbas	                   last_name: shojaosadati	full_name: seyed abbas shojaosadati
# Updating entry 4003
# Calling API for name:
# first_name: myeong	middle_name: ok	                   last_name: kim	full_name: myeong ok kim
# Updating entry 4019
# Calling API for name:
# first_name: boon	middle_name: hian	                   last_name: loo	full_name: boon hian loo
# Updating entry 4022
# Calling API for name:
# first_name: en	middle_name: tang	                   last_name: kang	full_name: en tang kang
# Updating entry 4024
# Calling API for name:
# first_name: kyu	middle_name: tek	                   last_name: park	full_name: kyu tek park
# Updating entry 4029
# Calling API for name:
# first_name: chorng	middle_name: haur	                   last_name: sow	full_name: chorng haur sow
# Updating entry 4043
# Calling API for name:
# first_name: sze	middle_name: ki	                   last_name: luk	full_name: sze ki luk
# Updating entry 4050
# Calling API for name:
# first_name: edson	middle_name: hyidu	                   last_name: mizobutsi	full_name: edson hyidu mizobutsi
# Updating entry 4053
# Calling API for name:
# first_name: jee	middle_name: hian	                   last_name: tan	full_name: jee hian tan
# Updating entry 4075
# Calling API for name:
# first_name: tai	middle_name: hyoung	                   last_name: cho	full_name: tai hyoung cho
# Updating entry 4085
# Calling API for name:
# first_name: suk	middle_name: in	                   last_name: noh	full_name: suk in noh
# Updating entry 4092
# Calling API for name:
# first_name: hann	middle_name: chorng	                   last_name: kuo	full_name: hann chorng kuo
# Updating entry 4093
# Calling API for name:
# first_name: kyung	middle_name: sub	                   last_name: kim	full_name: kyung sub kim
# Updating entry 4097
# Calling API for name:
# first_name: jong	middle_name: hyeon	                   last_name: peck	full_name: jong hyeon peck
# Updating entry 4107
# Calling API for name:
# first_name: kurinchi	middle_name: selvan	                   last_name: gurusamy	full_name: kurinchi selvan gurusamy
# Updating entry 4113
# Calling API for name:
# first_name: jeong	middle_name: zoo	                   last_name: lee	full_name: jeong zoo lee
# Updating entry 4139
# Calling API for name:
# first_name: abolfazl	middle_name: (kouros)	                   last_name: mohammadian	full_name: abolfazl (kouros) mohammadian
# Updating entry 4144
# Calling API for name:
# first_name: ik	middle_name: hyun	                   last_name: cho	full_name: ik hyun cho
# Updating entry 4172
# Calling API for name:
# first_name: won	middle_name: seung	                   last_name: cho	full_name: won seung cho
# Updating entry 4175
# Calling API for name:
# first_name: jung	middle_name: bong	                   last_name: kim	full_name: jung bong kim
# Updating entry 4198
# Calling API for name:
# first_name: mee	middle_name: ree	                   last_name: kim	full_name: mee ree kim
# Updating entry 4200
# Calling API for name:
# first_name: sheau	middle_name: chiou	                   last_name: chao	full_name: sheau chiou chao
# Updating entry 4202
# Calling API for name:
# first_name: gee	middle_name: yeng	                   last_name: tien	full_name: gee yeng tien
# Updating entry 4214
# Calling API for name:
# first_name: soo	middle_name: muk	                   last_name: cho	full_name: soo muk cho
# Updating entry 4221
# Calling API for name:
# first_name: chew	middle_name: wun	                   last_name: wu	full_name: chew wun wu
# Updating entry 4236
# Calling API for name:
# first_name: mahboobe	middle_name: ghorbani	                   last_name: ravandi	full_name: mahboobe ghorbani ravandi
# Updating entry 4253
# Calling API for name:
# first_name: do	middle_name: suk	                   last_name: han	full_name: do suk han
# Updating entry 4262
# Calling API for name:
# first_name: jye	middle_name: lin	                   last_name: hsu	full_name: jye lin hsu
# Updating entry 4265
# Calling API for name:
# first_name: chuti	middle_name: on	                   last_name: kanwatanakid-savini	full_name: chuti on kanwatanakid-savini
# Updating entry 4276
# Calling API for name:
# first_name: biing	middle_name: teo	                   last_name: wong	full_name: biing teo wong
# Updating entry 4278
# Calling API for name:
# first_name: maria	middle_name: grazia	                   last_name: fumo	full_name: maria grazia fumo
# Updating entry 4279
# Calling API for name:
# first_name: elida	middle_name: nora	                   last_name: ferri	full_name: elida nora ferri
# Updating entry 4294
# Calling API for name:
# first_name: anne	middle_name: laure	                   last_name: jarnoux	full_name: anne laure jarnoux
# Updating entry 4305
# Calling API for name:
# first_name: anabela	middle_name: bernardes	                   last_name: da silva	full_name: anabela bernardes da silva
# Updating entry 4306
# Calling API for name:
# first_name: susana	middle_name: de	                   last_name: araujo	full_name: susana de araujo
# Updating entry 4311
# Calling API for name:
# first_name: young	middle_name: mi	                   last_name: park	full_name: young mi park
# Updating entry 4314
# Calling API for name:
# first_name: silvia	middle_name: helena	                   last_name: prado bettini	full_name: silvia helena prado bettini
# Updating entry 4325
# Calling API for name:
# first_name: hsiu	middle_name: fung	                   last_name: cheng	full_name: hsiu fung cheng
# Updating entry 4340
# Calling API for name:
# first_name: gui	middle_name: li	                   last_name: wang	full_name: gui li wang
# Updating entry 4345
# Calling API for name:
# first_name: fang	middle_name: fang	                   last_name: dang	full_name: fang fang dang
# Updating entry 4349
# Calling API for name:
# first_name: fabiana	middle_name: fioretti	                   last_name: martins ferreira	full_name: fabiana fioretti martins ferreira
# Updating entry 4350
# Calling API for name:
# first_name: carmen	middle_name: baur	                   last_name: vieira	full_name: carmen baur vieira
# Updating entry 4351
# Calling API for name:
# first_name: patricia	middle_name: aparecida	                   last_name: fontes vieira	full_name: patricia aparecida fontes vieira
# Updating entry 4353
# Calling API for name:
# first_name: claudia	middle_name: regina	                   last_name: dias-areira	full_name: claudia regina dias-areira
# Updating entry 4371
# Calling API for name:
# first_name: ching	middle_name: hsia	                   last_name: hung	full_name: ching hsia hung
# Updating entry 4378
# Calling API for name:
# first_name: maria	middle_name: teresa	                   last_name: de magistris	full_name: maria teresa de magistris
# Updating entry 4379
# Calling API for name:
# first_name: so	middle_name: young	                   last_name: yoo	full_name: so young yoo
# Updating entry 4386
# Calling API for name:
# first_name: carol	middle_name: bishop	                   last_name: mills	full_name: carol bishop mills
# Updating entry 4400
# Calling API for name:
# first_name: mary	middle_name: kay	                   last_name: crepinsek	full_name: mary kay crepinsek
# Updating entry 4405
# Calling API for name:
# first_name: gordana	middle_name: buljan	                   last_name: flander	full_name: gordana buljan flander
# Updating entry 4406
# Calling API for name:
# first_name: ana	middle_name: cristina	                   last_name: de moraes	full_name: ana cristina de moraes
# Updating entry 4407
# Calling API for name:
# first_name: georgina	middle_name: catherine	                   last_name: hughes	full_name: georgina catherine hughes
# Updating entry 4423
# Calling API for name:
# first_name: theresa	middle_name: sinicrope	                   last_name: talley	full_name: theresa sinicrope talley
# Updating entry 4434
# Calling API for name:
# first_name: mary	middle_name: anne	                   last_name: simpson	full_name: mary anne simpson
# Updating entry 4437
# Calling API for name:
# first_name: marcela	middle_name: rosana	                   last_name: da silva santos	full_name: marcela rosana da silva santos
# Updating entry 4439
# Calling API for name:
# first_name: natasa	middle_name: zabukovec	                   last_name: logar	full_name: natasa zabukovec logar
# Updating entry 4445
# Calling API for name:
# first_name: rita	middle_name: annoni	                   last_name: manghi	full_name: rita annoni manghi
# Updating entry 4452
# Calling API for name:
# first_name: ann	middle_name: christine	                   last_name: ehlis	full_name: ann christine ehlis
# Updating entry 4453
# Calling API for name:
# first_name: aylin	middle_name: fidan	                   last_name: korcum	full_name: aylin fidan korcum
# Updating entry 4459
# Calling API for name:
# first_name: sara	middle_name: fisher	                   last_name: ellison	full_name: sara fisher ellison
# Updating entry 4467
# Calling API for name:
# first_name: clarice	middle_name: nunes	                   last_name: dias	full_name: clarice nunes dias
# Updating entry 4505
# Calling API for name:
# first_name: amy	middle_name: joan	                   last_name: ham	full_name: amy joan ham
# Updating entry 4509
# Calling API for name:
# first_name: laura	middle_name: lowe	                   last_name: furge	full_name: laura lowe furge
# Updating entry 4512
# Calling API for name:
# first_name: min	middle_name: kyoung	                   last_name: kim	full_name: min kyoung kim
# Updating entry 4521
# Calling API for name:
# first_name: mary	middle_name: ann	                   last_name: dombrink-kurtzman	full_name: mary ann dombrink-kurtzman
# Updating entry 4523
# Calling API for name:
# first_name: ella	middle_name: fung	                   last_name: jones	full_name: ella fung jones
# Updating entry 4524
# Calling API for name:
# first_name: mei	middle_name: hsiu	                   last_name: pan	full_name: mei hsiu pan
# Updating entry 4552
# Calling API for name:
# first_name: shiow	middle_name: ling	                   last_name: lee	full_name: shiow ling lee
# Updating entry 4588
# Calling API for name:
# first_name: erika	middle_name: cristina	                   last_name: pavarina	full_name: erika cristina pavarina
# Updating entry 4589
# Calling API for name:
# first_name: isis	middle_name: serrano	                   last_name: silva	full_name: isis serrano silva
# Updating entry 4601
# Calling API for name:
# first_name: fernanda	middle_name: rodrigues	                   last_name: fernandes	full_name: fernanda rodrigues fernandes
# Updating entry 4604
# Calling API for name:
# first_name: kay	middle_name: tee	                   last_name: khaw	full_name: kay tee khaw
# Updating entry 4615
# Calling API for name:
# first_name: vera	middle_name: helen	                   last_name: rees	full_name: vera helen rees
# Updating entry 4632
# Calling API for name:
# first_name: flavia	middle_name: de	                   last_name: alves	full_name: flavia de alves
# Updating entry 4641
# Calling API for name:
# first_name: eunice	middle_name: maia	                   last_name: de andrade	full_name: eunice maia de andrade
# Updating entry 4644
# Calling API for name:
# first_name: marie	middle_name: louise	                   last_name: fjallskog	full_name: marie louise fjallskog
# Updating entry 4647
# Calling API for name:
# first_name: trine	middle_name: lembrecht	                   last_name: jorgensen	full_name: trine lembrecht jorgensen
# Updating entry 4656
# Calling API for name:
# first_name: xiao	middle_name: li	                   last_name: huang	full_name: xiao li huang
# Updating entry 4677
# Calling API for name:
# first_name: maria	middle_name: rocio	                   last_name: martinez-torres	full_name: maria rocio martinez-torres
# Updating entry 4679
# Calling API for name:
# first_name: li	middle_name: juan	                   last_name: he	full_name: li juan he
# Updating entry 4695
# Calling API for name:
# first_name: nicola	middle_name: ursula	                   last_name: zitzmann	full_name: nicola ursula zitzmann
# Updating entry 4697
# Calling API for name:
# first_name: renata	middle_name: pereira	                   last_name: de sousa barbosa	full_name: renata pereira de sousa barbosa
# Updating entry 4698
# Calling API for name:
# first_name: maria	middle_name: julie	                   last_name: kvetny	full_name: maria julie kvetny
# Updating entry 4700
# Calling API for name:
# first_name: judith	middle_name: lee	                   last_name: smith	full_name: judith lee smith
# Updating entry 4714
# Calling API for name:
# first_name: juliana	middle_name: celia	                   last_name: denadai	full_name: juliana celia denadai
# Updating entry 4715
# Calling API for name:
# first_name: cibele	middle_name: regina	                   last_name: de souza kruliski	full_name: cibele regina de souza kruliski
# Updating entry 4728
# Calling API for name:
# first_name: paula	middle_name: durante	                   last_name: andrade	full_name: paula durante andrade
# Updating entry 4729
# Calling API for name:
# first_name: angelica	middle_name: martins	                   last_name: batista	full_name: angelica martins batista
# Updating entry 4739
# Calling API for name:
# first_name: ivy	middle_name: lynn	                   last_name: bourgeault	full_name: ivy lynn bourgeault
# Updating entry 4748
# Calling API for name:
# first_name: marie	middle_name: line	                   last_name: jacquemont	full_name: marie line jacquemont
# Updating entry 4784
# Calling API for name:
# first_name: jin	middle_name: mei	                   last_name: zhang	full_name: jin mei zhang
# Updating entry 4790
# Calling API for name:
# first_name: soo	middle_name: young	                   last_name: park	full_name: soo young park
# Updating entry 4799
# Calling API for name:
# first_name: hatice	middle_name: ozel	                   last_name: abaan	full_name: hatice ozel abaan
# Updating entry 4802
# Calling API for name:
# first_name: eeva	middle_name: liisa	                   last_name: eskelinen	full_name: eeva liisa eskelinen
# Updating entry 4806
# Calling API for name:
# first_name: linda	middle_name: korseberg	                   last_name: hagen	full_name: linda korseberg hagen
# Updating entry 4807
# Calling API for name:
# first_name: yan	middle_name: ping	                   last_name: wang	full_name: yan ping wang
# Updating entry 4821
# Calling API for name:
# first_name: maria	middle_name: anna	                   last_name: sico	full_name: maria anna sico
# Updating entry 4830
# Calling API for name:
# first_name: anna	middle_name: maria	                   last_name: timperio	full_name: anna maria timperio
# Updating entry 4834
# Calling API for name:
# first_name: soo	middle_name: jung	                   last_name: kim	full_name: soo jung kim
# Updating entry 4846
# Calling API for name:
# first_name: mariana	middle_name: atena	                   last_name: poiana	full_name: mariana atena poiana
# Updating entry 4851
# Calling API for name:
# first_name: anna	middle_name: maria	                   last_name: novello	full_name: anna maria novello
# Updating entry 4908
# Calling API for name:
# first_name: ana	middle_name: paula	                   last_name: do nascimento prata	full_name: ana paula do nascimento prata
# Updating entry 4909
# Calling API for name:
# first_name: ana	middle_name: beatriz	                   last_name: barros de morais	full_name: ana beatriz barros de morais
# Updating entry 4910
# Calling API for name:
# first_name: camila	middle_name: duarte	                   last_name: ritter	full_name: camila duarte ritter
# Updating entry 4912
# Calling API for name:
# first_name: paula	middle_name: braga	                   last_name: gomes	full_name: paula braga gomes
# Updating entry 4916
# Calling API for name:
# first_name: yung	middle_name: ting	                   last_name: chuang	full_name: yung ting chuang
# Updating entry 4920
# Calling API for name:
# first_name: so	middle_name: young	                   last_name: kim	full_name: so young kim
# Updating entry 4921
# Calling API for name:
# first_name: hye	middle_name: kyung	                   last_name: chung	full_name: hye kyung chung
# Updating entry 4922
# Calling API for name:
# first_name: min	middle_name: sun	                   last_name: park	full_name: min sun park
# Updating entry 4923
# Calling API for name:
# first_name: sun	middle_name: mee	                   last_name: lee	full_name: sun mee lee
# Updating entry 4924
# Calling API for name:
# first_name: jeong	middle_name: won	                   last_name: kim	full_name: jeong won kim
# Updating entry 4925
# Calling API for name:
# first_name: hye	middle_name: ja	                   last_name: chang	full_name: hye ja chang
# Updating entry 4926
# Calling API for name:
# first_name: myung	middle_name: hee	                   last_name: chung	full_name: myung hee chung
# Updating entry 4949
# Calling API for name:
# first_name: ana	middle_name: maria	                   last_name: pinto da fonseca martins	full_name: ana maria pinto da fonseca martins
# Updating entry 4954
# Calling API for name:
# first_name: zi	middle_name: yun	                   last_name: shi	full_name: zi yun shi
# Updating entry 4955
# Calling API for name:
# first_name: young	middle_name: soon	                   last_name: kwon	full_name: young soon kwon
# Updating entry 4958
# Calling API for name:
# first_name: song	middle_name: you	                   last_name: hong	full_name: song you hong
# Updating entry 4968
# Calling API for name:
# first_name: emel	middle_name: dikicioglu	                   last_name: cetin	full_name: emel dikicioglu cetin
# Updating entry 4979
# Calling API for name:
# first_name: vanda	middle_name: brito	                   last_name: de medeiros	full_name: vanda brito de medeiros
# Updating entry 4983
# Calling API for name:
# first_name: ae	middle_name: nim	                   last_name: pae	full_name: ae nim pae
# Updating entry 4985
# Calling API for name:
# first_name: daniele	middle_name: fabio	                   last_name: zullino	full_name: daniele fabio zullino
# Updating entry 4988
# Calling API for name:
# first_name: patricia	middle_name: mirella	                   last_name: da silva	full_name: patricia mirella da silva
# Updating entry 5000
# Calling API for name:
# first_name: yi	middle_name: ching	                   last_name: ho	full_name: yi ching ho
# Updating entry 5006
# Calling API for name:
# first_name: rita	middle_name: de	                   last_name: conceicao	full_name: rita de conceicao
# Updating entry 5023
# Calling API for name:
# first_name: myung	middle_name: hee	                   last_name: kang	full_name: myung hee kang
# Updating entry 5034
# Calling API for name:
# first_name: eun	middle_name: seok	                   last_name: kang	full_name: eun seok kang
# Updating entry 5035
# Calling API for name:
# first_name: jeong	middle_name: bong	                   last_name: lee	full_name: jeong bong lee
# Updating entry 5037
# Calling API for name:
# first_name: dong	middle_name: eun	                   last_name: lee	full_name: dong eun lee
# Updating entry 5038
# Calling API for name:
# first_name: nan	middle_name: xian	                   last_name: chen	full_name: nan xian chen
# Updating entry 5040
# Calling API for name:
# first_name: yee	middle_name: lang	                   last_name: liu	full_name: yee lang liu
# Updating entry 5042
# Calling API for name:
# first_name: yuan	middle_name: zhen	                   last_name: zhou	full_name: yuan zhen zhou
# Updating entry 5044
# Calling API for name:
# first_name: yu	middle_name: wen	                   last_name: chen	full_name: yu wen chen
# Updating entry 5050
# Calling API for name:
# first_name: sun	middle_name: lon	                   last_name: jen	full_name: sun lon jen
# Updating entry 5051
# Calling API for name:
# first_name: yan	middle_name: chay	                   last_name: li	full_name: yan chay li
# Updating entry 5052
# Calling API for name:
# first_name: bing	middle_name: zhu	                   last_name: zhang	full_name: bing zhu zhang
# Updating entry 5055
# Calling API for name:
# first_name: zhong	middle_name: ning	                   last_name: chen	full_name: zhong ning chen
# Updating entry 5056
# Calling API for name:
# first_name: ming	middle_name: qiao	                   last_name: zhu	full_name: ming qiao zhu
# Updating entry 5059
# Calling API for name:
# first_name: chin	middle_name: kian	                   last_name: liew	full_name: chin kian liew
# Updating entry 5061
# Calling API for name:
# first_name: jen	middle_name: tien	                   last_name: wung	full_name: jen tien wung
# Updating entry 5063
# Calling API for name:
# first_name: heng	middle_name: shan	                   last_name: dong	full_name: heng shan dong
# Updating entry 5066
# Calling API for name:
# first_name: yi	middle_name: jen	                   last_name: wang	full_name: yi jen wang
# Updating entry 5069
# Calling API for name:
# first_name: ming	middle_name: shyan	                   last_name: huang	full_name: ming shyan huang
# Updating entry 5071
# Calling API for name:
# first_name: zhen	middle_name: ling	                   last_name: cui	full_name: zhen ling cui
# Updating entry 5073
# Calling API for name:
# first_name: guang	middle_name: ming	                   last_name: lu	full_name: guang ming lu
# Updating entry 5080
# Calling API for name:
# first_name: jing	middle_name: ru	                   last_name: zhou	full_name: jing ru zhou
# Updating entry 5082
# Calling API for name:
# first_name: chin	middle_name: yu	                   last_name: huang	full_name: chin yu huang
# Updating entry 5090
# Calling API for name:
# first_name: chun	middle_name: po	                   last_name: yen	full_name: chun po yen
# Updating entry 5092
# Calling API for name:
# first_name: shin	middle_name: heng	                   last_name: chiou	full_name: shin heng chiou
# Updating entry 5093
# Calling API for name:
# first_name: fei	middle_name: han	                   last_name: hun	full_name: fei han hun
# Updating entry 5095
# Calling API for name:
# first_name: wei	middle_name: da	                   last_name: liu	full_name: wei da liu
# Updating entry 5096
# Calling API for name:
# first_name: yi	middle_name: ping	                   last_name: ge	full_name: yi ping ge
# Updating entry 5097
# Calling API for name:
# first_name: ming	middle_name: xian	                   last_name: liu	full_name: ming xian liu
# Updating entry 5099
# Calling API for name:
# first_name: xiu	middle_name: jian	                   last_name: wang	full_name: xiu jian wang
# Updating entry 5104
# Calling API for name:
# first_name: feng	middle_name: ling	                   last_name: qing	full_name: feng ling qing
# Updating entry 5105
# Calling API for name:
# first_name: fang	middle_name: chieh	                   last_name: chou	full_name: fang chieh chou
# Updating entry 5106
# Calling API for name:
# first_name: xiu	middle_name: ji	                   last_name: shui	full_name: xiu ji shui
# Updating entry 5107
# Calling API for name:
# first_name: ji	middle_name: hyun	                   last_name: jang	full_name: ji hyun jang
# Updating entry 5113
# Calling API for name:
# first_name: pei	middle_name: hong	                   last_name: chen	full_name: pei hong chen
# Updating entry 5114
# Calling API for name:
# first_name: xiao	middle_name: tao	                   last_name: liu	full_name: xiao tao liu
# Updating entry 5117
# Calling API for name:
# first_name: maria	middle_name: teresa	                   last_name: zugliani toniato	full_name: maria teresa zugliani toniato
# Updating entry 5119
# Calling API for name:
# first_name: ki	middle_name: ju	                   last_name: lee	full_name: ki ju lee
# Updating entry 5121
# Calling API for name:
# first_name: woo	middle_name: jong	                   last_name: yu	full_name: woo jong yu
# Updating entry 5126
# Calling API for name:
# first_name: eun	middle_name: jig	                   last_name: lee	full_name: eun jig lee
# Updating entry 5132
# Calling API for name:
# first_name: ya	middle_name: qin	                   last_name: zhang	full_name: ya qin zhang
# Updating entry 5147
# Calling API for name:
# first_name: seong	middle_name: eun	                   last_name: lee	full_name: seong eun lee
# Updating entry 5148
# Calling API for name:
# first_name: so	middle_name: meng	                   last_name: wang	full_name: so meng wang
# Updating entry 5154
# Calling API for name:
# first_name: in	middle_name: chul	                   last_name: hwang	full_name: in chul hwang
# Updating entry 5158
# Calling API for name:
# first_name: tae	middle_name: ju	                   last_name: park	full_name: tae ju park
# Updating entry 5163
# Calling API for name:
# first_name: herminia	middle_name: mino	                   last_name: de kaspar	full_name: herminia mino de kaspar
# Updating entry 5170
# Calling API for name:
# first_name: xiao	middle_name: gui	                   last_name: zhan	full_name: xiao gui zhan
# Updating entry 5184
# Calling API for name:
# first_name: maria	middle_name: grazia	                   last_name: bonomo	full_name: maria grazia bonomo
# Updating entry 5187
# Calling API for name:
# first_name: min	middle_name: hee	                   last_name: lee	full_name: min hee lee
# Updating entry 5188
# Calling API for name:
# first_name: ji	middle_name: hye	                   last_name: han	full_name: ji hye han
# Updating entry 5190
# Calling API for name:
# first_name: ling	middle_name: yueh	                   last_name: hu	full_name: ling yueh hu
# Updating entry 5197
# Calling API for name:
# first_name: soo	middle_name: kyong	                   last_name: choi	full_name: soo kyong choi
# Updating entry 5198
# Calling API for name:
# first_name: yeon	middle_name: gil	                   last_name: jung	full_name: yeon gil jung
# Updating entry 5201
# Calling API for name:
# first_name: li	middle_name: sha	                   last_name: an	full_name: li sha an
# Updating entry 5211
# Calling API for name:
# first_name: yu	middle_name: lin	                   last_name: lai	full_name: yu lin lai
# Updating entry 5216
# Calling API for name:
# first_name: sang	middle_name: woo	                   last_name: lee	full_name: sang woo lee
# Updating entry 5219
# Calling API for name:
# first_name: jose	middle_name: albertino	                   last_name: bendassoli	full_name: jose albertino bendassoli
# Updating entry 5226
# Calling API for name:
# first_name: gustavo	middle_name: ferreira	                   last_name: leonhardt	full_name: gustavo ferreira leonhardt
# Updating entry 5256
# Calling API for name:
# first_name: vicente	middle_name: paulo	                   last_name: campos	full_name: vicente paulo campos
# Updating entry 5307
# Calling API for name:
# first_name: ferhan	middle_name: sami	                   last_name: atalay	full_name: ferhan sami atalay
# Updating entry 5312
# Calling API for name:
# first_name: eung	middle_name: kwan	                   last_name: lee	full_name: eung kwan lee
# Updating entry 5317
# Calling API for name:
# first_name: guo	middle_name: liang	                   last_name: wang	full_name: guo liang wang
# Updating entry 5334
# Calling API for name:
# first_name: de	middle_name: yi	                   last_name: wang	full_name: de yi wang
# Updating entry 5340
# Calling API for name:
# first_name: yuan	middle_name: hao	                   last_name: liu	full_name: yuan hao liu
# Updating entry 5361
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: tardif	full_name: jean claude tardif
# Updating entry 5363
# Calling API for name:
# first_name: kwang	middle_name: ho	                   last_name: kim	full_name: kwang ho kim
# Updating entry 5364
# Calling API for name:
# first_name: yu	middle_name: jen	                   last_name: chen	full_name: yu jen chen
# Updating entry 5376
# Calling API for name:
# first_name: bibhas	middle_name: ranjan	                   last_name: majhi	full_name: bibhas ranjan majhi
# Updating entry 5377
# Calling API for name:
# first_name: george	middle_name: jiunruey	                   last_name: huang	full_name: george jiunruey huang
# Updating entry 5382
# Calling API for name:
# first_name: antonio	middle_name: macilio	                   last_name: pereira de lucenas	full_name: antonio macilio pereira de lucenas
# Updating entry 5385
# Calling API for name:
# first_name: shi	middle_name: wu	                   last_name: wen	full_name: shi wu wen
# Updating entry 5390
# Calling API for name:
# first_name: sergio	middle_name: gregorio	                   last_name: dasilva	full_name: sergio gregorio dasilva
# Updating entry 5396
# Calling API for name:
# first_name: mustafa	middle_name: serdar	                   last_name: genc	full_name: mustafa serdar genc
# Updating entry 5403
# Calling API for name:
# first_name: manuel	middle_name: pedro	                   last_name: salema fevereiro	full_name: manuel pedro salema fevereiro
# Updating entry 5408
# Calling API for name:
# first_name: adunias	middle_name: dos	                   last_name: teixeira	full_name: adunias dos teixeira
# Updating entry 5414
# Calling API for name:
# first_name: young	middle_name: chul	                   last_name: ghim (kim)	full_name: young chul ghim (kim)
# Updating entry 5422
# Calling API for name:
# first_name: mario	middle_name: marcello	                   last_name: miglietta	full_name: mario marcello miglietta
# Updating entry 5429
# Calling API for name:
# first_name: sung	middle_name: hwa	                   last_name: kim	full_name: sung hwa kim
# Updating entry 5448
# Calling API for name:
# first_name: ethan	middle_name: david	                   last_name: cohen	full_name: ethan david cohen
# Updating entry 5485
# Calling API for name:
# first_name: chul	middle_name: hoon	                   last_name: lee	full_name: chul hoon lee
# Updating entry 5501
# Calling API for name:
# first_name: hong	middle_name: fu	                   last_name: wang	full_name: hong fu wang
# Updating entry 5504
# Calling API for name:
# first_name: fabiano	middle_name: buss	                   last_name: cruz	full_name: fabiano buss cruz
# Updating entry 5525
# Calling API for name:
# first_name: gil	middle_name: ho	                   last_name: kim	full_name: gil ho kim
# Updating entry 5546
# Calling API for name:
# first_name: muhammad	middle_name: saeed	                   last_name: wagan	full_name: muhammad saeed wagan
# Updating entry 5552
# Calling API for name:
# first_name: jin	middle_name: tao	                   last_name: wang	full_name: jin tao wang
# Updating entry 5559
# Calling API for name:
# first_name: george	middle_name: davey	                   last_name: smith	full_name: george davey smith
# Updating entry 5577
# Calling API for name:
# first_name: chiu	middle_name: on	                   last_name: ng	full_name: chiu on ng
# Updating entry 5636
# Calling API for name:
# first_name: sang	middle_name: kyu	                   last_name: ye	full_name: sang kyu ye
# Updating entry 5650
# Calling API for name:
# first_name: sang	middle_name: won	                   last_name: yeo	full_name: sang won yeo
# Updating entry 5655
# Calling API for name:
# first_name: hamid	middle_name: reza	                   last_name: khavasi	full_name: hamid reza khavasi
# Updating entry 5677
# Calling API for name:
# first_name: yves	middle_name: andre	                   last_name: bureau	full_name: yves andre bureau
# Updating entry 5684
# Calling API for name:
# first_name: hasan	middle_name: tahsin	                   last_name: gozdas	full_name: hasan tahsin gozdas
# Updating entry 5701
# Calling API for name:
# first_name: wei	middle_name: dong	                   last_name: zhang	full_name: wei dong zhang
# Updating entry 5704
# Calling API for name:
# first_name: sang	middle_name: hyun	                   last_name: oh	full_name: sang hyun oh
# Updating entry 5710
# Calling API for name:
# first_name: li	middle_name: ming	                   last_name: su	full_name: li ming su
# Updating entry 5711
# Calling API for name:
# first_name: hans	middle_name: joachim	                   last_name: ruscheweyh	full_name: hans joachim ruscheweyh
# Updating entry 5715
# Calling API for name:
# first_name: david	middle_name: henry	                   last_name: jimmy	full_name: david henry jimmy
# Updating entry 5719
# Calling API for name:
# first_name: xue	middle_name: jun	                   last_name: liu	full_name: xue jun liu
# Updating entry 5721
# Calling API for name:
# first_name: ravinder	middle_name: kumar	                   last_name: kohli	full_name: ravinder kumar kohli
# Updating entry 5728
# Calling API for name:
# first_name: ken	middle_name: ichi	                   last_name: fujita	full_name: ken ichi fujita
# Updating entry 5755
# Calling API for name:
# first_name: geon	middle_name: ho	                   last_name: choe	full_name: geon ho choe
# Updating entry 5756
# Calling API for name:
# first_name: young	middle_name: tae	                   last_name: kim	full_name: young tae kim
# Updating entry 5757
# Calling API for name:
# first_name: jose	middle_name: carlos	                   last_name: netto-ferreira	full_name: jose carlos netto-ferreira
# Updating entry 5758
# Calling API for name:
# first_name: noedir	middle_name: antonio	                   last_name: groppo stolf	full_name: noedir antonio groppo stolf
# Updating entry 5771
# Calling API for name:
# first_name: seong	middle_name: heum	                   last_name: park	full_name: seong heum park
# Updating entry 5772
# Calling API for name:
# first_name: wei	middle_name: liang	                   last_name: sun	full_name: wei liang sun
# Updating entry 5795
# Calling API for name:
# first_name: hyo	middle_name: jin	                   last_name: ahn	full_name: hyo jin ahn
# Updating entry 5804
# Calling API for name:
# first_name: fernando	middle_name: augusto	                   last_name: barreiros	full_name: fernando augusto barreiros
# Updating entry 5805
# Calling API for name:
# first_name: eric	middle_name: chieh	                   last_name: chou	full_name: eric chieh chou
# Updating entry 5812
# Calling API for name:
# first_name: jong	middle_name: hu	                   last_name: park	full_name: jong hu park
# Updating entry 5813
# Calling API for name:
# first_name: jin	middle_name: ho	                   last_name: choe	full_name: jin ho choe
# Updating entry 5815
# Calling API for name:
# first_name: hassan	middle_name: mohamed	                   last_name: elsangedy	full_name: hassan mohamed elsangedy
# Updating entry 5841
# Calling API for name:
# first_name: woo	middle_name: ram	                   last_name: lee	full_name: woo ram lee
# Updating entry 5842
# Calling API for name:
# first_name: kyu	middle_name: sung	                   last_name: lee	full_name: kyu sung lee
# Updating entry 5843
# Calling API for name:
# first_name: tulio	middle_name: machado	                   last_name: fumian	full_name: tulio machado fumian
# Updating entry 5845
# Calling API for name:
# first_name: kai	middle_name: hang	                   last_name: yiu	full_name: kai hang yiu
# Updating entry 5847
# Calling API for name:
# first_name: deusdedit	middle_name: cortez	                   last_name: silva neto	full_name: deusdedit cortez silva neto
# Updating entry 5850
# Calling API for name:
# first_name: shi	middle_name: kai	                   last_name: yan	full_name: shi kai yan
# Updating entry 5857
# Calling API for name:
# first_name: sayed	middle_name: hossein	                   last_name: banitaba	full_name: sayed hossein banitaba
# Updating entry 5865
# Calling API for name:
# first_name: yu	middle_name: chen	                   last_name: yang	full_name: yu chen yang
# Updating entry 5866
# Calling API for name:
# first_name: kwon	middle_name: il	                   last_name: na	full_name: kwon il na
# Updating entry 5867
# Calling API for name:
# first_name: emanuel	middle_name: joaquim	                   last_name: victoria monteiro oliveira	full_name: emanuel joaquim victoria monteiro oliveira
# Updating entry 5871
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: chaumeil	full_name: jean claude chaumeil
# Updating entry 5873
# Calling API for name:
# first_name: wan	middle_name: chen	                   last_name: huang	full_name: wan chen huang
# Updating entry 5878
# Calling API for name:
# first_name: hye	middle_name: young	                   last_name: kim	full_name: hye young kim
# Updating entry 5885
# Calling API for name:
# first_name: jian	middle_name: jun	                   last_name: fu	full_name: jian jun fu
# Updating entry 5893
# Calling API for name:
# first_name: luis	middle_name: alberto	                   last_name: oliveira dallan	full_name: luis alberto oliveira dallan
# Updating entry 5894
# Calling API for name:
# first_name: gui	middle_name: xia	                   last_name: lu	full_name: gui xia lu
# Updating entry 5895
# Calling API for name:
# first_name: abu	middle_name: james	                   last_name: sundufu	full_name: abu james sundufu
# Updating entry 5905
# Calling API for name:
# first_name: quan	middle_name: sheng	                   last_name: wang	full_name: quan sheng wang
# Updating entry 5908
# Calling API for name:
# first_name: fabio	middle_name: fernando	                   last_name: de araujo	full_name: fabio fernando de araujo
# Updating entry 5918
# Calling API for name:
# first_name: manas	middle_name: ranjan	                   last_name: pattanayak	full_name: manas ranjan pattanayak
# Updating entry 5919
# Calling API for name:
# first_name: flavio	middle_name: pimenta	                   last_name: de figueiredo	full_name: flavio pimenta de figueiredo
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-fae6513a3579> in <module>()
# ----> 1 evaluatorNA.update_selected_records(to_update_remaining_indices)
#
# /Users/lucsan/Work/genderbias/name_gender_inference/evaluator.py in update_selected_records(self, indices)
#     198             api_resp = self._process_row_for_api_call(row)
#     199             api_resp = {'api_{}'.format(k): v for (k,v) in api_resp.items()}
# --> 200             api_resp['gender_infered'] = self.gender_response_mapping[api_resp['api_gender']]
#     201             for (k, v) in api_resp.items():
#     202                 self.test_data.loc[ind, k] = v
#
# KeyError: 'INDETERMINABLE'

# %% [markdown]
# The code couldn't handle the 'INDETERMINABLE' key. Let's fix it manually and commit a patch in evaluators.py.
#
# Note that this name is INDETERMINABLE b/c it's wrongly split in "Surname, Name". It should be: "Pimenta de Figueiredo, Flavio"

# %%
evaluatorNA.test_data[(evaluatorNA.test_data.index.isin(list(to_update_indices))) \
                       & (evaluatorNA.test_data.full_name=='flavio pimenta de figueiredo')]
# Out:
#      first_name middle_name      last_name                     full_name  \
# 5919     flavio     pimenta  de figueiredo  flavio pimenta de figueiredo
#
#      gender  origin  api_confidence      api_gender  gender_infered
# 5919      u  nature             1.0  INDETERMINABLE  INDETERMINABLE

# %%
evaluatorNA.test_data.loc[5919, 'gender_infered'] = 'u'

# %%
to_update_remaining_indices = [ind for ind in to_update_indices if ind>5919]
len(to_update_remaining_indices)
# Out:
# 319

# %%
evaluatorNA.update_selected_records(to_update_remaining_indices)
# Out:
# Updating entry 5936
# Calling API for name:
# first_name: young	middle_name: mo	                   last_name: koo	full_name: young mo koo
# Updating entry 5937
# Calling API for name:
# first_name: long	middle_name: jiang	                   last_name: zhang	full_name: long jiang zhang
# Updating entry 5945
# Calling API for name:
# first_name: kai	middle_name: ming	                   last_name: you	full_name: kai ming you
# Updating entry 5946
# Calling API for name:
# first_name: zhi	middle_name: hui	                   last_name: xu	full_name: zhi hui xu
# Updating entry 5947
# Calling API for name:
# first_name: kuo	middle_name: hung	                   last_name: huang	full_name: kuo hung huang
# Updating entry 5948
# Calling API for name:
# first_name: costin	middle_name: sorin	                   last_name: bildea	full_name: costin sorin bildea
# Updating entry 5950
# Calling API for name:
# first_name: el	middle_name: hassan	                   last_name: hamdani	full_name: el hassan hamdani
# Updating entry 5958
# Calling API for name:
# first_name: acaio	middle_name: zuniga	                   last_name: leite	full_name: acaio zuniga leite
# Updating entry 5959
# Calling API for name:
# first_name: chien	middle_name: ping	                   last_name: chiang	full_name: chien ping chiang
# Updating entry 5967
# Calling API for name:
# first_name: ji	middle_name: heon	                   last_name: park	full_name: ji heon park
# Updating entry 5980
# Calling API for name:
# first_name: leonardo	middle_name: henrique	                   last_name: gomes	full_name: leonardo henrique gomes
# Updating entry 5991
# Calling API for name:
# first_name: ill	middle_name: min	                   last_name: chung	full_name: ill min chung
# Updating entry 5993
# Calling API for name:
# first_name: seung	middle_name: hoon	                   last_name: lee	full_name: seung hoon lee
# Updating entry 5994
# Calling API for name:
# first_name: xiao	middle_name: hua	                   last_name: yuan	full_name: xiao hua yuan
# Updating entry 5998
# Calling API for name:
# first_name: hong	middle_name: yan	                   last_name: lu	full_name: hong yan lu
# Updating entry 6000
# Calling API for name:
# first_name: hao	middle_name: chieh	                   last_name: hsieh	full_name: hao chieh hsieh
# Updating entry 6011
# Calling API for name:
# first_name: sung	middle_name: soo	                   last_name: park	full_name: sung soo park
# Updating entry 6013
# Calling API for name:
# first_name: zheng	middle_name: de	                   last_name: deng	full_name: zheng de deng
# Updating entry 6015
# Calling API for name:
# first_name: cun	middle_name: gang	                   last_name: fan	full_name: cun gang fan
# Updating entry 6016
# Calling API for name:
# first_name: shi	middle_name: yong	                   last_name: fan	full_name: shi yong fan
# Updating entry 6033
# Calling API for name:
# first_name: guang	middle_name: xi	                   last_name: xing	full_name: guang xi xing
# Updating entry 6035
# Calling API for name:
# first_name: pedro	middle_name: luis	                   last_name: da costa aguiar alves	full_name: pedro luis da costa aguiar alves
# Updating entry 6044
# Calling API for name:
# first_name: jose	middle_name: teixeira	                   last_name: de seixas filho	full_name: jose teixeira de seixas filho
# Updating entry 6051
# Calling API for name:
# first_name: beom	middle_name: jin	                   last_name: lee	full_name: beom jin lee
# Updating entry 6052
# Calling API for name:
# first_name: anderson	middle_name: de	                   last_name: barbosa	full_name: anderson de barbosa
# Updating entry 6058
# Calling API for name:
# first_name: min	middle_name: ho	                   last_name: jang	full_name: min ho jang
# Updating entry 6061
# Calling API for name:
# first_name: jia	middle_name: ming	                   last_name: li	full_name: jia ming li
# Updating entry 6067
# Calling API for name:
# first_name: zhi	middle_name: bing	                   last_name: zheng	full_name: zhi bing zheng
# Updating entry 6068
# Calling API for name:
# first_name: chul	middle_name: won	                   last_name: park	full_name: chul won park
# Updating entry 6072
# Calling API for name:
# first_name: lon	middle_name: yen	                   last_name: tsao	full_name: lon yen tsao
# Updating entry 6085
# Calling API for name:
# first_name: jin	middle_name: chun	                   last_name: kim	full_name: jin chun kim
# Updating entry 6087
# Calling API for name:
# first_name: jung	middle_name: hyun	                   last_name: kim	full_name: jung hyun kim
# Updating entry 6094
# Calling API for name:
# first_name: cristiano	middle_name: ragagnin	                   last_name: de menezes	full_name: cristiano ragagnin de menezes
# Updating entry 6105
# Calling API for name:
# first_name: wei	middle_name: ming	                   last_name: wang	full_name: wei ming wang
# Updating entry 6106
# Calling API for name:
# first_name: rolf	middle_name: juergen	                   last_name: schwarz	full_name: rolf juergen schwarz
# Updating entry 6116
# Calling API for name:
# first_name: shiang	middle_name: huei	                   last_name: jiang	full_name: shiang huei jiang
# Updating entry 6119
# Calling API for name:
# first_name: ming	middle_name: ming	                   last_name: guo	full_name: ming ming guo
# Updating entry 6121
# Calling API for name:
# first_name: guo	middle_name: ping	                   last_name: han	full_name: guo ping han
# Updating entry 6122
# Calling API for name:
# first_name: chi	middle_name: ming	                   last_name: hu	full_name: chi ming hu
# Updating entry 6128
# Calling API for name:
# first_name: rong	middle_name: keng	                   last_name: yap	full_name: rong keng yap
# Updating entry 6130
# Calling API for name:
# first_name: chun	middle_name: hung	                   last_name: lai	full_name: chun hung lai
# Updating entry 6137
# Calling API for name:
# first_name: dong	middle_name: hyuk	                   last_name: shin	full_name: dong hyuk shin
# Updating entry 6138
# Calling API for name:
# first_name: hong	middle_name: ru	                   last_name: dong	full_name: hong ru dong
# Updating entry 6142
# Calling API for name:
# first_name: chien	middle_name: hung	                   last_name: yeh	full_name: chien hung yeh
# Updating entry 6144
# Calling API for name:
# first_name: jae	middle_name: keun	                   last_name: kim	full_name: jae keun kim
# Updating entry 6145
# Calling API for name:
# first_name: chang	middle_name: whan	                   last_name: won	full_name: chang whan won
# Updating entry 6150
# Calling API for name:
# first_name: britt	middle_name: maria	                   last_name: beckmann	full_name: britt maria beckmann
# Updating entry 6158
# Calling API for name:
# first_name: jie	middle_name: jin	                   last_name: wang	full_name: jie jin wang
# Updating entry 6173
# Calling API for name:
# first_name: shashi	middle_name: prabha	                   last_name: dubey	full_name: shashi prabha dubey
# Updating entry 6177
# Calling API for name:
# first_name: youn	middle_name: kyung	                   last_name: lim	full_name: youn kyung lim
# Updating entry 6179
# Calling API for name:
# first_name: jin	middle_name: sook	                   last_name: yoon	full_name: jin sook yoon
# Updating entry 6184
# Calling API for name:
# first_name: lee	middle_name: mei	                   last_name: yap	full_name: lee mei yap
# Updating entry 6199
# Calling API for name:
# first_name: kim	middle_name: phuong	                   last_name: vu	full_name: kim phuong vu
# Updating entry 6200
# Calling API for name:
# first_name: sri	middle_name: devi	                   last_name: narasimhan	full_name: sri devi narasimhan
# Updating entry 6203
# Calling API for name:
# first_name: cong	middle_name: xiao	                   last_name: wang	full_name: cong xiao wang
# Updating entry 6204
# Calling API for name:
# first_name: chang	middle_name: hyun	                   last_name: kim	full_name: chang hyun kim
# Updating entry 6211
# Calling API for name:
# first_name: rejane	middle_name: mansur	                   last_name: nogueira	full_name: rejane mansur nogueira
# Updating entry 6216
# Calling API for name:
# first_name: youn	middle_name: soo	                   last_name: kim	full_name: youn soo kim
# Updating entry 6220
# Calling API for name:
# first_name: taciana	middle_name: marco	                   last_name: ferraz caneppele	full_name: taciana marco ferraz caneppele
# Updating entry 6231
# Calling API for name:
# first_name: kim	middle_name: butts	                   last_name: pauly	full_name: kim butts pauly
# Updating entry 6243
# Calling API for name:
# first_name: chris	middle_name: brown	                   last_name: mahoney	full_name: chris brown mahoney
# Updating entry 6245
# Calling API for name:
# first_name: antonia	middle_name: maria	                   last_name: das gracas lopes cito	full_name: antonia maria das gracas lopes cito
# Updating entry 6249
# Calling API for name:
# first_name: jung	middle_name: eun	                   last_name: lee	full_name: jung eun lee
# Updating entry 6257
# Calling API for name:
# first_name: young	middle_name: pil	                   last_name: park	full_name: young pil park
# Updating entry 6259
# Calling API for name:
# first_name: young	middle_name: bum	                   last_name: kim	full_name: young bum kim
# Updating entry 6260
# Calling API for name:
# first_name: jae	middle_name: woong	                   last_name: hwang	full_name: jae woong hwang
# Updating entry 6262
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: vandeweerd	full_name: jean michel vandeweerd
# Updating entry 6264
# Calling API for name:
# first_name: jin	middle_name: hee	                   last_name: woo	full_name: jin hee woo
# Updating entry 6265
# Calling API for name:
# first_name: young	middle_name: han	                   last_name: song	full_name: young han song
# Updating entry 6271
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: marty	full_name: jean louis marty
# Updating entry 6272
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: dognon	full_name: jean pierre dognon
# Updating entry 6273
# Calling API for name:
# first_name: jan	middle_name: ove	                   last_name: ebbestad	full_name: jan ove ebbestad
# Updating entry 6275
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: saudubray	full_name: jean marie saudubray
# Updating entry 6277
# Calling API for name:
# first_name: su	middle_name: young	                   last_name: kim	full_name: su young kim
# Updating entry 6285
# Calling API for name:
# first_name: chi	middle_name: sing	                   last_name: lam	full_name: chi sing lam
# Updating entry 6291
# Calling API for name:
# first_name: chang	middle_name: geun	                   last_name: song	full_name: chang geun song
# Updating entry 6292
# Calling API for name:
# first_name: jan	middle_name: rouke	                   last_name: kuipers	full_name: jan rouke kuipers
# Updating entry 6294
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: diaz	full_name: jean jacques diaz
# Updating entry 6296
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: allegret	full_name: jean pierre allegret
# Updating entry 6300
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: coville	full_name: jean luc coville
# Updating entry 6302
# Calling API for name:
# first_name: pu	middle_name: hong	                   last_name: zhang	full_name: pu hong zhang
# Updating entry 6307
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: merlin	full_name: jean louis merlin
# Updating entry 6311
# Calling API for name:
# first_name: jan	middle_name: erik	                   last_name: fosseidengen	full_name: jan erik fosseidengen
# Updating entry 6313
# Calling API for name:
# first_name: jean	middle_name: patrice	                   last_name: robin	full_name: jean patrice robin
# Updating entry 6314
# Calling API for name:
# first_name: hsin	middle_name: jen	                   last_name: tsai	full_name: hsin jen tsai
# Updating entry 6318
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: brankart	full_name: jean michel brankart
# Updating entry 6324
# Calling API for name:
# first_name: jan	middle_name: haug	                   last_name: anonsen	full_name: jan haug anonsen
# Updating entry 6330
# Calling API for name:
# first_name: chi	middle_name: tim	                   last_name: ng	full_name: chi tim ng
# Updating entry 6336
# Calling API for name:
# first_name: chang	middle_name: young	                   last_name: jang	full_name: chang young jang
# Updating entry 6340
# Calling API for name:
# first_name: jean	middle_name: noel	                   last_name: roux	full_name: jean noel roux
# Updating entry 6341
# Calling API for name:
# first_name: jan	middle_name: hakan	                   last_name: jansson	full_name: jan hakan jansson
# Updating entry 6342
# Calling API for name:
# first_name: jean	middle_name: francos	                   last_name: dartigues	full_name: jean francos dartigues
# Updating entry 6344
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: goujon	full_name: jean michel goujon
# Updating entry 6345
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: saiter	full_name: jean marc saiter
# Updating entry 6352
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: gallo	full_name: jean marc gallo
# Updating entry 6356
# Calling API for name:
# first_name: jean	middle_name: baptiste	                   last_name: sanchez	full_name: jean baptiste sanchez
# Updating entry 6359
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: robin	full_name: jean jacques robin
# Updating entry 6365
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: despres	full_name: jean pierre despres
# Updating entry 6372
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: morel	full_name: jean louis morel
# Updating entry 6374
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: routy	full_name: jean pierre routy
# Updating entry 6380
# Calling API for name:
# first_name: ali	middle_name: esref	                   last_name: mueezzinoglu	full_name: ali esref mueezzinoglu
# Updating entry 6389
# Calling API for name:
# first_name: yong	middle_name: tark	                   last_name: jeon	full_name: yong tark jeon
# Updating entry 6390
# Calling API for name:
# first_name: young	middle_name: tae	                   last_name: chang	full_name: young tae chang
# Updating entry 6395
# Calling API for name:
# first_name: ki	middle_name: chang	                   last_name: keum	full_name: ki chang keum
# Updating entry 6396
# Calling API for name:
# first_name: jean	middle_name: philippe	                   last_name: pin	full_name: jean philippe pin
# Updating entry 6399
# Calling API for name:
# first_name: jan	middle_name: erik	                   last_name: svensson	full_name: jan erik svensson
# Updating entry 6402
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: kraus	full_name: jean louis kraus
# Updating entry 6407
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: deschanvres	full_name: jean luc deschanvres
# Updating entry 6408
# Calling API for name:
# first_name: jean	middle_name: leon	                   last_name: thomas	full_name: jean leon thomas
# Updating entry 6410
# Calling API for name:
# first_name: shun	middle_name: lien	                   last_name: chuang	full_name: shun lien chuang
# Updating entry 6411
# Calling API for name:
# first_name: jean	middle_name: daniel	                   last_name: fekete	full_name: jean daniel fekete
# Updating entry 6412
# Calling API for name:
# first_name: chi	middle_name: wing	                   last_name: fu	full_name: chi wing fu
# Updating entry 6413
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: marier	full_name: jean francois marier
# Updating entry 6418
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: clement	full_name: jean pierre clement
# Updating entry 6421
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: mercier	full_name: jean francois mercier
# Updating entry 6425
# Calling API for name:
# first_name: hong	middle_name: kee	                   last_name: kim	full_name: hong kee kim
# Updating entry 6426
# Calling API for name:
# first_name: young	middle_name: jo	                   last_name: kim	full_name: young jo kim
# Updating entry 6428
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: tadie	full_name: jean marc tadie
# Updating entry 6431
# Calling API for name:
# first_name: jan	middle_name: hendrik	                   last_name: hooijberg	full_name: jan hendrik hooijberg
# Updating entry 6432
# Calling API for name:
# first_name: jan	middle_name: ingvar	                   last_name: jonsson	full_name: jan ingvar jonsson
# Updating entry 6444
# Calling API for name:
# first_name: young	middle_name: don	                   last_name: choi	full_name: young don choi
# Updating entry 6445
# Calling API for name:
# first_name: jean	middle_name: baptiste	                   last_name: michel	full_name: jean baptiste michel
# Updating entry 6449
# Calling API for name:
# first_name: hae	middle_name: ryong	                   last_name: song	full_name: hae ryong song
# Updating entry 6475
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: ploteau	full_name: jean pierre ploteau
# Updating entry 6476
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: besson	full_name: jean luc besson
# Updating entry 6479
# Calling API for name:
# first_name: young	middle_name: tack	                   last_name: lee	full_name: young tack lee
# Updating entry 6481
# Calling API for name:
# first_name: jean	middle_name: philippe	                   last_name: attane	full_name: jean philippe attane
# Updating entry 6492
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: frayret	full_name: jean marc frayret
# Updating entry 6494
# Calling API for name:
# first_name: jaime	middle_name: vilela	                   last_name: de resende	full_name: jaime vilela de resende
# Updating entry 6498
# Calling API for name:
# first_name: chong	middle_name: tin	                   last_name: tan	full_name: chong tin tan
# Updating entry 6500
# Calling API for name:
# first_name: jenn	middle_name: ren	                   last_name: hsiao	full_name: jenn ren hsiao
# Updating entry 6504
# Calling API for name:
# first_name: adrian	middle_name: mihai	                   last_name: ionescu	full_name: adrian mihai ionescu
# Updating entry 6506
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: francois	full_name: jean marie francois
# Updating entry 6508
# Calling API for name:
# first_name: chung	middle_name: yee	                   last_name: lee	full_name: chung yee lee
# Updating entry 6511
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: cornet	full_name: jean francois cornet
# Updating entry 6517
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: lareyre	full_name: jean jacques lareyre
# Updating entry 6519
# Calling API for name:
# first_name: jan	middle_name: peter	                   last_name: embs	full_name: jan peter embs
# Updating entry 6522
# Calling API for name:
# first_name: chung	middle_name: ming	                   last_name: leung	full_name: chung ming leung
# Updating entry 6527
# Calling API for name:
# first_name: ji	middle_name: won	                   last_name: yang	full_name: ji won yang
# Updating entry 6529
# Calling API for name:
# first_name: jan	middle_name: even	                   last_name: nilsen	full_name: jan even nilsen
# Updating entry 6530
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: bonnemain	full_name: jean louis bonnemain
# Updating entry 6531
# Calling API for name:
# first_name: jenn	middle_name: tai	                   last_name: liang	full_name: jenn tai liang
# Updating entry 6535
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: delroisse	full_name: jean marc delroisse
# Updating entry 6536
# Calling API for name:
# first_name: dar	middle_name: ren	                   last_name: ji	full_name: dar ren ji
# Updating entry 6537
# Calling API for name:
# first_name: jan	middle_name: christian	                   last_name: habel	full_name: jan christian habel
# Updating entry 6541
# Calling API for name:
# first_name: chang	middle_name: hyok	                   last_name: choi	full_name: chang hyok choi
# Updating entry 6542
# Calling API for name:
# first_name: man	middle_name: kit	                   last_name: leung	full_name: man kit leung
# Updating entry 6544
# Calling API for name:
# first_name: jaime	middle_name: wilson	                   last_name: vargas de mello	full_name: jaime wilson vargas de mello
# Updating entry 6554
# Calling API for name:
# first_name: ko	middle_name: jiunn	                   last_name: liu	full_name: ko jiunn liu
# Updating entry 6559
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: reubi	full_name: jean claude reubi
# Updating entry 6560
# Calling API for name:
# first_name: jean	middle_name: christophe	                   last_name: rossi	full_name: jean christophe rossi
# Updating entry 6561
# Calling API for name:
# first_name: yong	middle_name: rak	                   last_name: kim	full_name: yong rak kim
# Updating entry 6562
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: probst	full_name: jean luc probst
# Updating entry 6564
# Calling API for name:
# first_name: pak	middle_name: yin	                   last_name: leung	full_name: pak yin leung
# Updating entry 6568
# Calling API for name:
# first_name: jean	middle_name: frederic	                   last_name: gerbeau	full_name: jean frederic gerbeau
# Updating entry 6576
# Calling API for name:
# first_name: chong	middle_name: jai	                   last_name: kim	full_name: chong jai kim
# Updating entry 6583
# Calling API for name:
# first_name: jan	middle_name: maciej	                   last_name: waga	full_name: jan maciej waga
# Updating entry 6588
# Calling API for name:
# first_name: chong	middle_name: yang	                   last_name: liu	full_name: chong yang liu
# Updating entry 6589
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: olie	full_name: jean pierre olie
# Updating entry 6601
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: allain	full_name: jean pierre allain
# Updating entry 6607
# Calling API for name:
# first_name: jean	middle_name: sebastien	                   last_name: sereni	full_name: jean sebastien sereni
# Updating entry 6613
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: huez	full_name: jean francois huez
# Updating entry 6616
# Calling API for name:
# first_name: jean	middle_name: noel	                   last_name: talbot	full_name: jean noel talbot
# Updating entry 6621
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: le galliard	full_name: jean francois le galliard
# Updating entry 6624
# Calling API for name:
# first_name: jan	middle_name: olav	                   last_name: johannessen	full_name: jan olav johannessen
# Updating entry 6626
# Calling API for name:
# first_name: chi	middle_name: hua	                   last_name: chen	full_name: chi hua chen
# Updating entry 6636
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: ndambi	full_name: jean marie ndambi
# Updating entry 6644
# Calling API for name:
# first_name: jan	middle_name: ming	                   last_name: ho	full_name: jan ming ho
# Updating entry 6651
# Calling API for name:
# first_name: jean	middle_name: charles	                   last_name: soria	full_name: jean charles soria
# Updating entry 6655
# Calling API for name:
# first_name: jean	middle_name: baptiste	                   last_name: lattouf	full_name: jean baptiste lattouf
# Updating entry 6664
# Calling API for name:
# first_name: sergey	middle_name: yu	                   last_name: grachev	full_name: sergey yu grachev
# Updating entry 6690
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: nierengarten	full_name: jean francois nierengarten
# Updating entry 6693
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: sauvage	full_name: jean pierre sauvage
# Updating entry 6698
# Calling API for name:
# first_name: jean	middle_name: eric	                   last_name: tarride	full_name: jean eric tarride
# Updating entry 6699
# Calling API for name:
# first_name: jean	middle_name: frederic	                   last_name: colombel	full_name: jean frederic colombel
# Updating entry 6700
# Calling API for name:
# first_name: jean	middle_name: sebastien	                   last_name: rachoin	full_name: jean sebastien rachoin
# Updating entry 6706
# Calling API for name:
# first_name: sung	middle_name: kew	                   last_name: kim	full_name: sung kew kim
# Updating entry 6709
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: etard	full_name: jean francois etard
# Updating entry 6710
# Calling API for name:
# first_name: xue	middle_name: ru	                   last_name: wu	full_name: xue ru wu
# Updating entry 6711
# Calling API for name:
# first_name: jean	middle_name: paul	                   last_name: klein	full_name: jean paul klein
# Updating entry 6713
# Calling API for name:
# first_name: christian	middle_name: meyer	                   last_name: zum bueschenfelde	full_name: christian meyer zum bueschenfelde
# Updating entry 6719
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: beny	full_name: jean louis beny
# Updating entry 6723
# Calling API for name:
# first_name: jean	middle_name: christophe	                   last_name: leroux	full_name: jean christophe leroux
# Updating entry 6727
# Calling API for name:
# first_name: chong	middle_name: shu	                   last_name: zhu	full_name: chong shu zhu
# Updating entry 6728
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: devoisselle	full_name: jean marie devoisselle
# Updating entry 6730
# Calling API for name:
# first_name: pier	middle_name: nicola	                   last_name: sergi	full_name: pier nicola sergi
# Updating entry 6734
# Calling API for name:
# first_name: ali	middle_name: ahmadi	                   last_name: peyghan	full_name: ali ahmadi peyghan
# Updating entry 6735
# Calling API for name:
# first_name: ali	middle_name: osman	                   last_name: solak	full_name: ali osman solak
# Updating entry 6739
# Calling API for name:
# first_name: man	middle_name: bo	                   last_name: li	full_name: man bo li
# Updating entry 6741
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: silvain	full_name: jean francois silvain
# Updating entry 6746
# Calling API for name:
# first_name: jean	middle_name: sebastien	                   last_name: pierre	full_name: jean sebastien pierre
# Updating entry 6748
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: saliege	full_name: jean francois saliege
# Updating entry 6758
# Calling API for name:
# first_name: chong	middle_name: lye	                   last_name: ang	full_name: chong lye ang
# Updating entry 6760
# Calling API for name:
# first_name: young	middle_name: hyun	                   last_name: yoo	full_name: young hyun yoo
# Updating entry 6761
# Calling API for name:
# first_name: hong	middle_name: guo	                   last_name: jin	full_name: hong guo jin
# Updating entry 6766
# Calling API for name:
# first_name: shin	middle_name: young	                   last_name: park	full_name: shin young park
# Updating entry 6767
# Calling API for name:
# first_name: yeon	middle_name: woo	                   last_name: jeong	full_name: yeon woo jeong
# Updating entry 6770
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: vila	full_name: jean marie vila
# Updating entry 6772
# Calling API for name:
# first_name: xing	middle_name: yu	                   last_name: jin	full_name: xing yu jin
# Updating entry 6773
# Calling API for name:
# first_name: young	middle_name: kul	                   last_name: jung	full_name: young kul jung
# Updating entry 6776
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: seigneurin	full_name: jean marie seigneurin
# Updating entry 6780
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: patard	full_name: jean jacques patard
# Updating entry 6782
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: morfin	full_name: jean francois morfin
# Updating entry 6784
# Calling API for name:
# first_name: hong	middle_name: quan	                   last_name: he	full_name: hong quan he
# Updating entry 6790
# Calling API for name:
# first_name: jan	middle_name: roelof	                   last_name: polling	full_name: jan roelof polling
# Updating entry 6793
# Calling API for name:
# first_name: jean	middle_name: claude	                   last_name: berges	full_name: jean claude berges
# Updating entry 6795
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: savard	full_name: jean francois savard
# Updating entry 6796
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: fagon	full_name: jean yves fagon
# Updating entry 6797
# Calling API for name:
# first_name: jean	middle_name: lacau	                   last_name: guily	full_name: jean lacau guily
# Updating entry 6804
# Calling API for name:
# first_name: li	middle_name: sung	                   last_name: tsao	full_name: li sung tsao
# Updating entry 6805
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: sollet	full_name: jean pierre sollet
# Updating entry 6808
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: reperant	full_name: jean michel reperant
# Updating entry 6809
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: leyssale	full_name: jean marc leyssale
# Updating entry 6814
# Calling API for name:
# first_name: chi	middle_name: wang	                   last_name: ip	full_name: chi wang ip
# Updating entry 6816
# Calling API for name:
# first_name: yong	middle_name: lie	                   last_name: chu	full_name: yong lie chu
# Updating entry 6821
# Calling API for name:
# first_name: young	middle_name: bok	                   last_name: lee	full_name: young bok lee
# Updating entry 6822
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: pitetti	full_name: jean luc pitetti
# Updating entry 6826
# Calling API for name:
# first_name: tie	middle_name: hong	                   last_name: chen	full_name: tie hong chen
# Updating entry 6831
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: descotes	full_name: jean luc descotes
# Updating entry 6832
# Calling API for name:
# first_name: chong	middle_name: kil	                   last_name: lee	full_name: chong kil lee
# Updating entry 6836
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: colleau	full_name: jean jacques colleau
# Updating entry 6838
# Calling API for name:
# first_name: man	middle_name: soo	                   last_name: choi	full_name: man soo choi
# Updating entry 6841
# Calling API for name:
# first_name: young	middle_name: geun	                   last_name: lee	full_name: young geun lee
# Updating entry 6845
# Calling API for name:
# first_name: jean	middle_name: marc	                   last_name: guillaume	full_name: jean marc guillaume
# Updating entry 6846
# Calling API for name:
# first_name: chang	middle_name: wook	                   last_name: baek	full_name: chang wook baek
# Updating entry 6847
# Calling API for name:
# first_name: jean	middle_name: ching	                   last_name: tien	full_name: jean ching tien
# Updating entry 6848
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: winum	full_name: jean yves winum
# Updating entry 6851
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: petit	full_name: jean michel petit
# Updating entry 6853
# Calling API for name:
# first_name: eun	middle_name: soo	                   last_name: an	full_name: eun soo an
# Updating entry 6858
# Calling API for name:
# first_name: jan	middle_name: harry	                   last_name: storksen	full_name: jan harry storksen
# Updating entry 6860
# Calling API for name:
# first_name: sang	middle_name: yoo	                   last_name: park	full_name: sang yoo park
# Updating entry 6861
# Calling API for name:
# first_name: ki	middle_name: yong	                   last_name: jeon	full_name: ki yong jeon
# Updating entry 6865
# Calling API for name:
# first_name: eun	middle_name: soo	                   last_name: youk	full_name: eun soo youk
# Updating entry 6868
# Calling API for name:
# first_name: su	middle_name: hyeong	                   last_name: kim	full_name: su hyeong kim
# Updating entry 6870
# Calling API for name:
# first_name: chang	middle_name: keun	                   last_name: sung	full_name: chang keun sung
# Updating entry 6871
# Calling API for name:
# first_name: jean	middle_name: michel	                   last_name: mansuy	full_name: jean michel mansuy
# Updating entry 6872
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: peron	full_name: jean marie peron
# Updating entry 6874
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: girard	full_name: jean marie girard
# Updating entry 6875
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: bouquard	full_name: jean louis bouquard
# Updating entry 6878
# Calling API for name:
# first_name: young	middle_name: woo	                   last_name: kim	full_name: young woo kim
# Updating entry 6879
# Calling API for name:
# first_name: young	middle_name: gil	                   last_name: jeong	full_name: young gil jeong
# Updating entry 6881
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: menetret	full_name: jean francois menetret
# Updating entry 6884
# Calling API for name:
# first_name: qiao	middle_name: bing	                   last_name: wang	full_name: qiao bing wang
# Updating entry 6887
# Calling API for name:
# first_name: britt	middle_name: bang	                   last_name: jensen	full_name: britt bang jensen
# Updating entry 6889
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: marigo	full_name: jean jacques marigo
# Updating entry 6890
# Calling API for name:
# first_name: ji	middle_name: won	                   last_name: kim	full_name: ji won kim
# Updating entry 6892
# Calling API for name:
# first_name: chung	middle_name: shou	                   last_name: chen	full_name: chung shou chen
# Updating entry 6893
# Calling API for name:
# first_name: jean	middle_name: phillipe	                   last_name: avaro	full_name: jean phillipe avaro
# Updating entry 6899
# Calling API for name:
# first_name: chang	middle_name: sup	                   last_name: oh	full_name: chang sup oh
# Updating entry 6900
# Calling API for name:
# first_name: young	middle_name: tai	                   last_name: choi	full_name: young tai choi
# Updating entry 6901
# Calling API for name:
# first_name: sai	middle_name: ming	                   last_name: cheung	full_name: sai ming cheung
# Updating entry 6902
# Calling API for name:
# first_name: ali	middle_name: asghar	                   last_name: rastegari	full_name: ali asghar rastegari
# Updating entry 6903
# Calling API for name:
# first_name: jean	middle_name: rene	                   last_name: lusson	full_name: jean rene lusson
# Updating entry 6905
# Calling API for name:
# first_name: chang	middle_name: hsin	                   last_name: chien	full_name: chang hsin chien
# Updating entry 6907
# Calling API for name:
# first_name: su	middle_name: jae	                   last_name: kim	full_name: su jae kim
# Updating entry 6910
# Calling API for name:
# first_name: youn	middle_name: sun	                   last_name: chung	full_name: youn sun chung
# Updating entry 6913
# Calling API for name:
# first_name: kan	middle_name: shan	                   last_name: shih	full_name: kan shan shih
# Updating entry 6917
# Calling API for name:
# first_name: jean	middle_name: francois	                   last_name: dufour	full_name: jean francois dufour
# Updating entry 6918
# Calling API for name:
# first_name: shun	middle_name: ichi	                   last_name: kuwana	full_name: shun ichi kuwana
# Updating entry 6927
# Calling API for name:
# first_name: da	middle_name: hong	                   last_name: wang	full_name: da hong wang
# Updating entry 6928
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: prioul	full_name: jean louis prioul
# Updating entry 6929
# Calling API for name:
# first_name: taylor	middle_name: price	                   last_name: frazier	full_name: taylor price frazier
# Updating entry 6932
# Calling API for name:
# first_name: jean	middle_name: pierre	                   last_name: finet	full_name: jean pierre finet
# Updating entry 6935
# Calling API for name:
# first_name: kei	middle_name: ichi	                   last_name: maeda	full_name: kei ichi maeda
# Updating entry 6941
# Calling API for name:
# first_name: young	middle_name: kuk	                   last_name: cho	full_name: young kuk cho
# Updating entry 6944
# Calling API for name:
# first_name: ilham	middle_name: zainal	                   last_name: abidin	full_name: ilham zainal abidin
# Updating entry 6945
# Calling API for name:
# first_name: soo	middle_name: yeon	                   last_name: seo	full_name: soo yeon seo
# Updating entry 6946
# Calling API for name:
# first_name: chang	middle_name: soo	                   last_name: eun	full_name: chang soo eun
# Updating entry 6947
# Calling API for name:
# first_name: jean	middle_name: pascal	                   last_name: lefaucheur	full_name: jean pascal lefaucheur
# Updating entry 6952
# Calling API for name:
# first_name: zi	middle_name: niu	                   last_name: yu	full_name: zi niu yu
# Updating entry 6955
# Calling API for name:
# first_name: kelly	middle_name: cristiane	                   last_name: ito	full_name: kelly cristiane ito
# Updating entry 6956
# Calling API for name:
# first_name: young	middle_name: chan	                   last_name: choe	full_name: young chan choe
# Updating entry 6957
# Calling API for name:
# first_name: jan	middle_name: jaap	                   last_name: van lier	full_name: jan jaap van lier
# Updating entry 6959
# Calling API for name:
# first_name: jean	middle_name: christophe	                   last_name: mulatier	full_name: jean christophe mulatier
# Updating entry 6967
# Calling API for name:
# first_name: jeong	middle_name: hyun	                   last_name: lee	full_name: jeong hyun lee
# Updating entry 6968
# Calling API for name:
# first_name: jean	middle_name: laurent	                   last_name: codaccioni	full_name: jean laurent codaccioni
# Updating entry 6969
# Calling API for name:
# first_name: oi	middle_name: hong	                   last_name: tung	full_name: oi hong tung
# Updating entry 6971
# Calling API for name:
# first_name: jean	middle_name: dominique	                   last_name: luporsi	full_name: jean dominique luporsi
# Updating entry 6972
# Calling API for name:
# first_name: jean	middle_name: luc	                   last_name: pasquie	full_name: jean luc pasquie
# Updating entry 6974
# Calling API for name:
# first_name: jean	middle_name: nicolas	                   last_name: cornu	full_name: jean nicolas cornu
# Updating entry 6978
# Calling API for name:
# first_name: jie	middle_name: lun	                   last_name: chiang	full_name: jie lun chiang
# Updating entry 6981
# Calling API for name:
# first_name: chi	middle_name: leung	                   last_name: watt	full_name: chi leung watt
# Updating entry 6984
# Calling API for name:
# first_name: elisha	middle_name: raju	                   last_name: repalle	full_name: elisha raju repalle
# Updating entry 6986
# Calling API for name:
# first_name: chong	middle_name: xin	                   last_name: liu	full_name: chong xin liu
# Updating entry 6987
# Calling API for name:
# first_name: jan	middle_name: eric	                   last_name: grunwald	full_name: jan eric grunwald
# Updating entry 6989
# Calling API for name:
# first_name: dong	middle_name: xin	                   last_name: liu	full_name: dong xin liu
# Updating entry 6990
# Calling API for name:
# first_name: jae	middle_name: soo	                   last_name: koh	full_name: jae soo koh
# Updating entry 6992
# Calling API for name:
# first_name: kuo	middle_name: shun	                   last_name: sun	full_name: kuo shun sun
# Updating entry 6994
# Calling API for name:
# first_name: cao	middle_name: ying	                   last_name: yang	full_name: cao ying yang
# Updating entry 6995
# Calling API for name:
# first_name: bi	middle_name: dong	                   last_name: fang	full_name: bi dong fang
# Updating entry 7003
# Calling API for name:
# first_name: chang	middle_name: sup	                   last_name: kim	full_name: chang sup kim
# Updating entry 7005
# Calling API for name:
# first_name: jean	middle_name: louis	                   last_name: baulieu	full_name: jean louis baulieu
# Updating entry 7008
# Calling API for name:
# first_name: francis	middle_name: raymond	                   last_name: arkoncel	full_name: francis raymond arkoncel
# Updating entry 7011
# Calling API for name:
# first_name: jin	middle_name: young	                   last_name: bae	full_name: jin young bae
# Updating entry 7012
# Calling API for name:
# first_name: jae	middle_name: sin	                   last_name: choi	full_name: jae sin choi
# Updating entry 7016
# Calling API for name:
# first_name: chang	middle_name: hyeon	                   last_name: joh	full_name: chang hyeon joh
# Updating entry 7019
# Calling API for name:
# first_name: chong	middle_name: woo	                   last_name: chu	full_name: chong woo chu
# Updating entry 7023
# Calling API for name:
# first_name: jin	middle_name: young	                   last_name: kim	full_name: jin young kim
# Updating entry 7026
# Calling API for name:
# first_name: chang	middle_name: keun	                   last_name: jo	full_name: chang keun jo
# Updating entry 7032
# Calling API for name:
# first_name: chang	middle_name: woon	                   last_name: choi	full_name: chang woon choi
# Updating entry 7034
# Calling API for name:
# first_name: kyung	middle_name: hwa	                   last_name: han	full_name: kyung hwa han
# Updating entry 7037
# Calling API for name:
# first_name: jean	middle_name: paul	                   last_name: callot	full_name: jean paul callot
# Updating entry 7038
# Calling API for name:
# first_name: chang	middle_name: su	                   last_name: kim	full_name: chang su kim
# Updating entry 7039
# Calling API for name:
# first_name: jean	middle_name: jacques	                   last_name: meister	full_name: jean jacques meister
# Updating entry 7041
# Calling API for name:
# first_name: chang	middle_name: woo	                   last_name: lee	full_name: chang woo lee
# Updating entry 7045
# Calling API for name:
# first_name: jean	middle_name: marie	                   last_name: bonnetblanc	full_name: jean marie bonnetblanc
# Updating entry 7046
# Calling API for name:
# first_name: hong	middle_name: yeol	                   last_name: kim	full_name: hong yeol kim
# Updating entry 7047
# Calling API for name:
# first_name: lee	middle_name: wen	                   last_name: huang	full_name: lee wen huang
# Updating entry 7049
# Calling API for name:
# first_name: young	middle_name: dok	                   last_name: kim	full_name: young dok kim
# Updating entry 7050
# Calling API for name:
# first_name: qi	middle_name: cai	                   last_name: chen	full_name: qi cai chen
# Updating entry 7051
# Calling API for name:
# first_name: lian	middle_name: bing	                   last_name: lin	full_name: lian bing lin
# Updating entry 7056
# Calling API for name:
# first_name: kei	middle_name: ichi	                   last_name: tainaka	full_name: kei ichi tainaka
# Updating entry 7057
# Calling API for name:
# first_name: guo	middle_name: wen	                   last_name: liu	full_name: guo wen liu
# Updating entry 7062
# Calling API for name:
# first_name: chong	middle_name: jun	                   last_name: li	full_name: chong jun li
# Updating entry 7063
# Calling API for name:
# first_name: jean	middle_name: jules	                   last_name: tewa	full_name: jean jules tewa
# Updating entry 7064
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: rauch	full_name: jean yves rauch
# Updating entry 7068
# Calling API for name:
# first_name: chung	middle_name: hyun	                   last_name: cho	full_name: chung hyun cho
# Updating entry 7073
# Calling API for name:
# first_name: pier	middle_name: andrea	                   last_name: de iaco	full_name: pier andrea de iaco
# Updating entry 7074
# Calling API for name:
# first_name: jean	middle_name: yves	                   last_name: scoazec	full_name: jean yves scoazec
# Data updated in dump file test_data/names_api/test_data_all_names_api.csv

# %%
evaluatorNA.compute_all_errors()
evaluatorNA.confusion_matrix
# Out:
#    f_pred  m_pred  u_pred
# f    1585      92     283
# m     141    2827     861
# u     256     586     444

# %% [markdown]
# ### GenderAPI Full

# %%
data_source = 'all'
service_name = GenderAPIFullEvaluator

# %%
evaluatorGAF = service_name(data_source)
evaluatorGAF.load_data()
evaluatorGAF.fetch_gender()
# Out:
# Reading data from dump file test_data/gender_api_full/test_data_all_gender_api_full.csv

# %%
check_match_test_evaluated_data(evaluatorGAF)
# Out:
# Evaluated data set matches contents of test data set. Good!
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_accuracy, api_duration, api_first_name, api_gender, api_last_name, api_name, api_samples, api_strict, gender_infered, _merge]
# Index: []

# %% [markdown]
# #### Re-do names with middle name - since handling of connectors in the code changed after loop refactoring

# %%
# To avoid repeating valid queries, we take only names when empty connector was used
connected_with_empty = (evaluatorGAF.test_data.api_name == evaluatorGAF.test_data.first_name + evaluatorGAF.test_data.middle_name)
evaluatorGAF.test_data[(evaluatorGAF.test_data.middle_name!='') & (connected_with_empty)].head(10)
# Out:
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_accuracy, api_duration, api_first_name, api_gender, api_last_name, api_name, api_samples, api_strict, gender_infered]
# Index: []

# %%
len(evaluatorGA.test_data[(evaluatorGAF.test_data.middle_name!='') & (connected_with_empty)])
# Out:
# 0

# %% [markdown]
# No need to fix the connector - data was evaluated after code refactoring

# %%
evaluatorGAF.compute_all_errors()
evaluatorGAF.confusion_matrix
# Out:
#    f_pred  m_pred  u_pred
# f    1485     240     236
# m     145    3123     561
# u     257     853     176

# %% [markdown]
# ### GenderAPI

# %%
data_source = 'all'
service_name = GenderAPIEvaluator

# %%
evaluatorGA = service_name(data_source)
evaluatorGA.load_data()
evaluatorGA.fetch_gender()
# Out:
# Reading data from dump file test_data/gender_api/test_data_all_gender_api.csv

# %% [markdown]
# #### Fix problem with 'nan' name

# %%
check_match_test_evaluated_data(evaluatorGA)
# Out:
# There is a mismatch between raw and evaluated datasets. Please fix.
# right_only are entries in the raw data set. left_only in the evaluated one.
#      first_name middle_name last_name      full_name gender  origin  \
# 5038                   xian      chen  nan xian chen      m  nature
# 7076        nan        xian      chen  nan xian chen      m  nature
#
#       api_accuracy api_duration gender_infered api_name  api_samples  \
# 5038          61.0         29ms              m     xian        405.0
# 7076           NaN          NaN            NaN      NaN          NaN
#
#      api_gender      _merge
# 5038       male   left_only
# 7076        NaN  right_only

# %%
# In the old test data file the first name had been incorrectly read as NaN. Put 'nan' back in
evaluatorGA.test_data.loc[5038, 'first_name'] = 'nan'

# %%
evaluatorGA.update_selected_records([5038])
# Out:
# Updating entry 5038
# Calling API for name:
# first_name: nan	middle_name: xian	                   last_name: chen	full_name: nan xian chen
# Data updated in dump file test_data/gender_api/test_data_all_gender_api.csv

# %%
evaluatorGA.fetch_gender()
# Out:
# Reading data from dump file test_data/gender_api/test_data_all_gender_api.csv

# %%
check_match_test_evaluated_data(evaluatorGA)
# Out:
# Evaluated data set matches contents of test data set. Good!
# Empty DataFrame
# Columns: [first_name, middle_name, last_name, full_name, gender, origin, api_accuracy, api_duration, gender_infered, api_name, api_samples, api_gender, _merge]
# Index: []

# %% [markdown]
# #### Re-do names with middle name - since handling of connectors in the code changed after loop refactoring

# %%
# To avoid repeating valid queries, we take only names when empty connector was used
connected_with_empty = (evaluatorGA.test_data.api_name == evaluatorGA.test_data.first_name + evaluatorGA.test_data.middle_name)
evaluatorGA.test_data[(evaluatorGA.test_data.middle_name!='') & (connected_with_empty)].head(20)
# Out:
#      first_name middle_name         last_name                    full_name  \
# 44          jae          il               lee                   jae il lee
# 115         jin          ho              choi                  jin ho choi
# 195         soo         jin               kim                  soo jin kim
# 218        sung        hoon              hong               sung hoon hong
# 266       abdel        hadi             ahmed             abdel hadi ahmed
# 373       cheng         wei              chen               cheng wei chen
# 789       carol        anne  costabile-heming  carol anne costabile-heming
# 1009       anne        mary              buck               anne mary buck
# 1838       gian        luca          di tanna           gian luca di tanna
# 2281      young          ae              kang                young ae kang
# 2282        jae         hee              kang                 jae hee kang
# 2322        hae         jin               kim                  hae jin kim
# 2670        ann       marie      navar-boggan       ann marie navar-boggan
# 3397       moon       jeong             chang             moon jeong chang
# 3417         ji          in              kang                   ji in kang
# 3704      seung         joo               kim                seung joo kim
# 3796        won         tae              kwon                 won tae kwon
# 3910        nor      eddine            sounni            nor eddine sounni
# 4097       jong       hyeon              peck              jong hyeon peck
# 4311      young          mi              park                young mi park
#
#      gender             origin  api_accuracy api_duration gender_infered  \
# 44        u             zbmath           100         37ms              m
# 115       m             zbmath            99         16ms              m
# 195       f             zbmath            91         33ms              f
# 218       u             zbmath           100         19ms              m
# 266       u             zbmath            98         20ms              m
# 373       u             zbmath            96         20ms              m
# 789       f         genderizeR            98         30ms              f
# 1009      f  genderizeR_titles           100         72ms              f
# 1838      m            filardo            99         29ms              m
# 2281      f            filardo           100         28ms              f
# 2282      f            filardo            61         43ms              f
# 2322      f            filardo            66         35ms              f
# 2670      f            filardo            98         17ms              f
# 3397      f             nature            86         21ms              f
# 3417      f             nature            69         32ms              f
# 3704      m             nature            60         31ms              m
# 3796      m             nature           100         38ms              m
# 3910      m             nature            99         26ms              m
# 4097      m             nature            93         17ms              m
# 4311      f             nature            89         17ms              f
#
#        api_name  api_samples api_gender
# 44        jaeil           40       male
# 115       jinho          280       male
# 195      soojin          121     female
# 218    sunghoon          140       male
# 266   abdelhadi         1200       male
# 373    chengwei           26       male
# 789   carolanne          183     female
# 1009   annemary           22     female
# 1838   gianluca        23063       male
# 2281    youngae            9     female
# 2282     jaehee          100     female
# 2322     haejin           58     female
# 2670   annmarie          790     female
# 3397  moonjeong            7     female
# 3417       jiin           54     female
# 3704   seungjoo           15       male
# 3796     wontae           19       male
# 3910  noreddine          267       male
# 4097  jonghyeon           14       male
# 4311    youngmi           47     female

# %%
len(evaluatorGA.test_data[(evaluatorGA.test_data.middle_name!='') & (connected_with_empty)])
# Out:
# 105

# %%
to_update_indices = evaluatorGA.test_data[(evaluatorGA.test_data.middle_name!='') & (connected_with_empty)].index
to_update_indices
# Out:
# Int64Index([  44,  115,  195,  218,  266,  373,  789, 1009, 1838, 2281,
#             ...
#             6878, 6890, 6945, 6946, 6956, 6967, 7011, 7016, 7023, 7041],
#            dtype='int64', length=105)

# %%
evaluatorGA.update_selected_records(to_update_indices)
# Out:
# Updating entry 44
# Calling API for name:
# first_name: jae	middle_name: il	                   last_name: lee	full_name: jae il lee
# Updating entry 115
# Calling API for name:
# first_name: jin	middle_name: ho	                   last_name: choi	full_name: jin ho choi
# Updating entry 195
# Calling API for name:
# first_name: soo	middle_name: jin	                   last_name: kim	full_name: soo jin kim
# Updating entry 218
# Calling API for name:
# first_name: sung	middle_name: hoon	                   last_name: hong	full_name: sung hoon hong
# Updating entry 266
# Calling API for name:
# first_name: abdel	middle_name: hadi	                   last_name: ahmed	full_name: abdel hadi ahmed
# Updating entry 373
# Calling API for name:
# first_name: cheng	middle_name: wei	                   last_name: chen	full_name: cheng wei chen
# Updating entry 789
# Calling API for name:
# first_name: carol	middle_name: anne	                   last_name: costabile-heming	full_name: carol anne costabile-heming
# Updating entry 1009
# Calling API for name:
# first_name: anne	middle_name: mary	                   last_name: buck	full_name: anne mary buck
# Updating entry 1838
# Calling API for name:
# first_name: gian	middle_name: luca	                   last_name: di tanna	full_name: gian luca di tanna
# Updating entry 2281
# Calling API for name:
# first_name: young	middle_name: ae	                   last_name: kang	full_name: young ae kang
# Updating entry 2282
# Calling API for name:
# first_name: jae	middle_name: hee	                   last_name: kang	full_name: jae hee kang
# Updating entry 2322
# Calling API for name:
# first_name: hae	middle_name: jin	                   last_name: kim	full_name: hae jin kim
# Updating entry 2670
# Calling API for name:
# first_name: ann	middle_name: marie	                   last_name: navar-boggan	full_name: ann marie navar-boggan
# Updating entry 3397
# Calling API for name:
# first_name: moon	middle_name: jeong	                   last_name: chang	full_name: moon jeong chang
# Updating entry 3417
# Calling API for name:
# first_name: ji	middle_name: in	                   last_name: kang	full_name: ji in kang
# Updating entry 3704
# Calling API for name:
# first_name: seung	middle_name: joo	                   last_name: kim	full_name: seung joo kim
# Updating entry 3796
# Calling API for name:
# first_name: won	middle_name: tae	                   last_name: kwon	full_name: won tae kwon
# Updating entry 3910
# Calling API for name:
# first_name: nor	middle_name: eddine	                   last_name: sounni	full_name: nor eddine sounni
# Updating entry 4097
# Calling API for name:
# first_name: jong	middle_name: hyeon	                   last_name: peck	full_name: jong hyeon peck
# Updating entry 4311
# Calling API for name:
# first_name: young	middle_name: mi	                   last_name: park	full_name: young mi park
# Updating entry 4379
# Calling API for name:
# first_name: so	middle_name: young	                   last_name: yoo	full_name: so young yoo
# Updating entry 4434
# Calling API for name:
# first_name: mary	middle_name: anne	                   last_name: simpson	full_name: mary anne simpson
# Updating entry 4512
# Calling API for name:
# first_name: min	middle_name: kyoung	                   last_name: kim	full_name: min kyoung kim
# Updating entry 4604
# Calling API for name:
# first_name: kay	middle_name: tee	                   last_name: khaw	full_name: kay tee khaw
# Updating entry 4790
# Calling API for name:
# first_name: soo	middle_name: young	                   last_name: park	full_name: soo young park
# Updating entry 4830
# Calling API for name:
# first_name: anna	middle_name: maria	                   last_name: timperio	full_name: anna maria timperio
# Updating entry 4834
# Calling API for name:
# first_name: soo	middle_name: jung	                   last_name: kim	full_name: soo jung kim
# Updating entry 4851
# Calling API for name:
# first_name: anna	middle_name: maria	                   last_name: novello	full_name: anna maria novello
# Updating entry 4920
# Calling API for name:
# first_name: so	middle_name: young	                   last_name: kim	full_name: so young kim
# Updating entry 4922
# Calling API for name:
# first_name: min	middle_name: sun	                   last_name: park	full_name: min sun park
# Updating entry 4924
# Calling API for name:
# first_name: jeong	middle_name: won	                   last_name: kim	full_name: jeong won kim
# Updating entry 4926
# Calling API for name:
# first_name: myung	middle_name: hee	                   last_name: chung	full_name: myung hee chung
# Updating entry 5023
# Calling API for name:
# first_name: myung	middle_name: hee	                   last_name: kang	full_name: myung hee kang
# Updating entry 5034
# Calling API for name:
# first_name: eun	middle_name: seok	                   last_name: kang	full_name: eun seok kang
# Updating entry 5044
# Calling API for name:
# first_name: yu	middle_name: wen	                   last_name: chen	full_name: yu wen chen
# Updating entry 5066
# Calling API for name:
# first_name: yi	middle_name: jen	                   last_name: wang	full_name: yi jen wang
# Updating entry 5082
# Calling API for name:
# first_name: chin	middle_name: yu	                   last_name: huang	full_name: chin yu huang
# Updating entry 5095
# Calling API for name:
# first_name: wei	middle_name: da	                   last_name: liu	full_name: wei da liu
# Updating entry 5096
# Calling API for name:
# first_name: yi	middle_name: ping	                   last_name: ge	full_name: yi ping ge
# Updating entry 5107
# Calling API for name:
# first_name: ji	middle_name: hyun	                   last_name: jang	full_name: ji hyun jang
# Updating entry 5147
# Calling API for name:
# first_name: seong	middle_name: eun	                   last_name: lee	full_name: seong eun lee
# Updating entry 5154
# Calling API for name:
# first_name: in	middle_name: chul	                   last_name: hwang	full_name: in chul hwang
# Updating entry 5158
# Calling API for name:
# first_name: tae	middle_name: ju	                   last_name: park	full_name: tae ju park
# Updating entry 5187
# Calling API for name:
# first_name: min	middle_name: hee	                   last_name: lee	full_name: min hee lee
# Updating entry 5188
# Calling API for name:
# first_name: ji	middle_name: hye	                   last_name: han	full_name: ji hye han
# Updating entry 5201
# Calling API for name:
# first_name: li	middle_name: sha	                   last_name: an	full_name: li sha an
# Updating entry 5211
# Calling API for name:
# first_name: yu	middle_name: lin	                   last_name: lai	full_name: yu lin lai
# Updating entry 5216
# Calling API for name:
# first_name: sang	middle_name: woo	                   last_name: lee	full_name: sang woo lee
# Updating entry 5340
# Calling API for name:
# first_name: yuan	middle_name: hao	                   last_name: liu	full_name: yuan hao liu
# Updating entry 5363
# Calling API for name:
# first_name: kwang	middle_name: ho	                   last_name: kim	full_name: kwang ho kim
# Updating entry 5364
# Calling API for name:
# first_name: yu	middle_name: jen	                   last_name: chen	full_name: yu jen chen
# Updating entry 5414
# Calling API for name:
# first_name: young	middle_name: chul	                   last_name: ghim (kim)	full_name: young chul ghim (kim)
# Updating entry 5429
# Calling API for name:
# first_name: sung	middle_name: hwa	                   last_name: kim	full_name: sung hwa kim
# Updating entry 5650
# Calling API for name:
# first_name: sang	middle_name: won	                   last_name: yeo	full_name: sang won yeo
# Updating entry 5655
# Calling API for name:
# first_name: hamid	middle_name: reza	                   last_name: khavasi	full_name: hamid reza khavasi
# Updating entry 5704
# Calling API for name:
# first_name: sang	middle_name: hyun	                   last_name: oh	full_name: sang hyun oh
# Updating entry 5710
# Calling API for name:
# first_name: li	middle_name: ming	                   last_name: su	full_name: li ming su
# Updating entry 5728
# Calling API for name:
# first_name: ken	middle_name: ichi	                   last_name: fujita	full_name: ken ichi fujita
# Updating entry 5756
# Calling API for name:
# first_name: young	middle_name: tae	                   last_name: kim	full_name: young tae kim
# Updating entry 5772
# Calling API for name:
# first_name: wei	middle_name: liang	                   last_name: sun	full_name: wei liang sun
# Updating entry 5795
# Calling API for name:
# first_name: hyo	middle_name: jin	                   last_name: ahn	full_name: hyo jin ahn
# Updating entry 5813
# Calling API for name:
# first_name: jin	middle_name: ho	                   last_name: choe	full_name: jin ho choe
# Updating entry 5841
# Calling API for name:
# first_name: woo	middle_name: ram	                   last_name: lee	full_name: woo ram lee
# Updating entry 5865
# Calling API for name:
# first_name: yu	middle_name: chen	                   last_name: yang	full_name: yu chen yang
# Updating entry 5878
# Calling API for name:
# first_name: hye	middle_name: young	                   last_name: kim	full_name: hye young kim
# Updating entry 5936
# Calling API for name:
# first_name: young	middle_name: mo	                   last_name: koo	full_name: young mo koo
# Updating entry 5945
# Calling API for name:
# first_name: kai	middle_name: ming	                   last_name: you	full_name: kai ming you
# Updating entry 5950
# Calling API for name:
# first_name: el	middle_name: hassan	                   last_name: hamdani	full_name: el hassan hamdani
# Updating entry 5967
# Calling API for name:
# first_name: ji	middle_name: heon	                   last_name: park	full_name: ji heon park
# Updating entry 5993
# Calling API for name:
# first_name: seung	middle_name: hoon	                   last_name: lee	full_name: seung hoon lee
# Updating entry 6011
# Calling API for name:
# first_name: sung	middle_name: soo	                   last_name: park	full_name: sung soo park
# Updating entry 6058
# Calling API for name:
# first_name: min	middle_name: ho	                   last_name: jang	full_name: min ho jang
# Updating entry 6061
# Calling API for name:
# first_name: jia	middle_name: ming	                   last_name: li	full_name: jia ming li
# Updating entry 6087
# Calling API for name:
# first_name: jung	middle_name: hyun	                   last_name: kim	full_name: jung hyun kim
# Updating entry 6105
# Calling API for name:
# first_name: wei	middle_name: ming	                   last_name: wang	full_name: wei ming wang
# Updating entry 6119
# Calling API for name:
# first_name: ming	middle_name: ming	                   last_name: guo	full_name: ming ming guo
# Updating entry 6137
# Calling API for name:
# first_name: dong	middle_name: hyuk	                   last_name: shin	full_name: dong hyuk shin
# Updating entry 6204
# Calling API for name:
# first_name: chang	middle_name: hyun	                   last_name: kim	full_name: chang hyun kim
# Updating entry 6249
# Calling API for name:
# first_name: jung	middle_name: eun	                   last_name: lee	full_name: jung eun lee
# Updating entry 6259
# Calling API for name:
# first_name: young	middle_name: bum	                   last_name: kim	full_name: young bum kim
# Updating entry 6260
# Calling API for name:
# first_name: jae	middle_name: woong	                   last_name: hwang	full_name: jae woong hwang
# Updating entry 6264
# Calling API for name:
# first_name: jin	middle_name: hee	                   last_name: woo	full_name: jin hee woo
# Updating entry 6291
# Calling API for name:
# first_name: chang	middle_name: geun	                   last_name: song	full_name: chang geun song
# Updating entry 6390
# Calling API for name:
# first_name: young	middle_name: tae	                   last_name: chang	full_name: young tae chang
# Updating entry 6426
# Calling API for name:
# first_name: young	middle_name: jo	                   last_name: kim	full_name: young jo kim
# Updating entry 6444
# Calling API for name:
# first_name: young	middle_name: don	                   last_name: choi	full_name: young don choi
# Updating entry 6527
# Calling API for name:
# first_name: ji	middle_name: won	                   last_name: yang	full_name: ji won yang
# Updating entry 6536
# Calling API for name:
# first_name: dar	middle_name: ren	                   last_name: ji	full_name: dar ren ji
# Updating entry 6626
# Calling API for name:
# first_name: chi	middle_name: hua	                   last_name: chen	full_name: chi hua chen
# Updating entry 6760
# Calling API for name:
# first_name: young	middle_name: hyun	                   last_name: yoo	full_name: young hyun yoo
# Updating entry 6766
# Calling API for name:
# first_name: shin	middle_name: young	                   last_name: park	full_name: shin young park
# Updating entry 6841
# Calling API for name:
# first_name: young	middle_name: geun	                   last_name: lee	full_name: young geun lee
# Updating entry 6853
# Calling API for name:
# first_name: eun	middle_name: soo	                   last_name: an	full_name: eun soo an
# Updating entry 6861
# Calling API for name:
# first_name: ki	middle_name: yong	                   last_name: jeon	full_name: ki yong jeon
# Updating entry 6865
# Calling API for name:
# first_name: eun	middle_name: soo	                   last_name: youk	full_name: eun soo youk
# Updating entry 6878
# Calling API for name:
# first_name: young	middle_name: woo	                   last_name: kim	full_name: young woo kim
# Updating entry 6890
# Calling API for name:
# first_name: ji	middle_name: won	                   last_name: kim	full_name: ji won kim
# Updating entry 6945
# Calling API for name:
# first_name: soo	middle_name: yeon	                   last_name: seo	full_name: soo yeon seo
# Updating entry 6946
# Calling API for name:
# first_name: chang	middle_name: soo	                   last_name: eun	full_name: chang soo eun
# Updating entry 6956
# Calling API for name:
# first_name: young	middle_name: chan	                   last_name: choe	full_name: young chan choe
# Updating entry 6967
# Calling API for name:
# first_name: jeong	middle_name: hyun	                   last_name: lee	full_name: jeong hyun lee
# Updating entry 7011
# Calling API for name:
# first_name: jin	middle_name: young	                   last_name: bae	full_name: jin young bae
# Updating entry 7016
# Calling API for name:
# first_name: chang	middle_name: hyeon	                   last_name: joh	full_name: chang hyeon joh
# Updating entry 7023
# Calling API for name:
# first_name: jin	middle_name: young	                   last_name: kim	full_name: jin young kim
# Updating entry 7041
# Calling API for name:
# first_name: chang	middle_name: woo	                   last_name: lee	full_name: chang woo lee
# Data updated in dump file test_data/gender_api/test_data_all_gender_api.csv

# %%
connected_with_empty = (evaluatorGA.test_data.api_name == evaluatorGA.test_data.first_name + evaluatorGA.test_data.middle_name)
len(evaluatorGA.test_data[(evaluatorGA.test_data.middle_name!='') & (connected_with_empty)])
# Out:
# 0

# %%
evaluatorGA.compute_all_errors()
evaluatorGA.confusion_matrix
# Out:
#    f_pred  m_pred  u_pred
# f    1728     187      46
# m     141    3560     128
# u     298     912      76
